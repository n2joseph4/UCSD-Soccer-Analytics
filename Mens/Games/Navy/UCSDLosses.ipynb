# %%
import pandas as pd
from mplsoccer import Pitch
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
fullHtml = '<div class="teamstats__Index-module__field___8-HYg"><img src="https://cdn5.wyscout.com/photos/team/public/g-13891_120x120.png" class="teamstats__Index-module__field-logo___2x5GG"><svg viewBox="0 0 706 470" class="teamstats__Arrows-module__arrows___1HMhX"><g class=""><defs><marker id="arrow_2311254697" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254697)" x1="173.67600000000002" y1="371.3" x2="554.9159999999999" y2="371.3"></line></g><g class=""><defs><marker id="arrow_2311254705" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254705)" x1="328.996" y1="28.2" x2="378.416" y2="18.8"></line></g><g class=""><defs><marker id="arrow_2311254717" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254717)" x1="505.496" y1="61.1" x2="611.396" y2="173.9"></line></g><g class=""><defs><marker id="arrow_2311254719" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254719)" x1="456.07599999999996" y1="366.6" x2="512.556" y2="352.5"></line></g><g class=""><defs><marker id="arrow_2311254746" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254746)" x1="272.516" y1="32.9" x2="328.996" y2="75.2"></line></g><g class=""><defs><marker id="arrow_2311254760" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254760)" x1="216.03600000000003" y1="28.2" x2="350.176" y2="32.9"></line></g><g class=""><defs><marker id="arrow_2311254768" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254768)" x1="406.656" y1="413.6" x2="526.6759999999999" y2="357.2"></line></g><g class=""><defs><marker id="arrow_2311254770" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254770)" x1="208.97600000000003" y1="178.6" x2="265.456" y2="28.2"></line></g><g class=""><defs><marker id="arrow_2311254775" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254775)" x1="434.89599999999996" y1="75.2" x2="590.216" y2="28.2"></line></g><g class=""><defs><marker id="arrow_2311254780" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254780)" x1="180.73600000000002" y1="239.7" x2="547.856" y2="136.3"></line></g><g class=""><defs><marker id="arrow_2311254799" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254799)" x1="293.696" y1="89.3" x2="611.396" y2="84.6"></line></g><g class=""><defs><marker id="arrow_2311254804" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254804)" x1="251.336" y1="103.4" x2="554.9159999999999" y2="112.8"></line></g><g class=""><defs><marker id="arrow_2311254809" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254809)" x1="618.456" y1="343.1" x2="639.636" y2="291.4"></line></g><g class=""><defs><marker id="arrow_2311254817" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254817)" x1="646.696" y1="446.5" x2="639.636" y2="272.6"></line></g><g class=""><defs><marker id="arrow_2311254829" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254829)" x1="272.516" y1="338.4" x2="618.456" y2="239.7"></line></g><g class=""><defs><marker id="arrow_2311254859" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254859)" x1="456.07599999999996" y1="296.1" x2="413.716" y2="333.7"></line></g><g class=""><defs><marker id="arrow_2311254873" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254873)" x1="244.276" y1="89.3" x2="293.696" y2="79.9"></line></g><g class=""><defs><marker id="arrow_2311254880" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254880)" x1="639.636" y1="361.9" x2="646.696" y2="258.5"></line></g><g class=""><defs><marker id="arrow_2311254894" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254894)" x1="60.715999999999994" y1="441.8" x2="124.256" y2="427.7"></line></g><g class=""><defs><marker id="arrow_2311254904" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254904)" x1="399.596" y1="408.9" x2="392.536" y2="239.7"></line></g><g class=""><defs><marker id="arrow_2311254938" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254938)" x1="583.156" y1="239.7" x2="590.216" y2="352.5"></line></g><g class=""><defs><marker id="arrow_2311254964" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254964)" x1="180.73600000000002" y1="343.1" x2="180.73600000000002" y2="244.4"></line></g><g class=""><defs><marker id="arrow_2311254978" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254978)" x1="378.416" y1="155.1" x2="653.756" y2="188"></line></g><g class=""><defs><marker id="arrow_2311254996" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311254996)" x1="74.836" y1="202.1" x2="484.316" y2="79.9"></line></g><g class=""><defs><marker id="arrow_2311255008" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255008)" x1="674.9359999999999" y1="56.4" x2="681.9959999999999" y2="216.2"></line></g><g class=""><defs><marker id="arrow_2311255043" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255043)" x1="67.776" y1="418.3" x2="110.13600000000001" y2="418.3"></line></g><g class=""><defs><marker id="arrow_2311255051" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255051)" x1="216.03600000000003" y1="418.3" x2="653.756" y2="253.8"></line></g><g class=""><defs><marker id="arrow_2311255080" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255080)" x1="216.03600000000003" y1="51.7" x2="364.296" y2="70.5"></line></g><g class=""><defs><marker id="arrow_2311255082" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255082)" x1="230.15600000000003" y1="117.5" x2="505.496" y2="211.5"></line></g><g class=""><defs><marker id="arrow_2311255094" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255094)" x1="314.87600000000003" y1="150.4" x2="491.376" y2="211.5"></line></g><g class=""><defs><marker id="arrow_2311255110" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255110)" x1="646.696" y1="343.1" x2="583.156" y2="333.7"></line></g><g class=""><defs><marker id="arrow_2311255111" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255111)" x1="519.616" y1="418.3" x2="561.976" y2="413.6"></line></g><g class=""><defs><marker id="arrow_2311255118" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255118)" x1="279.576" y1="404.2" x2="646.696" y2="263.2"></line></g><g class=""><defs><marker id="arrow_2311255164" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255164)" x1="286.636" y1="47" x2="470.19599999999997" y2="42.3"></line></g><g class=""><defs><marker id="arrow_2311255175" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255175)" x1="96.016" y1="343.1" x2="449.01599999999996" y2="366.6"></line></g><g class=""><defs><marker id="arrow_2311255251" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255251)" x1="681.9959999999999" y1="418.3" x2="660.8159999999999" y2="286.7"></line></g><g class=""><defs><marker id="arrow_2311255261" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255261)" x1="632.576" y1="272.6" x2="696.1159999999999" y2="235"></line></g><g class=""><defs><marker id="arrow_2311255276" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255276)" x1="293.696" y1="366.6" x2="625.516" y2="300.8"></line></g><g class=""><defs><marker id="arrow_2311255302" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255302)" x1="321.93600000000004" y1="150.4" x2="569.036" y2="347.8"></line></g><g class=""><defs><marker id="arrow_2311255350" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255350)" x1="392.536" y1="300.8" x2="434.89599999999996" y2="338.4"></line></g><g class=""><defs><marker id="arrow_2311255360" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255360)" x1="251.336" y1="371.3" x2="427.836" y2="267.9"></line></g><g class=""><defs><marker id="arrow_2311255530" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255530)" x1="265.456" y1="117.5" x2="293.696" y2="108.1"></line></g><g class=""><defs><marker id="arrow_2311255541" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255541)" x1="378.416" y1="103.4" x2="547.856" y2="32.9"></line></g><g class=""><defs><marker id="arrow_2311255571" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255571)" x1="477.256" y1="136.3" x2="406.656" y2="183.3"></line></g><g class=""><defs><marker id="arrow_2311255599" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255599)" x1="554.9159999999999" y1="314.9" x2="590.216" y2="338.4"></line></g><g class=""><defs><marker id="arrow_2311255620" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255620)" x1="307.81600000000003" y1="65.8" x2="512.556" y2="89.3"></line></g><g class=""><defs><marker id="arrow_2311255633" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255633)" x1="194.85600000000002" y1="202.1" x2="152.496" y2="159.8"></line></g><g class=""><defs><marker id="arrow_2311255634" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255634)" x1="53.65599999999999" y1="216.2" x2="180.73600000000002" y2="267.9"></line></g><g class=""><defs><marker id="arrow_2311255635" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255635)" x1="74.836" y1="282" x2="53.65599999999999" y2="399.5"></line></g><g class=""><defs><marker id="arrow_2311255663" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255663)" x1="639.636" y1="418.3" x2="653.756" y2="244.4"></line></g><g class=""><defs><marker id="arrow_2311255676" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255676)" x1="441.95599999999996" y1="380.7" x2="519.616" y2="394.8"></line></g><g class=""><defs><marker id="arrow_2311255708" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255708)" x1="399.596" y1="70.5" x2="540.7959999999999" y2="28.2"></line></g><g class=""><defs><marker id="arrow_2311255722" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255722)" x1="244.276" y1="112.8" x2="272.516" y2="117.5"></line></g><g class=""><defs><marker id="arrow_2311255738" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255738)" x1="427.836" y1="173.9" x2="625.516" y2="206.8"></line></g><g class=""><defs><marker id="arrow_2311255744" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255744)" x1="187.79600000000002" y1="230.3" x2="427.836" y2="117.5"></line></g><g class=""><defs><marker id="arrow_2311255753" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255753)" x1="138.376" y1="404.2" x2="237.216" y2="263.2"></line></g><g class=""><defs><marker id="arrow_2311255755" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255755)" x1="96.016" y1="178.6" x2="145.436" y2="79.9"></line></g><g class=""><defs><marker id="arrow_2311255790" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255790)" x1="88.956" y1="333.7" x2="180.73600000000002" y2="446.5"></line></g><g class=""><defs><marker id="arrow_2311255815" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255815)" x1="477.256" y1="267.9" x2="526.6759999999999" y2="122.2"></line></g><g class=""><defs><marker id="arrow_2311255826" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255826)" x1="519.616" y1="117.5" x2="576.096" y2="296.1"></line></g><g class=""><defs><marker id="arrow_2311255900" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255900)" x1="258.396" y1="324.3" x2="208.97600000000003" y2="296.1"></line></g><g class=""><defs><marker id="arrow_2311255925" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255925)" x1="350.176" y1="112.8" x2="427.836" y2="94"></line></g><g class=""><defs><marker id="arrow_2311255953" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255953)" x1="279.576" y1="361.9" x2="505.496" y2="437.1"></line></g><g class=""><defs><marker id="arrow_2311255990" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311255990)" x1="201.91600000000003" y1="84.6" x2="336.056" y2="103.4"></line></g><g class=""><defs><marker id="arrow_2311256034" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256034)" x1="145.436" y1="103.4" x2="293.696" y2="159.8"></line></g><g class=""><defs><marker id="arrow_2311256080" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256080)" x1="300.75600000000003" y1="418.3" x2="293.696" y2="333.7"></line></g><g class=""><defs><marker id="arrow_2311256090" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256090)" x1="434.89599999999996" y1="423" x2="576.096" y2="376"></line></g><g class=""><defs><marker id="arrow_2311256094" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256094)" x1="597.276" y1="399.5" x2="576.096" y2="413.6"></line></g><g class=""><defs><marker id="arrow_2311256102" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256102)" x1="173.67600000000002" y1="235" x2="230.15600000000003" y2="98.7"></line></g><g class=""><defs><marker id="arrow_2311256114" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256114)" x1="427.836" y1="28.2" x2="463.13599999999997" y2="47"></line></g><g class=""><defs><marker id="arrow_2311256124" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256124)" x1="385.476" y1="117.5" x2="321.93600000000004" y2="98.7"></line></g><g class=""><defs><marker id="arrow_2311256137" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256137)" x1="180.73600000000002" y1="94" x2="427.836" y2="47"></line></g><g class=""><defs><marker id="arrow_2311256142" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256142)" x1="173.67600000000002" y1="333.7" x2="498.436" y2="404.2"></line></g><g class=""><defs><marker id="arrow_2311256146" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256146)" x1="223.09600000000003" y1="347.8" x2="420.776" y2="347.8"></line></g><g class=""><defs><marker id="arrow_2311256154" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256154)" x1="456.07599999999996" y1="141" x2="434.89599999999996" y2="159.8"></line></g><g class=""><defs><marker id="arrow_2311256204" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2311256204)" x1="81.896" y1="202.1" x2="385.476" y2="37.6"></line></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="180.73600000000002" y1="343.1" x2="180.73600000000002" y2="244.4"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="180.73600000000002" y1="244.4" x2="96.016" y2="319.6"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="96.016" y1="319.6" x2="0" y2="197.4"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="378.416" y1="126.9" x2="343.116" y2="178.6"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="343.116" y1="178.6" x2="470.19599999999997" y2="296.1"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="470.19599999999997" y1="296.1" x2="456.07599999999996" y2="413.6"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="456.07599999999996" y1="413.6" x2="131.316" y2="399.5"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="131.316" y1="399.5" x2="152.496" y2="277.3"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="152.496" y1="277.3" x2="0" y2="235"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="74.836" y1="282" x2="53.65599999999999" y2="399.5"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="53.65599999999999" y1="399.5" x2="152.496" y2="263.2"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="152.496" y1="263.2" x2="166.616" y2="329"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="166.616" y1="329" x2="0" y2="202.1"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="74.836" y1="220.9" x2="152.496" y2="263.2"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="152.496" y1="263.2" x2="166.616" y2="329"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="166.616" y1="329" x2="0" y2="202.1"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="286.636" y1="150.4" x2="258.396" y2="79.9"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="258.396" y1="79.9" x2="180.73600000000002" y2="37.6"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="180.73600000000002" y1="37.6" x2="208.97600000000003" y2="94"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="208.97600000000003" y1="94" x2="251.336" y2="126.9"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="251.336" y1="126.9" x2="216.03600000000003" y2="239.7"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="216.03600000000003" y1="239.7" x2="0" y2="235"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="166.616" y1="197.4" x2="251.336" y2="126.9"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="251.336" y1="126.9" x2="216.03600000000003" y2="239.7"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="216.03600000000003" y1="239.7" x2="0" y2="235"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="244.276" y1="112.8" x2="180.73600000000002" y2="79.9"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="180.73600000000002" y1="79.9" x2="138.376" y2="164.5"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="138.376" y1="164.5" x2="0" y2="235"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="201.91600000000003" y1="145.7" x2="138.376" y2="164.5"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="138.376" y1="164.5" x2="0" y2="235"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="138.376" y1="404.2" x2="237.216" y2="263.2"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="237.216" y1="263.2" x2="321.93600000000004" y2="263.2"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="321.93600000000004" y1="263.2" x2="279.576" y2="324.3"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="279.576" y1="324.3" x2="208.97600000000003" y2="202.1"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="208.97600000000003" y1="202.1" x2="0" y2="223.25"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="328.996" y1="432.4" x2="237.216" y2="399.5"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="237.216" y1="399.5" x2="173.67600000000002" y2="366.6"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="173.67600000000002" y1="366.6" x2="173.67600000000002" y2="286.7"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="173.67600000000002" y1="286.7" x2="0" y2="235"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="173.67600000000002" y1="235" x2="230.15600000000003" y2="98.7"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="230.15600000000003" y1="98.7" x2="173.67600000000002" y2="155.1"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="173.67600000000002" y1="155.1" x2="0" y2="218.55"></line></g></g></svg><div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 79%; left: 24%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 70%; left: 72%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 6%; left: 46%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 13%; left: 71%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 78%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 26%; left: 58%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 7%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 6%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 31%; left: 52%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 88%; left: 57%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 38%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 16%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 51%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 33%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 9%; left: 56%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 19%; left: 41%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 22%; left: 35%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__cross___2KrLS" style="top: 73%; left: 87%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 81%; left: 68%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 95%; left: 91%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 72%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 68%; left: 93%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 63%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 57%; left: 47%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 19%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 31%; left: 54%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 77%; left: 90%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 8%; left: 63%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 47%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 94%; left: 8%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 87%; left: 56%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 48%; left: 47%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 67%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 60%; left: 93%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 51%; left: 82%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 16%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 87%; left: 86%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 73%; left: 25%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 17%; left: 45%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 33%; left: 53%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 38%; left: 84%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 43%; left: 10%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 12%; left: 95%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 89%; left: 9%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 89%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 11%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 25%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 60%; left: 74%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 32%; left: 44%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 84%; left: 77%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 73%; left: 91%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 89%; left: 73%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 72%; left: 80%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 86%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 17%; left: 58%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>31</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 10%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 27%; left: 53%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 37%; left: 47%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 73%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 33%; left: 47%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 23%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 56%; left: 89%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 74%; left: 92%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>29</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 89%; left: 96%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 41%; left: 97%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 58%; left: 89%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 78%; left: 41%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 75%; left: 45%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 32%; left: 6%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 32%; left: 45%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 51%; left: 53%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 58%; left: 18%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 69%; left: 57%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 64%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 79%; left: 35%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 75%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 25%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 22%; left: 53%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 11%; left: 77%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 84%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 29%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 13%; left: 75%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>31</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 67%; left: 78%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 14%; left: 43%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>31</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 24%; left: 68%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>31</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 43%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 46%; left: 7%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 60%; left: 10%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 47%; left: 10%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 32%; left: 40%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 42%; left: 23%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 49%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 25%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 89%; left: 90%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 81%; left: 62%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 73%; left: 46%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 71%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 15%; left: 56%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 73%; left: 71%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 24%; left: 34%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>31</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 31%; left: 28%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>31</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 38%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 37%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 49%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 8%; left: 44%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 86%; left: 19%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 38%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 16%; left: 44%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 45%; left: 90%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 71%; left: 12%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 31%; left: 44%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 57%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 25%; left: 73%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 40%; left: 89%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 72%; left: 8%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 69%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 92%; left: 46%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 24%; left: 49%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 77%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 38%; left: 91%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 18%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 29%; left: 57%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 38%; left: 90%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 22%; left: 20%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 50%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 34%; left: 9%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>29</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 89%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 90%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 85%; left: 84%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>29</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 22%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 50%; left: 24%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 6%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 25%; left: 54%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 20%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 71%; left: 24%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 74%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 30%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 69%; left: 77%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 43%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div></div></div>'

# %%
arrows = fullHtml.find("teamstats__Arrows-module__arrows")
dots =fullHtml.find("teamstats__Dots-module__dots")
arrowsData = fullHtml[arrows:dots]
dotsData = fullHtml[dots:]

labels = dotsData.split('<div class="teamstats__Dots-module__dot')
positions = []
for label in labels[1:]:
    if "_ground_" in label:
        lossType = "Duel"
    elif '_interception_' in label or '_cross_' in label:
        lossType = "Pass"
    else:
        lossType = "Other"
    left = label.find("left:")
    left = int(label[left+6:left+8].replace("%",""))/100*120
    top = label.find("top:")
    top = int(label[top+5:top+7].replace("%",""))/100*80
    positions.append([left,top,lossType])
positions = pd.DataFrame(positions,columns=["x1","y1","type"])
arrowLabels = arrowsData.split('<g class=""><defs>')
arrows = []
for label in arrowLabels[1:]:
    x1 = label.find("x1")
    y1 = label.find("y1")
    x2 = label.find("x2")
    y2 = label.find("y2")
    coords = label.split("=")[17:]
    coordinates = []
    for i in range(4):
        if i%2==0:
            divided = 710.2359999999999/120
        else:
            divided = 470/80
        val = coords[i]
        val = float(val.split('"')[1])/divided
        coordinates.append(val)
    arrows.append(coordinates)
arrows = pd.DataFrame(arrows,columns=["x1",'y1',"x2","y2"])
noPasses = positions[positions.get("type")!="Pass"]
pos = noPasses.get(["x1","y1"]).to_numpy()
arr = arrows.get(["x2","y2"]).to_numpy()
merged = np.concatenate((pos,arr))
merged = pd.DataFrame(merged,columns=['x','y'])

# %%
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=merged.get("x"),y=merged.get("y"),fill = True,shade_lowest = False,alpha = .5,n_levels = 20,cmap = "magma")
for i in range(positions.shape[0]):
    row = positions.iloc[i]

    plt.plot(row.get("x1"),row.get("y1"),'ro')
plt.title("UCSD Losses")
plt.show()

# %%
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=arrows.get("x1"),y=arrows.get("y1"),fill = True,shade_lowest = False,alpha = .5,n_levels = 20,cmap = "magma")
for i in range(arrows.shape[0]):
    row = arrows.iloc[i]
    plt.arrow(row.get("x1"),row.get("y1"),row.get("x2")-row.get("x1"),row.get("y2")-row.get("y1"),width = .2,alpha = .3)

plt.title("UCSD Misplayed Passes Starting")
plt.show()
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=arrows.get("x2"),y=arrows.get("y2"),fill = True,shade_lowest = False,alpha = .5,n_levels = 20,cmap = "magma")
for i in range(arrows.shape[0]):
    row = arrows.iloc[i]
    plt.arrow(row.get("x1"),row.get("y1"),row.get("x2")-row.get("x1"),row.get("y2")-row.get("y1"),width = .2,alpha = .3)
plt.title("UCSD Misplayed Passes Ending")
plt.show()

# %%
print(positions.shape[0]-arrows.shape[0], arrows.shape[0])
# Out:
# 63 76

# %%
leftLosses = merged[merged.get("y")<40]
rightLosses = merged[merged.get("y")>40]
print(leftLosses.shape[0],rightLosses.shape[0])
# Out:
# 75 62
