# %%
import pandas as pd
from mplsoccer import Pitch
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
fullHtml = '<div class="teamstats__Index-module__field___8-HYg"><img src="https://cdn5.wyscout.com/photos/team/public/g-2322_120x120.png" class="teamstats__Index-module__field-logo___2x5GG"><svg viewBox="0 0 706 470" class="teamstats__Arrows-module__arrows___1HMhX"><g class=""><defs><marker id="arrow_2270522586" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522586)" x1="540.7959999999999" y1="155.1" x2="653.756" y2="230.3"></line></g><g class=""><defs><marker id="arrow_2270522600" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522600)" x1="166.616" y1="437.1" x2="286.636" y2="324.3"></line></g><g class=""><defs><marker id="arrow_2270522605" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522605)" x1="258.396" y1="455.9" x2="569.036" y2="329"></line></g><g class=""><defs><marker id="arrow_2270522623" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522623)" x1="110.13600000000001" y1="249.1" x2="533.736" y2="230.3"></line></g><g class=""><defs><marker id="arrow_2270522628" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522628)" x1="244.276" y1="390.1" x2="336.056" y2="343.1"></line></g><g class=""><defs><marker id="arrow_2270522640" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522640)" x1="293.696" y1="103.4" x2="519.616" y2="230.3"></line></g><g class=""><defs><marker id="arrow_2270522644" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522644)" x1="81.896" y1="235" x2="547.856" y2="343.1"></line></g><g class=""><defs><marker id="arrow_2270522706" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522706)" x1="46.596" y1="319.6" x2="293.696" y2="230.3"></line></g><g class=""><defs><marker id="arrow_2270522719" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522719)" x1="110.13600000000001" y1="145.7" x2="512.556" y2="211.5"></line></g><g class=""><defs><marker id="arrow_2270522778" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522778)" x1="286.636" y1="272.6" x2="498.436" y2="230.3"></line></g><g class=""><defs><marker id="arrow_2270522790" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522790)" x1="533.736" y1="89.3" x2="470.19599999999997" y2="197.4"></line></g><g class=""><defs><marker id="arrow_2270522800" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522800)" x1="554.9159999999999" y1="451.2" x2="554.9159999999999" y2="324.3"></line></g><g class=""><defs><marker id="arrow_2270522821" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522821)" x1="159.556" y1="427.7" x2="498.436" y2="300.8"></line></g><g class=""><defs><marker id="arrow_2270522863" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522863)" x1="328.996" y1="37.6" x2="569.036" y2="103.4"></line></g><g class=""><defs><marker id="arrow_2270522931" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522931)" x1="117.196" y1="239.7" x2="484.316" y2="145.7"></line></g><g class=""><defs><marker id="arrow_2270522935" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522935)" x1="385.476" y1="286.7" x2="491.376" y2="310.2"></line></g><g class=""><defs><marker id="arrow_2270522941" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522941)" x1="321.93600000000004" y1="338.4" x2="307.81600000000003" y2="352.5"></line></g><g class=""><defs><marker id="arrow_2270522963" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522963)" x1="703.1759999999999" y1="122.2" x2="674.9359999999999" y2="202.1"></line></g><g class=""><defs><marker id="arrow_2270522984" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270522984)" x1="314.87600000000003" y1="230.3" x2="484.316" y2="75.2"></line></g><g class=""><defs><marker id="arrow_2270523001" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523001)" x1="138.376" y1="47" x2="336.056" y2="112.8"></line></g><g class=""><defs><marker id="arrow_2270523004" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523004)" x1="223.09600000000003" y1="155.1" x2="477.256" y2="103.4"></line></g><g class=""><defs><marker id="arrow_2270523044" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523044)" x1="533.736" y1="347.8" x2="540.7959999999999" y2="178.6"></line></g><g class=""><defs><marker id="arrow_2270523058" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523058)" x1="491.376" y1="216.2" x2="463.13599999999997" y2="296.1"></line></g><g class=""><defs><marker id="arrow_2270523090" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523090)" x1="265.456" y1="324.3" x2="526.6759999999999" y2="282"></line></g><g class=""><defs><marker id="arrow_2270523194" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523194)" x1="681.9959999999999" y1="418.3" x2="703.1759999999999" y2="244.4"></line></g><g class=""><defs><marker id="arrow_2270523269" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523269)" x1="74.836" y1="159.8" x2="272.516" y2="286.7"></line></g><g class=""><defs><marker id="arrow_2270523299" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523299)" x1="39.536" y1="249.1" x2="307.81600000000003" y2="333.7"></line></g><g class=""><defs><marker id="arrow_2270523329" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523329)" x1="187.79600000000002" y1="103.4" x2="251.336" y2="112.8"></line></g><g class=""><defs><marker id="arrow_2270523348" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523348)" x1="208.97600000000003" y1="225.6" x2="505.496" y2="117.5"></line></g><g class=""><defs><marker id="arrow_2270523349" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523349)" x1="152.496" y1="216.2" x2="258.396" y2="178.6"></line></g><g class=""><defs><marker id="arrow_2270523463" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523463)" x1="124.256" y1="103.4" x2="441.95599999999996" y2="79.9"></line></g><g class=""><defs><marker id="arrow_2270523470" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523470)" x1="145.436" y1="136.3" x2="470.19599999999997" y2="230.3"></line></g><g class=""><defs><marker id="arrow_2270523471" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523471)" x1="244.276" y1="230.3" x2="449.01599999999996" y2="239.7"></line></g><g class=""><defs><marker id="arrow_2270523481" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523481)" x1="216.03600000000003" y1="460.6" x2="533.736" y2="305.5"></line></g><g class=""><defs><marker id="arrow_2270523505" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523505)" x1="392.536" y1="446.5" x2="427.836" y2="329"></line></g><g class=""><defs><marker id="arrow_2270523536" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523536)" x1="138.376" y1="108.1" x2="441.95599999999996" y2="98.7"></line></g><g class=""><defs><marker id="arrow_2270523579" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523579)" x1="216.03600000000003" y1="47" x2="491.376" y2="366.6"></line></g><g class=""><defs><marker id="arrow_2270523589" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523589)" x1="166.616" y1="310.2" x2="512.556" y2="126.9"></line></g><g class=""><defs><marker id="arrow_2270523619" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523619)" x1="166.616" y1="89.3" x2="272.516" y2="192.7"></line></g><g class=""><defs><marker id="arrow_2270523653" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523653)" x1="159.556" y1="51.7" x2="505.496" y2="235"></line></g><g class=""><defs><marker id="arrow_2270523709" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523709)" x1="187.79600000000002" y1="286.7" x2="470.19599999999997" y2="258.5"></line></g><g class=""><defs><marker id="arrow_2270523723" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523723)" x1="46.596" y1="249.1" x2="300.75600000000003" y2="235"></line></g><g class=""><defs><marker id="arrow_2270523750" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523750)" x1="258.396" y1="47" x2="300.75600000000003" y2="122.2"></line></g><g class=""><defs><marker id="arrow_2270523751" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523751)" x1="138.376" y1="28.2" x2="293.696" y2="155.1"></line></g><g class=""><defs><marker id="arrow_2270523761" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523761)" x1="223.09600000000003" y1="352.5" x2="385.476" y2="305.5"></line></g><g class=""><defs><marker id="arrow_2270523824" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523824)" x1="265.456" y1="347.8" x2="441.95599999999996" y2="206.8"></line></g><g class=""><defs><marker id="arrow_2270523834" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523834)" x1="343.116" y1="343.1" x2="561.976" y2="89.3"></line></g><g class=""><defs><marker id="arrow_2270523843" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523843)" x1="11.296000000000001" y1="390.1" x2="67.776" y2="390.1"></line></g><g class=""><defs><marker id="arrow_2270523854" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523854)" x1="569.036" y1="347.8" x2="604.336" y2="239.7"></line></g><g class=""><defs><marker id="arrow_2270523863" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523863)" x1="470.19599999999997" y1="94" x2="434.89599999999996" y2="112.8"></line></g><g class=""><defs><marker id="arrow_2270523878" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523878)" x1="646.696" y1="70.5" x2="660.8159999999999" y2="145.7"></line></g><g class=""><defs><marker id="arrow_2270523961" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523961)" x1="223.09600000000003" y1="197.4" x2="491.376" y2="357.2"></line></g><g class=""><defs><marker id="arrow_2270523984" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270523984)" x1="159.556" y1="23.5" x2="265.456" y2="150.4"></line></g><g class=""><defs><marker id="arrow_2270524020" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270524020)" x1="533.736" y1="122.2" x2="604.336" y2="150.4"></line></g><g class=""><defs><marker id="arrow_2270524059" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270524059)" x1="385.476" y1="258.5" x2="477.256" y2="352.5"></line></g><g class=""><defs><marker id="arrow_2270524065" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270524065)" x1="625.516" y1="122.2" x2="646.696" y2="145.7"></line></g><g class=""><defs><marker id="arrow_2270524084" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270524084)" x1="463.13599999999997" y1="432.4" x2="547.856" y2="404.2"></line></g><g class=""><defs><marker id="arrow_2270524094" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270524094)" x1="427.836" y1="249.1" x2="427.836" y2="75.2"></line></g><g class=""><defs><marker id="arrow_2270524098" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270524098)" x1="660.8159999999999" y1="408.9" x2="625.516" y2="249.1"></line></g><g class=""><defs><marker id="arrow_2270524100" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270524100)" x1="145.436" y1="244.4" x2="505.496" y2="361.9"></line></g><g class=""><defs><marker id="arrow_2270524123" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270524123)" x1="265.456" y1="305.5" x2="194.85600000000002" y2="159.8"></line></g><g class=""><defs><marker id="arrow_2270524130" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270524130)" x1="463.13599999999997" y1="216.2" x2="434.89599999999996" y2="230.3"></line></g><g class=""><defs><marker id="arrow_2270524162" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2270524162)" x1="159.556" y1="32.9" x2="456.07599999999996" y2="112.8"></line></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="46.596" y1="89.3" x2="46.596" y2="89.3"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="46.596" y1="89.3" x2="96.016" y2="136.3"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="96.016" y1="136.3" x2="180.73600000000002" y2="178.6"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="180.73600000000002" y1="178.6" x2="173.67600000000002" y2="126.9"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="173.67600000000002" y1="126.9" x2="173.67600000000002" y2="169.2"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="173.67600000000002" y1="169.2" x2="0" y2="213.85"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="293.696" y1="324.3" x2="223.09600000000003" y2="310.2"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="223.09600000000003" y1="310.2" x2="251.336" y2="371.3"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="251.336" y1="371.3" x2="265.456" y2="423"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="265.456" y1="423" x2="258.396" y2="394.8"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="258.396" y1="394.8" x2="223.09600000000003" y2="126.9"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="223.09600000000003" y1="126.9" x2="0" y2="202.1"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="25.416" y1="192.7" x2="208.97600000000003" y2="192.7"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="208.97600000000003" y1="192.7" x2="0" y2="267.9"></line></g></g></svg><div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 33%; left: 76%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 88%; left: 86%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 89%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 14%; left: 48%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 93%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 97%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 48%; left: 66%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 53%; left: 15%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 60%; left: 53%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 83%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 22%; left: 41%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 50%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 60%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 82%; left: 90%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 10%; left: 95%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 15%; left: 68%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 47%; left: 73%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 68%; left: 6%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 85%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 31%; left: 15%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 18%; left: 4%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 58%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 19%; left: 75%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 96%; left: 78%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 83%; left: 80%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 91%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 12%; left: 87%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 76%; left: 73%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 8%; left: 46%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 85%; left: 90%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 87%; left: 35%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 51%; left: 16%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 61%; left: 54%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 90%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 72%; left: 45%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 89%; left: 45%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 26%; left: 99%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 19%; left: 6%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 49%; left: 44%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 21%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 10%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 33%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 74%; left: 75%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 46%; left: 69%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 64%; left: 81%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 52%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 10%; left: 69%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 69%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 90%; left: 62%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 18%; left: 79%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 89%; left: 96%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>18</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 22%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 69%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 34%; left: 10%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 78%; left: 66%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 53%; left: 5%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 60%; left: 99%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 22%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 50%; left: 14%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 48%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 46%; left: 21%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 41%; left: 3%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 25%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 22%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 29%; left: 20%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 49%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 98%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 54%; left: 54%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 95%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>18</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 23%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 82%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 10%; left: 4%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 10%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 79%; left: 54%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 66%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 37%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 19%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 11%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 39%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 52%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 49%; left: 72%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 68%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 61%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 53%; left: 6%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 10%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 6%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 75%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 15%; left: 78%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 31%; left: 77%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 74%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 45%; left: 59%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 73%; left: 48%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 83%; left: 1%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 74%; left: 80%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 20%; left: 66%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__cross___2KrLS" style="top: 15%; left: 91%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 22%; left: 63%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 14%; left: 54%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 32%; left: 41%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 42%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 5%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 66%; left: 74%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 26%; left: 75%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 43%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 27%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 58%; left: 65%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 93%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 55%; left: 54%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__cross___2KrLS" style="top: 26%; left: 88%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 35%; left: 58%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 92%; left: 65%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 28%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 53%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 87%; left: 93%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 52%; left: 20%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 67%; left: 97%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 83%; left: 87%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 65%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 46%; left: 65%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 22%; left: 94%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 93%; left: 54%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 57%; left: 54%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 7%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 7%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 21%; left: 65%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 46%; left: 94%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div></div></div>'

# %%
arrows = fullHtml.find("teamstats__Arrows-module__arrows")
dots =fullHtml.find("teamstats__Dots-module__dots")
arrowsData = fullHtml[arrows:dots]
dotsData = fullHtml[dots:]

labels = dotsData.split('<div class="teamstats__Dots-module__dot')
positions = []
for label in labels[1:]:
    left = label.find("left:")
    left = int(label[left+6:left+8].replace("%",""))/100*120
    top = label.find("top:")
    top = int(label[top+5:top+7].replace("%",""))/100*80
    positions.append([left,top])
positions = pd.DataFrame(positions,columns=["x1","y1"])
arrowLabels = arrowsData.split('<g class=""><defs>')
arrows = []
for label in arrowLabels[1:]:
    x1 = label.find("x1")
    y1 = label.find("y1")
    x2 = label.find("x2")
    y2 = label.find("y2")
    coords = label.split("=")[17:]
    coordinates = []
    for i in range(4):
        if i%2==0:
            divided = 710.2359999999999/120
        else:
            divided = 470/80
        val = coords[i]
        val = float(val.split('"')[1])/divided
        coordinates.append(val)
    arrows.append(coordinates)
arrows = pd.DataFrame(arrows,columns=["x1",'y1',"x2","y2"])
pos = positions.to_numpy()
arr = arrows.get(["x2","y2"]).to_numpy()
merged = np.concatenate((pos,arr))
merged = pd.DataFrame(merged,columns=['x','y'])
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=merged.get("x"),y=merged.get("y"),fill = True,shade_lowest = False,alpha = .5,n_levels = 20,cmap = "magma")
plt.title("Duke Losses")

# %%
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=arrows.get("x1"),y=arrows.get("y1"),fill = True,shade_lowest = False,alpha = .5,n_levels = 20,cmap = "magma")
plt.title("Duke Misplayed Passes Starting")
# Out:
# Text(0.5, 1.0, 'Duke Misplayed Passes Starting')
