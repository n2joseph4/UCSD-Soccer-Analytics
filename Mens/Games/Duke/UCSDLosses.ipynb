# %%
import pandas as pd
from mplsoccer import Pitch
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
fullHtml = '<div class="teamstats__Index-module__field___8-HYg"><img src="https://cdn5.wyscout.com/photos/team/public/g-13891_120x120.png" class="teamstats__Index-module__field-logo___2x5GG"><svg viewBox="0 0 706 470" class="teamstats__Arrows-module__arrows___1HMhX"><g class=""><defs><marker id="arrow_2275219318" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219318)" x1="413.716" y1="145.7" x2="512.556" y2="169.2"></line></g><g class=""><defs><marker id="arrow_2275219320" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219320)" x1="441.95599999999996" y1="94" x2="597.276" y2="32.9"></line></g><g class=""><defs><marker id="arrow_2275219342" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219342)" x1="314.87600000000003" y1="18.8" x2="646.696" y2="150.4"></line></g><g class=""><defs><marker id="arrow_2275219354" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219354)" x1="625.516" y1="296.1" x2="611.396" y2="141"></line></g><g class=""><defs><marker id="arrow_2275219365" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219365)" x1="110.13600000000001" y1="338.4" x2="187.79600000000002" y2="0"></line></g><g class=""><defs><marker id="arrow_2275219374" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219374)" x1="138.376" y1="51.7" x2="173.67600000000002" y2="32.9"></line></g><g class=""><defs><marker id="arrow_2275219379" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219379)" x1="491.376" y1="79.9" x2="477.256" y2="79.9"></line></g><g class=""><defs><marker id="arrow_2275219392" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219392)" x1="434.89599999999996" y1="361.9" x2="484.316" y2="470"></line></g><g class=""><defs><marker id="arrow_2275219396" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219396)" x1="96.016" y1="202.1" x2="512.556" y2="131.6"></line></g><g class=""><defs><marker id="arrow_2275219399" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219399)" x1="307.81600000000003" y1="188" x2="441.95599999999996" y2="94"></line></g><g class=""><defs><marker id="arrow_2275219414" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219414)" x1="46.596" y1="263.2" x2="237.216" y2="319.6"></line></g><g class=""><defs><marker id="arrow_2275219416" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219416)" x1="230.15600000000003" y1="239.7" x2="406.656" y2="291.4"></line></g><g class=""><defs><marker id="arrow_2275219419" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219419)" x1="208.97600000000003" y1="324.3" x2="328.996" y2="413.6"></line></g><g class=""><defs><marker id="arrow_2275219432" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219432)" x1="533.736" y1="51.7" x2="590.216" y2="150.4"></line></g><g class=""><defs><marker id="arrow_2275219477" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219477)" x1="131.316" y1="202.1" x2="223.09600000000003" y2="164.5"></line></g><g class=""><defs><marker id="arrow_2275219533" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219533)" x1="336.056" y1="155.1" x2="434.89599999999996" y2="159.8"></line></g><g class=""><defs><marker id="arrow_2275219559" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219559)" x1="689.0559999999999" y1="427.7" x2="667.8759999999999" y2="272.6"></line></g><g class=""><defs><marker id="arrow_2275219592" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219592)" x1="300.75600000000003" y1="56.4" x2="611.396" y2="296.1"></line></g><g class=""><defs><marker id="arrow_2275219714" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219714)" x1="53.65599999999999" y1="399.5" x2="456.07599999999996" y2="357.2"></line></g><g class=""><defs><marker id="arrow_2275219717" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219717)" x1="293.696" y1="324.3" x2="470.19599999999997" y2="296.1"></line></g><g class=""><defs><marker id="arrow_2275219725" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219725)" x1="258.396" y1="286.7" x2="328.996" y2="263.2"></line></g><g class=""><defs><marker id="arrow_2275219778" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219778)" x1="265.456" y1="56.4" x2="272.516" y2="206.8"></line></g><g class=""><defs><marker id="arrow_2275219789" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219789)" x1="561.976" y1="343.1" x2="625.516" y2="239.7"></line></g><g class=""><defs><marker id="arrow_2275219792" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219792)" x1="653.756" y1="352.5" x2="653.756" y2="122.2"></line></g><g class=""><defs><marker id="arrow_2275219798" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219798)" x1="265.456" y1="131.6" x2="371.356" y2="122.2"></line></g><g class=""><defs><marker id="arrow_2275219826" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219826)" x1="173.67600000000002" y1="150.4" x2="237.216" y2="126.9"></line></g><g class=""><defs><marker id="arrow_2275219833" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219833)" x1="223.09600000000003" y1="225.6" x2="399.596" y2="225.6"></line></g><g class=""><defs><marker id="arrow_2275219864" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219864)" x1="293.696" y1="376" x2="314.87600000000003" y2="366.6"></line></g><g class=""><defs><marker id="arrow_2275219939" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219939)" x1="343.116" y1="150.4" x2="420.776" y2="75.2"></line></g><g class=""><defs><marker id="arrow_2275219952" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219952)" x1="674.9359999999999" y1="47" x2="667.8759999999999" y2="230.3"></line></g><g class=""><defs><marker id="arrow_2275219995" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275219995)" x1="173.67600000000002" y1="122.2" x2="300.75600000000003" y2="103.4"></line></g><g class=""><defs><marker id="arrow_2275220097" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220097)" x1="201.91600000000003" y1="249.1" x2="279.576" y2="225.6"></line></g><g class=""><defs><marker id="arrow_2275220200" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220200)" x1="237.216" y1="357.2" x2="547.856" y2="418.3"></line></g><g class=""><defs><marker id="arrow_2275220218" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220218)" x1="307.81600000000003" y1="291.4" x2="293.696" y2="286.7"></line></g><g class=""><defs><marker id="arrow_2275220220" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220220)" x1="237.216" y1="347.8" x2="314.87600000000003" y2="380.7"></line></g><g class=""><defs><marker id="arrow_2275220231" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220231)" x1="223.09600000000003" y1="47" x2="350.176" y2="47"></line></g><g class=""><defs><marker id="arrow_2275220254" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220254)" x1="180.73600000000002" y1="94" x2="286.636" y2="65.8"></line></g><g class=""><defs><marker id="arrow_2275220347" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220347)" x1="67.776" y1="220.9" x2="39.536" y2="197.4"></line></g><g class=""><defs><marker id="arrow_2275220361" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220361)" x1="357.236" y1="28.2" x2="378.416" y2="211.5"></line></g><g class=""><defs><marker id="arrow_2275220365" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220365)" x1="371.356" y1="65.8" x2="498.436" y2="75.2"></line></g><g class=""><defs><marker id="arrow_2275220386" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220386)" x1="392.536" y1="432.4" x2="625.516" y2="366.6"></line></g><g class=""><defs><marker id="arrow_2275220406" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220406)" x1="81.896" y1="272.6" x2="470.19599999999997" y2="136.3"></line></g><g class=""><defs><marker id="arrow_2275220426" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220426)" x1="194.85600000000002" y1="314.9" x2="223.09600000000003" y2="225.6"></line></g><g class=""><defs><marker id="arrow_2275220434" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220434)" x1="427.836" y1="51.7" x2="505.496" y2="23.5"></line></g><g class=""><defs><marker id="arrow_2275220451" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220451)" x1="477.256" y1="282" x2="230.15600000000003" y2="310.2"></line></g><g class=""><defs><marker id="arrow_2275220466" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220466)" x1="223.09600000000003" y1="244.4" x2="286.636" y2="206.8"></line></g><g class=""><defs><marker id="arrow_2275220469" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220469)" x1="307.81600000000003" y1="65.8" x2="618.456" y2="84.6"></line></g><g class=""><defs><marker id="arrow_2275220500" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220500)" x1="96.016" y1="451.2" x2="81.896" y2="460.6"></line></g><g class=""><defs><marker id="arrow_2275220518" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220518)" x1="406.656" y1="451.2" x2="498.436" y2="465.3"></line></g><g class=""><defs><marker id="arrow_2275220562" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220562)" x1="703.1759999999999" y1="145.7" x2="689.0559999999999" y2="150.4"></line></g><g class=""><defs><marker id="arrow_2275220590" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#606060"></path></marker></defs><line fill="none" stroke="#606060" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2275220590)" x1="343.116" y1="23.5" x2="604.336" y2="51.7"></line></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="208.97600000000003" y1="324.3" x2="328.996" y2="413.6"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="328.996" y1="413.6" x2="251.336" y2="305.5"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="251.336" y1="305.5" x2="300.75600000000003" y2="314.9"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="300.75600000000003" y1="314.9" x2="39.536" y2="338.4"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="39.536" y1="338.4" x2="25.416" y2="253.8"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="25.416" y1="253.8" x2="0" y2="223.25"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="131.316" y1="202.1" x2="223.09600000000003" y2="164.5"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="223.09600000000003" y1="164.5" x2="131.316" y2="253.8"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="131.316" y1="253.8" x2="110.13600000000001" y2="305.5"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="110.13600000000001" y1="305.5" x2="138.376" y2="343.1"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="138.376" y1="343.1" x2="60.715999999999994" y2="225.6"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="60.715999999999994" y1="225.6" x2="0" y2="223.25"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="39.536" y1="169.2" x2="173.67600000000002" y2="136.3"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="173.67600000000002" y1="136.3" x2="0" y2="230.3"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="194.85600000000002" y1="192.7" x2="159.556" y2="286.7"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="159.556" y1="286.7" x2="187.79600000000002" y2="282"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="187.79600000000002" y1="282" x2="180.73600000000002" y2="235"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="180.73600000000002" y1="235" x2="0" y2="235"></line></g></g><g class=""><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="46.596" y1="267.9" x2="131.316" y2="141"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="131.316" y1="141" x2="88.956" y2="141"></line></g><g><line fill="none" stroke="yellow" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="88.956" y1="141" x2="103.07600000000001" y2="188"></line></g><g><marker id="arrow_undefined" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="yellow"></path></marker><line fill="none" stroke="yellow" marker-end="url(#arrow_undefined)" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" x1="103.07600000000001" y1="188" x2="0" y2="235"></line></g></g></svg><div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 24%; left: 68%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 31%; left: 58%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 20%; left: 62%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 4%; left: 44%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 20%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 18%; left: 18%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>25</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 63%; left: 88%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 72%; left: 15%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 36%; left: 67%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 11%; left: 19%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>25</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 6%; left: 63%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 17%; left: 69%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 77%; left: 61%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 43%; left: 13%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 40%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 87%; left: 45%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 79%; left: 24%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 56%; left: 6%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 51%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 69%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 50%; left: 92%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 11%; left: 75%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 2%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 20%; left: 62%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 72%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 17%; left: 59%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 23%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 43%; left: 18%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 11%; left: 71%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 4%; left: 72%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 45%; left: 56%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 41%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 33%; left: 47%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 7%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 36%; left: 5%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 91%; left: 97%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 87%; left: 63%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 85%; left: 54%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 12%; left: 42%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 3%; left: 67%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 11%; left: 64%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 37%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 41%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 53%; left: 12%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 81%; left: 65%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 85%; left: 7%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 69%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 61%; left: 36%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 17%; left: 24%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 12%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 10%; left: 60%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 73%; left: 79%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 75%; left: 92%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 28%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 24%; left: 30%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 32%; left: 24%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 14%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 48%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 4%; left: 61%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 80%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 41%; left: 92%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 76%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 32%; left: 48%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 10%; left: 95%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 3%; left: 61%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 55%; left: 93%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 51%; left: 98%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 26%; left: 24%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 19%; left: 86%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 70%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 57%; left: 6%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 43%; left: 4%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>25</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 87%; left: 60%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 58%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 35%; left: 14%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 79%; left: 48%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 53%; left: 28%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 84%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 22%; left: 30%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 13%; left: 63%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 8%; left: 59%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 19%; left: 62%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 100%; left: 100%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 78%; left: 44%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 43%; left: 72%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 76%; left: 33%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 31%; left: 64%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 62%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 74%; left: 33%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 10%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 17%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 20%; left: 25%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>25</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 65%; left: 91%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 71%; left: 44%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 97%; left: 90%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 52%; left: 47%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 47%; left: 9%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 21%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 52%; left: 69%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 6%; left: 50%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 14%; left: 52%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 92%; left: 55%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 58%; left: 11%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 16%; left: 78%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 66%; left: 26%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 67%; left: 27%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 11%; left: 60%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 8%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 60%; left: 67%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 52%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 14%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 5%; left: 62%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 96%; left: 13%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 96%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 90%; left: 20%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 29%; left: 97%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>29</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 17%; left: 11%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 55%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 55%; left: 34%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 8%; left: 75%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 31%; left: 99%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>29</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 13%; left: 16%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>25</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 10%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__interception___1zT9-" style="top: 5%; left: 48%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 41%; left: 90%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__ground___2SzSF" style="top: 7%; left: 81%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div></div></div>'

# %%
arrows = fullHtml.find("teamstats__Arrows-module__arrows")
dots =fullHtml.find("teamstats__Dots-module__dots")
arrowsData = fullHtml[arrows:dots]
dotsData = fullHtml[dots:]

labels = dotsData.split('<div class="teamstats__Dots-module__dot')
positions = []
for label in labels[1:]:
    left = label.find("left:")
    left = int(label[left+6:left+8].replace("%",""))/100*120
    top = label.find("top:")
    top = int(label[top+5:top+7].replace("%",""))/100*80
    positions.append([left,top])
positions = pd.DataFrame(positions,columns=["x1","y1"])
arrowLabels = arrowsData.split('<g class=""><defs>')
arrows = []
for label in arrowLabels[1:]:
    x1 = label.find("x1")
    y1 = label.find("y1")
    x2 = label.find("x2")
    y2 = label.find("y2")
    coords = label.split("=")[17:]
    coordinates = []
    for i in range(4):
        if i%2==0:
            divided = 710.2359999999999/120
        else:
            divided = 470/80
        val = coords[i]
        val = float(val.split('"')[1])/divided
        coordinates.append(val)
    arrows.append(coordinates)
arrows = pd.DataFrame(arrows,columns=["x1",'y1',"x2","y2"])
pos = positions.to_numpy()
arr = arrows.get(["x2","y2"]).to_numpy()
merged = np.concatenate((pos,arr))
merged = pd.DataFrame(merged,columns=['x','y'])
# Out:
# Text(0.5, 1.0, 'Duke Losses')

# %%
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=merged.get("x"),y=merged.get("y"),fill = True,shade_lowest = False,alpha = .5,n_levels = 20,cmap = "magma")
plt.title("UCSD Losses")
# Out:
# Text(0.5, 1.0, 'UCSD Losses')

# %%
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=arrows.get("x1"),y=arrows.get("y1"),fill = True,shade_lowest = False,alpha = .5,n_levels = 20,cmap = "magma")
plt.title("UCSD Misplayed Passes Starting")
plt.show()
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=arrows.get("x2"),y=arrows.get("y2"),fill = True,shade_lowest = False,alpha = .5,n_levels = 20,cmap = "magma")
plt.title("UCSD Misplayed Passes Ending")
plt.show()
