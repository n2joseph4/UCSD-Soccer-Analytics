# %%
import pandas as pd
from mplsoccer import Pitch
from mplsoccer import VerticalPitch
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
htmlPlayers = {"Nolan":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387917823" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917823)" stroke-opacity="1" x1="42" y1="122.76" x2="63" y2="80.91"></line></g><g><defs><marker id="arrow_2387917842" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917842)" stroke-opacity="1" x1="96.6" y1="103.23" x2="298.2" y2="131.13"></line></g><g><defs><marker id="arrow_2387917879" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917879)" stroke-opacity="1" x1="42" y1="161.82" x2="54.6" y2="97.65"></line></g><g><defs><marker id="arrow_2387918049" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918049)" stroke-opacity="1" x1="33.6" y1="111.6" x2="138.6" y2="239.94"></line></g><g><defs><marker id="arrow_2387918139" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918139)" stroke-opacity="1" x1="25.2" y1="192.51" x2="172.2" y2="239.94"></line></g><g><defs><marker id="arrow_2387918505" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918505)" stroke-opacity="1" x1="8.4" y1="122.76" x2="79.8" y2="11.16"></line></g><g><defs><marker id="arrow_2387918579" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918579)" stroke-opacity="1" x1="46.2" y1="147.87" x2="113.4" y2="172.98"></line></g><g><defs><marker id="arrow_2387918602" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918602)" stroke-opacity="1" x1="92.4" y1="175.77" x2="302.4" y2="242.73"></line></g><g><defs><marker id="arrow_2387918634" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918634)" stroke-dasharray="6 4" stroke-opacity="1" x1="54.6" y1="161.82" x2="277.2" y2="147.87"></line></g><g><defs><marker id="arrow_2387918690" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918690)" stroke-opacity="1" x1="50.4" y1="108.81" x2="155.4" y2="97.65"></line></g><g><defs><marker id="arrow_2387918728" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918728)" stroke-opacity="1" x1="92.4" y1="161.82" x2="163.8" y2="172.98"></line></g><g><defs><marker id="arrow_2387918733" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918733)" stroke-opacity="1" x1="46.2" y1="94.86" x2="100.8" y2="103.23"></line></g></svg>',"Evan":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387917815" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917815)" stroke-opacity="1" x1="100.8" y1="122.76" x2="151.2" y2="231.57"></line></g><g><defs><marker id="arrow_2387917820" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917820)" stroke-opacity="1" x1="243.6" y1="239.94" x2="306.6" y2="253.89"></line></g><g><defs><marker id="arrow_2387917833" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917833)" stroke-opacity="1" x1="180.6" y1="206.46" x2="319.2" y2="225.99"></line></g><g><defs><marker id="arrow_2387917875" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917875)" stroke-opacity="1" x1="201.6" y1="156.24" x2="239.4" y2="248.31"></line></g><g><defs><marker id="arrow_2387917882" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917882)" stroke-opacity="1" x1="100.8" y1="203.67" x2="197.4" y2="259.47"></line></g><g><defs><marker id="arrow_2387917919" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917919)" stroke-opacity="1" x1="159.6" y1="239.94" x2="193.2" y2="256.68"></line></g><g><defs><marker id="arrow_2387917928" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917928)" stroke-dasharray="6 4" stroke-opacity="1" x1="159.6" y1="212.04" x2="268.8" y2="228.78"></line></g><g><defs><marker id="arrow_2387918141" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918141)" stroke-opacity="1" x1="134.4" y1="214.83" x2="189" y2="253.89"></line></g><g><defs><marker id="arrow_2387918156" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918156)" stroke-dasharray="6 4" stroke-opacity="1" x1="142.8" y1="223.2" x2="281.4" y2="234.36"></line></g><g><defs><marker id="arrow_2387918194" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918194)" stroke-opacity="1" x1="54.6" y1="172.98" x2="138.6" y2="153.45"></line></g><g><defs><marker id="arrow_2387918210" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918210)" stroke-opacity="1" x1="50.4" y1="195.3" x2="54.6" y2="245.52"></line></g><g><defs><marker id="arrow_2387918223" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918223)" stroke-opacity="1" x1="155.4" y1="200.88" x2="268.8" y2="192.51"></line></g><g><defs><marker id="arrow_2387918365" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918365)" stroke-opacity="1" x1="117.6" y1="170.19" x2="239.4" y2="30.69"></line></g><g><defs><marker id="arrow_2387918416" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918416)" stroke-opacity="1" x1="121.8" y1="159.03" x2="268.8" y2="41.85"></line></g><g><defs><marker id="arrow_2387918433" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918433)" stroke-dasharray="6 4" stroke-opacity="1" x1="84" y1="142.29" x2="79.8" y2="100.44"></line></g><g><defs><marker id="arrow_2387918436" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918436)" stroke-opacity="1" x1="113.4" y1="156.24" x2="147" y2="30.69"></line></g><g><defs><marker id="arrow_2387918544" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918544)" stroke-opacity="1" x1="109.2" y1="192.51" x2="151.2" y2="237.15"></line></g><g><defs><marker id="arrow_2387918559" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918559)" stroke-opacity="1" x1="226.8" y1="128.34" x2="155.4" y2="55.8"></line></g><g><defs><marker id="arrow_2387918604" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918604)" stroke-opacity="1" x1="172.2" y1="237.15" x2="176.4" y2="78.12"></line></g><g><defs><marker id="arrow_2387918654" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918654)" stroke-opacity="1" x1="88.2" y1="198.09" x2="84" y2="89.28"></line></g><g><defs><marker id="arrow_2387918688" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918688)" stroke-dasharray="6 4" stroke-opacity="1" x1="130.2" y1="133.92" x2="180.6" y2="139.5"></line></g><g><defs><marker id="arrow_2387918692" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918692)" stroke-dasharray="6 4" stroke-opacity="1" x1="46.2" y1="239.94" x2="294" y2="172.98"></line></g><g><defs><marker id="arrow_2387918790" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918790)" stroke-opacity="1" x1="109.2" y1="170.19" x2="159.6" y2="72.54"></line></g><g><defs><marker id="arrow_2387918721" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918721)" stroke-opacity="1" x1="180.6" y1="203.67" x2="218.4" y2="94.86"></line></g><g><defs><marker id="arrow_2387918729" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918729)" stroke-opacity="1" x1="163.8" y1="172.98" x2="168" y2="92.07"></line></g><g><defs><marker id="arrow_2387918738" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918738)" stroke-opacity="1" x1="105" y1="217.62" x2="231" y2="178.56"></line></g><g><defs><marker id="arrow_2387918747" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918747)" stroke-opacity="1" x1="134.4" y1="189.72" x2="184.8" y2="175.77"></line></g><g><defs><marker id="arrow_2387918751" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918751)" stroke-opacity="1" x1="117.6" y1="195.3" x2="126" y2="83.7"></line></g><g><defs><marker id="arrow_2387918754" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918754)" stroke-opacity="1" x1="130.2" y1="198.09" x2="260.4" y2="167.4"></line></g><g><defs><marker id="arrow_2387918760" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918760)" stroke-dasharray="6 4" stroke-opacity="1" x1="33.6" y1="175.77" x2="42" y2="181.35"></line></g><g><defs><marker id="arrow_2387918774" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918774)" stroke-opacity="1" x1="239.4" y1="175.77" x2="247.8" y2="69.75"></line></g></svg>',"Adam":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387917825" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917825)" stroke-opacity="1" x1="67.2" y1="44.64" x2="155.4" y2="103.23"></line></g><g><defs><marker id="arrow_2387917880" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917880)" stroke-opacity="1" x1="54.6" y1="97.65" x2="105" y2="142.29"></line></g><g><defs><marker id="arrow_2387917926" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917926)" stroke-opacity="1" x1="226.8" y1="89.28" x2="243.6" y2="145.08"></line></g><g><defs><marker id="arrow_2387917940" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917940)" stroke-opacity="1" x1="75.6" y1="53.01" x2="247.8" y2="83.7"></line></g><g><defs><marker id="arrow_2387917949" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917949)" stroke-opacity="1" x1="58.8" y1="19.53" x2="113.4" y2="16.74"></line></g><g><defs><marker id="arrow_2387917993" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917993)" stroke-opacity="1" x1="54.6" y1="50.22" x2="134.4" y2="94.86"></line></g><g><defs><marker id="arrow_2387918009" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918009)" stroke-opacity="1" x1="151.2" y1="66.96" x2="168" y2="189.72"></line></g><g><defs><marker id="arrow_2387918054" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918054)" stroke-dasharray="6 4" stroke-opacity="1" x1="109.2" y1="106.02" x2="155.4" y2="108.81"></line></g><g><defs><marker id="arrow_2387918133" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918133)" stroke-dasharray="6 4" stroke-opacity="1" x1="172.2" y1="72.54" x2="357" y2="66.96"></line></g><g><defs><marker id="arrow_2387918138" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918138)" stroke-opacity="1" x1="46.2" y1="89.28" x2="25.2" y2="192.51"></line></g><g><defs><marker id="arrow_2387918504" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918504)" stroke-opacity="1" x1="100.8" y1="50.22" x2="8.4" y2="122.76"></line></g><g><defs><marker id="arrow_2387918521" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918521)" stroke-opacity="1" x1="163.8" y1="86.49" x2="273" y2="131.13"></line></g><g><defs><marker id="arrow_2387918550" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918550)" stroke-opacity="1" x1="231" y1="75.33" x2="252" y2="27.9"></line></g><g><defs><marker id="arrow_2387918554" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918554)" stroke-opacity="1" x1="226.8" y1="41.85" x2="260.4" y2="92.07"></line></g><g><defs><marker id="arrow_2387918560" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918560)" stroke-opacity="1" x1="155.4" y1="55.8" x2="252" y2="19.53"></line></g><g><defs><marker id="arrow_2387918587" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918587)" stroke-opacity="1" x1="235.2" y1="36.27" x2="289.8" y2="69.75"></line></g><g><defs><marker id="arrow_2387918606" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918606)" stroke-opacity="1" x1="176.4" y1="78.12" x2="222.6" y2="19.53"></line></g><g><defs><marker id="arrow_2387918631" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918631)" stroke-dasharray="6 4" stroke-opacity="1" x1="113.4" y1="36.27" x2="172.2" y2="66.96"></line></g><g><defs><marker id="arrow_2387918648" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918648)" stroke-opacity="1" x1="222.6" y1="55.8" x2="289.8" y2="69.75"></line></g><g><defs><marker id="arrow_2387918655" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918655)" stroke-opacity="1" x1="84" y1="89.28" x2="113.4" y2="139.5"></line></g><g><defs><marker id="arrow_2387918707" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918707)" stroke-opacity="1" x1="159.6" y1="72.54" x2="247.8" y2="156.24"></line></g><g><defs><marker id="arrow_2387918712" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918712)" stroke-opacity="1" x1="247.8" y1="106.02" x2="239.4" y2="209.25"></line></g><g><defs><marker id="arrow_2387918714" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918714)" stroke-opacity="1" x1="260.4" y1="203.67" x2="285.6" y2="237.15"></line></g><g><defs><marker id="arrow_2387918718" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918718)" stroke-opacity="1" x1="260.4" y1="206.46" x2="298.2" y2="256.68"></line></g><g><defs><marker id="arrow_2387918730" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918730)" stroke-opacity="1" x1="168" y1="92.07" x2="226.8" y2="142.29"></line></g><g><defs><marker id="arrow_2387918741" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918741)" stroke-opacity="1" x1="151.2" y1="41.85" x2="327.6" y2="94.86"></line></g><g><defs><marker id="arrow_2387918750" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918750)" stroke-dasharray="6 4" stroke-opacity="1" x1="134.4" y1="64.17" x2="252" y2="131.13"></line></g><g><defs><marker id="arrow_2387918752" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918752)" stroke-opacity="1" x1="126" y1="83.7" x2="193.2" y2="111.6"></line></g><g><defs><marker id="arrow_2387918757" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918757)" stroke-opacity="1" x1="260.4" y1="61.38" x2="298.2" y2="47.43"></line></g><g><defs><marker id="arrow_2387918762" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918762)" stroke-opacity="1" x1="79.8" y1="39.06" x2="163.8" y2="50.22"></line></g><g><defs><marker id="arrow_2387918775" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918775)" stroke-opacity="1" x1="247.8" y1="69.75" x2="298.2" y2="78.12"></line></g><g><defs><marker id="arrow_2387918780" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918780)" stroke-opacity="1" x1="50.4" y1="78.12" x2="117.6" y2="69.75"></line></g><g><defs><marker id="arrow_2387918782" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918782)" stroke-opacity="1" x1="67.2" y1="39.06" x2="109.2" y2="50.22"></line></g><g><defs><marker id="arrow_2387918784" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918784)" stroke-dasharray="6 4" stroke-opacity="1" x1="113.4" y1="66.96" x2="113.4" y2="125.55"></line></g></svg>',"Cole":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387917819" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917819)" stroke-opacity="1" x1="277.2" y1="259.47" x2="243.6" y2="239.94"></line></g><g><defs><marker id="arrow_2387917830" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917830)" stroke-opacity="1" x1="268.8" y1="223.2" x2="327.6" y2="259.47"></line></g><g><defs><marker id="arrow_2387917832" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917832)" stroke-opacity="1" x1="285.6" y1="251.1" x2="180.6" y2="206.46"></line></g><g><defs><marker id="arrow_2387917835" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917835)" stroke-opacity="1" x1="344.4" y1="259.47" x2="281.4" y2="234.36"></line></g><g><defs><marker id="arrow_2387917838" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917838)" stroke-dasharray="6 4" stroke-opacity="1" x1="394.8" y1="259.47" x2="394.8" y2="245.52"></line></g><g><defs><marker id="arrow_2387917853" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917853)" stroke-dasharray="6 4" stroke-opacity="1" x1="336" y1="203.67" x2="386.4" y2="159.03"></line></g><g><defs><marker id="arrow_2387917872" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917872)" stroke-dasharray="6 4" stroke-opacity="1" x1="201.6" y1="265.05" x2="382.2" y2="33.48"></line></g><g><defs><marker id="arrow_2387917914" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917914)" stroke-opacity="1" x1="163.8" y1="265.05" x2="105" y2="239.94"></line></g><g><defs><marker id="arrow_2387917924" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917924)" stroke-opacity="1" x1="226.8" y1="231.57" x2="239.4" y2="172.98"></line></g><g><defs><marker id="arrow_2387918066" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918066)" stroke-dasharray="6 4" stroke-opacity="1" x1="344.4" y1="220.41" x2="306.6" y2="159.03"></line></g><g><defs><marker id="arrow_2387918112" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918112)" stroke-dasharray="6 4" stroke-opacity="1" x1="399" y1="195.3" x2="369.6" y2="189.72"></line></g><g><defs><marker id="arrow_2387918115" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918115)" stroke-dasharray="6 4" stroke-opacity="1" x1="373.8" y1="242.73" x2="394.8" y2="164.61"></line></g><g><defs><marker id="arrow_2387918646" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918646)" stroke-opacity="1" x1="268.8" y1="192.51" x2="226.8" y2="131.13"></line></g><g><defs><marker id="arrow_2387918671" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918671)" stroke-opacity="1" x1="373.8" y1="251.1" x2="361.2" y2="114.39"></line></g><g><defs><marker id="arrow_2387918719" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918719)" stroke-opacity="1" x1="298.2" y1="256.68" x2="247.8" y2="161.82"></line></g></svg>',"Woody":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387918196" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918196)" stroke-dasharray="6 4" stroke-opacity="1" x1="109.2" y1="156.24" x2="201.6" y2="279"></line></g><g><defs><marker id="arrow_2387918278" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918278)" stroke-opacity="1" x1="184.8" y1="80.91" x2="243.6" y2="147.87"></line></g><g><defs><marker id="arrow_2387918761" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918761)" stroke-opacity="1" x1="105" y1="72.54" x2="79.8" y2="39.06"></line></g><g><defs><marker id="arrow_2387918781" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918781)" stroke-opacity="1" x1="117.6" y1="69.75" x2="67.2" y2="39.06"></line></g></svg>',"Quinn":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387917808" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917808)" stroke-opacity="1" x1="96.6" y1="153.45" x2="58.8" y2="203.67"></line></g><g><defs><marker id="arrow_2387917811" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917811)" stroke-opacity="1" x1="54.6" y1="245.52" x2="117.6" y2="189.72"></line></g><g><defs><marker id="arrow_2387917826" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917826)" stroke-opacity="1" x1="155.4" y1="103.23" x2="147" y2="64.17"></line></g><g><defs><marker id="arrow_2387917837" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917837)" stroke-opacity="1" x1="319.2" y1="239.94" x2="394.8" y2="259.47"></line></g><g><defs><marker id="arrow_2387917876" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917876)" stroke-dasharray="6 4" stroke-opacity="1" x1="264.6" y1="212.04" x2="239.4" y2="198.09"></line></g><g><defs><marker id="arrow_2387917989" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917989)" stroke-dasharray="6 4" stroke-opacity="1" x1="193.2" y1="133.92" x2="289.8" y2="64.17"></line></g><g><defs><marker id="arrow_2387917995" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917995)" stroke-opacity="1" x1="155.4" y1="172.98" x2="163.8" y2="248.31"></line></g><g><defs><marker id="arrow_2387917998" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917998)" stroke-opacity="1" x1="315" y1="97.65" x2="306.6" y2="75.33"></line></g><g><defs><marker id="arrow_2387918004" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918004)" stroke-opacity="1" x1="382.2" y1="25.11" x2="306.6" y2="44.64"></line></g><g><defs><marker id="arrow_2387918159" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918159)" stroke-opacity="1" x1="294" y1="248.31" x2="336" y2="270.63"></line></g><g><defs><marker id="arrow_2387918160" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918160)" stroke-opacity="1" x1="315" y1="239.94" x2="386.4" y2="259.47"></line></g><g><defs><marker id="arrow_2387918168" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918168)" stroke-opacity="1" x1="54.6" y1="200.88" x2="134.4" y2="248.31"></line></g><g><defs><marker id="arrow_2387918175" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918175)" stroke-dasharray="6 4" stroke-opacity="1" x1="176.4" y1="265.05" x2="399" y2="245.52"></line></g><g><defs><marker id="arrow_2387918388" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918388)" stroke-opacity="1" x1="46.2" y1="122.76" x2="71.4" y2="136.71"></line></g><g><defs><marker id="arrow_2387918440" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918440)" stroke-opacity="1" x1="138.6" y1="94.86" x2="256.2" y2="125.55"></line></g><g><defs><marker id="arrow_2387918485" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918485)" stroke-opacity="1" x1="256.2" y1="53.01" x2="273" y2="25.11"></line></g><g><defs><marker id="arrow_2387918543" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918543)" stroke-opacity="1" x1="109.2" y1="55.8" x2="109.2" y2="192.51"></line></g><g><defs><marker id="arrow_2387918555" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918555)" stroke-opacity="1" x1="277.2" y1="50.22" x2="256.2" y2="114.39"></line></g><g><defs><marker id="arrow_2387918558" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918558)" stroke-dasharray="6 4" stroke-opacity="1" x1="260.4" y1="64.17" x2="327.6" y2="47.43"></line></g><g><defs><marker id="arrow_2387918565" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918565)" stroke-opacity="1" x1="252" y1="19.53" x2="336" y2="92.07"></line></g><g><defs><marker id="arrow_2387918588" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918588)" stroke-dasharray="6 4" stroke-opacity="1" x1="289.8" y1="69.75" x2="348.6" y2="86.49"></line></g><g><defs><marker id="arrow_2387918590" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918590)" stroke-opacity="1" x1="298.2" y1="50.22" x2="378" y2="61.38"></line></g><g><defs><marker id="arrow_2387918618" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918618)" stroke-dasharray="6 4" stroke-opacity="1" x1="378" y1="19.53" x2="281.4" y2="39.06"></line></g><g><defs><marker id="arrow_2387918647" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918647)" stroke-opacity="1" x1="226.8" y1="131.13" x2="222.6" y2="55.8"></line></g><g><defs><marker id="arrow_2387918650" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918650)" stroke-opacity="1" x1="252" y1="80.91" x2="243.6" y2="44.64"></line></g><g><defs><marker id="arrow_2387918691" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918691)" stroke-dasharray="6 4" stroke-opacity="1" x1="126" y1="117.18" x2="243.6" y2="279"></line></g><g><defs><marker id="arrow_2387918710" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918710)" stroke-opacity="1" x1="256.2" y1="86.49" x2="247.8" y2="106.02"></line></g><g><defs><marker id="arrow_2387918720" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918720)" stroke-opacity="1" x1="247.8" y1="161.82" x2="180.6" y2="203.67"></line></g><g><defs><marker id="arrow_2387918746" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918746)" stroke-opacity="1" x1="134.4" y1="69.75" x2="134.4" y2="189.72"></line></g></svg>',"Val":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387917827" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917827)" stroke-dasharray="6 4" stroke-opacity="1" x1="147" y1="64.17" x2="180.6" y2="50.22"></line></g><g><defs><marker id="arrow_2387917828" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917828)" stroke-dasharray="6 4" stroke-opacity="1" x1="189" y1="94.86" x2="331.8" y2="78.12"></line></g><g><defs><marker id="arrow_2387917829" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917829)" stroke-opacity="1" x1="256.2" y1="75.33" x2="268.8" y2="223.2"></line></g><g><defs><marker id="arrow_2387917839" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917839)" stroke-opacity="1" x1="184.8" y1="44.64" x2="96.6" y2="103.23"></line></g><g><defs><marker id="arrow_2387917874" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917874)" stroke-opacity="1" x1="294" y1="55.8" x2="201.6" y2="156.24"></line></g><g><defs><marker id="arrow_2387917950" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917950)" stroke-opacity="1" x1="113.4" y1="16.74" x2="147" y2="75.33"></line></g><g><defs><marker id="arrow_2387917987" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917987)" stroke-opacity="1" x1="117.6" y1="75.33" x2="155.4" y2="175.77"></line></g><g><defs><marker id="arrow_2387917999" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917999)" stroke-opacity="1" x1="306.6" y1="75.33" x2="273" y2="119.97"></line></g><g><defs><marker id="arrow_2387918006" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918006)" stroke-opacity="1" x1="306.6" y1="44.64" x2="348.6" y2="19.53"></line></g><g><defs><marker id="arrow_2387918035" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918035)" stroke-dasharray="6 4" stroke-opacity="1" x1="315" y1="22.32" x2="281.4" y2="39.06"></line></g><g><defs><marker id="arrow_2387918422" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918422)" stroke-opacity="1" x1="315" y1="27.9" x2="294" y2="66.96"></line></g><g><defs><marker id="arrow_2387918425" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918425)" stroke-dasharray="6 4" stroke-opacity="1" x1="390.6" y1="39.06" x2="390.6" y2="47.43"></line></g><g><defs><marker id="arrow_2387918487" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918487)" stroke-opacity="1" x1="273" y1="25.11" x2="281.4" y2="55.8"></line></g><g><defs><marker id="arrow_2387918491" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918491)" stroke-opacity="1" x1="315" y1="25.11" x2="369.6" y2="64.17"></line></g><g><defs><marker id="arrow_2387918542" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918542)" stroke-opacity="1" x1="67.2" y1="19.53" x2="109.2" y2="55.8"></line></g><g><defs><marker id="arrow_2387918552" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918552)" stroke-opacity="1" x1="306.6" y1="22.32" x2="226.8" y2="41.85"></line></g><g><defs><marker id="arrow_2387918568" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918568)" stroke-opacity="1" x1="327.6" y1="25.11" x2="373.8" y2="159.03"></line></g><g><defs><marker id="arrow_2387918586" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918586)" stroke-opacity="1" x1="231" y1="36.27" x2="294" y2="33.48"></line></g><g><defs><marker id="arrow_2387918593" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918593)" stroke-dasharray="6 4" stroke-opacity="1" x1="394.8" y1="69.75" x2="394.8" y2="75.33"></line></g><g><defs><marker id="arrow_2387918649" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918649)" stroke-opacity="1" x1="289.8" y1="69.75" x2="252" y2="80.91"></line></g><g><defs><marker id="arrow_2387918739" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918739)" stroke-dasharray="6 4" stroke-opacity="1" x1="231" y1="178.56" x2="273" y2="161.82"></line></g></svg>',"James":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387917809" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917809)" stroke-opacity="1" x1="58.8" y1="203.67" x2="134.4" y2="231.57"></line></g><g><defs><marker id="arrow_2387917816" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917816)" stroke-dasharray="6 4" stroke-opacity="1" x1="151.2" y1="231.57" x2="348.6" y2="206.46"></line></g><g><defs><marker id="arrow_2387917831" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917831)" stroke-opacity="1" x1="327.6" y1="259.47" x2="285.6" y2="251.1"></line></g><g><defs><marker id="arrow_2387917869" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917869)" stroke-opacity="1" x1="67.2" y1="242.73" x2="109.2" y2="200.88"></line></g><g><defs><marker id="arrow_2387917883" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917883)" stroke-dasharray="6 4" stroke-opacity="1" x1="197.4" y1="259.47" x2="378" y2="145.08"></line></g><g><defs><marker id="arrow_2387917959" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917959)" stroke-opacity="1" x1="235.2" y1="217.62" x2="235.2" y2="181.35"></line></g><g><defs><marker id="arrow_2387917996" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917996)" stroke-opacity="1" x1="163.8" y1="248.31" x2="323.4" y2="242.73"></line></g><g><defs><marker id="arrow_2387918002" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918002)" stroke-opacity="1" x1="256.2" y1="195.3" x2="382.2" y2="25.11"></line></g><g><defs><marker id="arrow_2387918010" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918010)" stroke-opacity="1" x1="168" y1="189.72" x2="193.2" y2="139.5"></line></g><g><defs><marker id="arrow_2387918050" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918050)" stroke-opacity="1" x1="138.6" y1="239.94" x2="264.6" y2="231.57"></line></g><g><defs><marker id="arrow_2387918114" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918114)" stroke-opacity="1" x1="310.8" y1="237.15" x2="373.8" y2="242.73"></line></g><g><defs><marker id="arrow_2387918140" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918140)" stroke-opacity="1" x1="168" y1="220.41" x2="134.4" y2="214.83"></line></g><g><defs><marker id="arrow_2387918155" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918155)" stroke-opacity="1" x1="189" y1="267.84" x2="142.8" y2="223.2"></line></g><g><defs><marker id="arrow_2387918169" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918169)" stroke-opacity="1" x1="134.4" y1="248.31" x2="130.2" y2="231.57"></line></g><g><defs><marker id="arrow_2387918184" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918184)" stroke-dasharray="6 4" stroke-opacity="1" x1="147" y1="245.52" x2="147" y2="189.72"></line></g><g><defs><marker id="arrow_2387918211" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918211)" stroke-opacity="1" x1="54.6" y1="245.52" x2="163.8" y2="231.57"></line></g><g><defs><marker id="arrow_2387918222" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918222)" stroke-opacity="1" x1="184.8" y1="256.68" x2="155.4" y2="200.88"></line></g><g><defs><marker id="arrow_2387918242" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918242)" stroke-opacity="1" x1="180.6" y1="198.09" x2="319.2" y2="228.78"></line></g><g><defs><marker id="arrow_2387918371" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918371)" stroke-opacity="1" x1="285.6" y1="231.57" x2="273" y2="189.72"></line></g><g><defs><marker id="arrow_2387918445" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918445)" stroke-opacity="1" x1="163.8" y1="237.15" x2="252" y2="212.04"></line></g><g><defs><marker id="arrow_2387918450" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918450)" stroke-dasharray="6 4" stroke-opacity="1" x1="168" y1="253.89" x2="420" y2="206.46"></line></g><g><defs><marker id="arrow_2387918499" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918499)" stroke-opacity="1" x1="264.6" y1="214.83" x2="327.6" y2="225.99"></line></g><g><defs><marker id="arrow_2387918508" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918508)" stroke-opacity="1" x1="96.6" y1="200.88" x2="197.4" y2="214.83"></line></g><g><defs><marker id="arrow_2387918515" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918515)" stroke-dasharray="6 4" stroke-opacity="1" x1="117.6" y1="242.73" x2="285.6" y2="245.52"></line></g><g><defs><marker id="arrow_2387918517" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918517)" stroke-opacity="1" x1="172.2" y1="265.05" x2="117.6" y2="178.56"></line></g><g><defs><marker id="arrow_2387918547" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918547)" stroke-opacity="1" x1="243.6" y1="231.57" x2="184.8" y2="175.77"></line></g><g><defs><marker id="arrow_2387918573" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918573)" stroke-opacity="1" x1="126" y1="220.41" x2="184.8" y2="228.78"></line></g><g><defs><marker id="arrow_2387918603" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918603)" stroke-opacity="1" x1="239.4" y1="248.31" x2="172.2" y2="237.15"></line></g><g><defs><marker id="arrow_2387918658" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918658)" stroke-opacity="1" x1="134.4" y1="225.99" x2="168" y2="217.62"></line></g><g><defs><marker id="arrow_2387918713" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918713)" stroke-opacity="1" x1="239.4" y1="209.25" x2="260.4" y2="203.67"></line></g><g><defs><marker id="arrow_2387918732" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918732)" stroke-dasharray="6 4" stroke-opacity="1" x1="331.8" y1="251.1" x2="373.8" y2="64.17"></line></g><g><defs><marker id="arrow_2387918736" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918736)" stroke-opacity="1" x1="117.6" y1="259.47" x2="134.4" y2="189.72"></line></g><g><defs><marker id="arrow_2387918742" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918742)" stroke-dasharray="6 4" stroke-opacity="1" x1="42" y1="239.94" x2="67.2" y2="248.31"></line></g></svg>',"Connor":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387918157" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918157)" stroke-opacity="1" x1="327.6" y1="262.26" x2="315" y2="245.52"></line></g><g><defs><marker id="arrow_2387918158" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918158)" stroke-opacity="1" x1="336" y1="270.63" x2="315" y2="239.94"></line></g><g><defs><marker id="arrow_2387918171" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918171)" stroke-opacity="1" x1="172.2" y1="200.88" x2="147" y2="200.88"></line></g><g><defs><marker id="arrow_2387918181" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918181)" stroke-opacity="1" x1="193.2" y1="242.73" x2="231" y2="259.47"></line></g><g><defs><marker id="arrow_2387918214" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918214)" stroke-opacity="1" x1="302.4" y1="267.84" x2="298.2" y2="228.78"></line></g><g><defs><marker id="arrow_2387918215" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918215)" stroke-dasharray="6 4" stroke-opacity="1" x1="323.4" y1="267.84" x2="273" y2="200.88"></line></g><g><defs><marker id="arrow_2387918221" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918221)" stroke-opacity="1" x1="243.6" y1="231.57" x2="184.8" y2="256.68"></line></g><g><defs><marker id="arrow_2387918240" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918240)" stroke-dasharray="6 4" stroke-opacity="1" x1="231" y1="164.61" x2="189" y2="181.35"></line></g><g><defs><marker id="arrow_2387918280" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918280)" stroke-dasharray="6 4" stroke-opacity="1" x1="285.6" y1="206.46" x2="323.4" y2="206.46"></line></g><g><defs><marker id="arrow_2387918387" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918387)" stroke-dasharray="6 4" stroke-opacity="1" x1="222.6" y1="153.45" x2="159.6" y2="111.6"></line></g><g><defs><marker id="arrow_2387918498" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918498)" stroke-opacity="1" x1="315" y1="150.66" x2="264.6" y2="214.83"></line></g><g><defs><marker id="arrow_2387918574" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918574)" stroke-opacity="1" x1="184.8" y1="228.78" x2="168" y2="195.3"></line></g></svg>',"Carter":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387917814" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917814)" stroke-opacity="1" x1="105" y1="33.48" x2="100.8" y2="122.76"></line></g><g><defs><marker id="arrow_2387917878" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917878)" stroke-opacity="1" x1="189" y1="39.06" x2="331.8" y2="53.01"></line></g><g><defs><marker id="arrow_2387917955" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917955)" stroke-opacity="1" x1="239.4" y1="55.8" x2="302.4" y2="58.59"></line></g><g><defs><marker id="arrow_2387917969" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917969)" stroke-dasharray="6 4" stroke-opacity="1" x1="155.4" y1="36.27" x2="252" y2="94.86"></line></g><g><defs><marker id="arrow_2387918043" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918043)" stroke-dasharray="6 4" stroke-opacity="1" x1="58.8" y1="103.23" x2="189" y2="145.08"></line></g><g><defs><marker id="arrow_2387918132" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918132)" stroke-opacity="1" x1="58.8" y1="111.6" x2="134.4" y2="181.35"></line></g><g><defs><marker id="arrow_2387918137" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918137)" stroke-opacity="1" x1="214.2" y1="55.8" x2="218.4" y2="44.64"></line></g><g><defs><marker id="arrow_2387918258" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918258)" stroke-opacity="1" x1="84" y1="27.9" x2="109.2" y2="22.32"></line></g><g><defs><marker id="arrow_2387918268" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918268)" stroke-dasharray="6 4" stroke-opacity="1" x1="46.2" y1="53.01" x2="168" y2="58.59"></line></g><g><defs><marker id="arrow_2387918275" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918275)" stroke-opacity="1" x1="113.4" y1="41.85" x2="142.8" y2="75.33"></line></g><g><defs><marker id="arrow_2387918367" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918367)" stroke-opacity="1" x1="239.4" y1="30.69" x2="268.8" y2="111.6"></line></g><g><defs><marker id="arrow_2387918377" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918377)" stroke-opacity="1" x1="37.8" y1="47.43" x2="130.2" y2="66.96"></line></g><g><defs><marker id="arrow_2387918421" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918421)" stroke-opacity="1" x1="256.2" y1="22.32" x2="315" y2="27.9"></line></g><g><defs><marker id="arrow_2387918437" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918437)" stroke-opacity="1" x1="147" y1="30.69" x2="252" y2="41.85"></line></g><g><defs><marker id="arrow_2387918474" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918474)" stroke-opacity="1" x1="243.6" y1="30.69" x2="235.2" y2="86.49"></line></g><g><defs><marker id="arrow_2387918525" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918525)" stroke-opacity="1" x1="121.8" y1="36.27" x2="168" y2="66.96"></line></g><g><defs><marker id="arrow_2387918534" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918534)" stroke-dasharray="6 4" stroke-opacity="1" x1="29.4" y1="69.75" x2="163.8" y2="47.43"></line></g><g><defs><marker id="arrow_2387918551" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918551)" stroke-opacity="1" x1="252" y1="27.9" x2="306.6" y2="22.32"></line></g><g><defs><marker id="arrow_2387918557" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918557)" stroke-opacity="1" x1="302.4" y1="11.16" x2="260.4" y2="64.17"></line></g><g><defs><marker id="arrow_2387918601" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918601)" stroke-opacity="1" x1="222.6" y1="94.86" x2="92.4" y2="175.77"></line></g><g><defs><marker id="arrow_2387918607" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918607)" stroke-dasharray="6 4" stroke-opacity="1" x1="222.6" y1="19.53" x2="336" y2="25.11"></line></g><g><defs><marker id="arrow_2387918651" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918651)" stroke-opacity="1" x1="243.6" y1="44.64" x2="331.8" y2="66.96"></line></g><g><defs><marker id="arrow_2387918726" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918726)" stroke-opacity="1" x1="264.6" y1="16.74" x2="180.6" y2="44.64"></line></g><g><defs><marker id="arrow_2387918764" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918764)" stroke-opacity="1" x1="117.6" y1="11.16" x2="264.6" y2="61.38"></line></g></svg>',"Jonah":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387917818" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917818)" stroke-opacity="1" x1="239.4" y1="198.09" x2="277.2" y2="259.47"></line></g><g><defs><marker id="arrow_2387917867" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917867)" stroke-opacity="1" x1="58.8" y1="192.51" x2="58.8" y2="214.83"></line></g><g><defs><marker id="arrow_2387917870" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917870)" stroke-opacity="1" x1="109.2" y1="200.88" x2="168" y2="200.88"></line></g><g><defs><marker id="arrow_2387917927" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917927)" stroke-opacity="1" x1="243.6" y1="145.08" x2="159.6" y2="212.04"></line></g><g><defs><marker id="arrow_2387917958" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917958)" stroke-opacity="1" x1="239.4" y1="111.6" x2="235.2" y2="217.62"></line></g><g><defs><marker id="arrow_2387917960" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917960)" stroke-dasharray="6 4" stroke-opacity="1" x1="235.2" y1="181.35" x2="420" y2="251.1"></line></g><g><defs><marker id="arrow_2387917986" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917986)" stroke-opacity="1" x1="58.8" y1="122.76" x2="117.6" y2="75.33"></line></g><g><defs><marker id="arrow_2387917994" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917994)" stroke-opacity="1" x1="134.4" y1="94.86" x2="155.4" y2="172.98"></line></g><g><defs><marker id="arrow_2387918001" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918001)" stroke-opacity="1" x1="273" y1="119.97" x2="256.2" y2="195.3"></line></g><g><defs><marker id="arrow_2387918011" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918011)" stroke-dasharray="6 4" stroke-opacity="1" x1="193.2" y1="139.5" x2="222.6" y2="150.66"></line></g><g><defs><marker id="arrow_2387918019" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918019)" stroke-dasharray="6 4" stroke-opacity="1" x1="58.8" y1="89.28" x2="88.2" y2="39.06"></line></g><g><defs><marker id="arrow_2387918059" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918059)" stroke-opacity="1" x1="113.4" y1="111.6" x2="142.8" y2="145.08"></line></g><g><defs><marker id="arrow_2387918154" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918154)" stroke-opacity="1" x1="172.2" y1="192.51" x2="189" y2="267.84"></line></g><g><defs><marker id="arrow_2387918172" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918172)" stroke-opacity="1" x1="147" y1="200.88" x2="176.4" y2="265.05"></line></g><g><defs><marker id="arrow_2387918178" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918178)" stroke-opacity="1" x1="58.8" y1="206.46" x2="134.4" y2="245.52"></line></g><g><defs><marker id="arrow_2387918218" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918218)" stroke-opacity="1" x1="298.2" y1="228.78" x2="323.4" y2="267.84"></line></g><g><defs><marker id="arrow_2387918248" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918248)" stroke-dasharray="6 4" stroke-opacity="1" x1="189" y1="92.07" x2="226.8" y2="75.33"></line></g><g><defs><marker id="arrow_2387918364" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918364)" stroke-opacity="1" x1="205.8" y1="131.13" x2="117.6" y2="170.19"></line></g><g><defs><marker id="arrow_2387918373" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918373)" stroke-dasharray="6 4" stroke-opacity="1" x1="273" y1="189.72" x2="306.6" y2="106.02"></line></g><g><defs><marker id="arrow_2387918415" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918415)" stroke-opacity="1" x1="205.8" y1="136.71" x2="121.8" y2="159.03"></line></g><g><defs><marker id="arrow_2387918435" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918435)" stroke-opacity="1" x1="205.8" y1="131.13" x2="113.4" y2="156.24"></line></g><g><defs><marker id="arrow_2387918472" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918472)" stroke-opacity="1" x1="226.8" y1="75.33" x2="243.6" y2="30.69"></line></g><g><defs><marker id="arrow_2387918497" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918497)" stroke-opacity="1" x1="277.2" y1="119.97" x2="315" y2="150.66"></line></g><g><defs><marker id="arrow_2387918516" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918516)" stroke-opacity="1" x1="138.6" y1="198.09" x2="172.2" y2="265.05"></line></g><g><defs><marker id="arrow_2387918518" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918518)" stroke-opacity="1" x1="117.6" y1="178.56" x2="105" y2="72.54"></line></g><g><defs><marker id="arrow_2387918548" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918548)" stroke-opacity="1" x1="184.8" y1="175.77" x2="172.2" y2="75.33"></line></g><g><defs><marker id="arrow_2387918553" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918553)" stroke-opacity="1" x1="260.4" y1="92.07" x2="277.2" y2="50.22"></line></g><g><defs><marker id="arrow_2387918556" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918556)" stroke-opacity="1" x1="256.2" y1="114.39" x2="302.4" y2="11.16"></line></g><g><defs><marker id="arrow_2387918575" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918575)" stroke-dasharray="6 4" stroke-opacity="1" x1="168" y1="195.3" x2="239.4" y2="61.38"></line></g><g><defs><marker id="arrow_2387918584" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918584)" stroke-opacity="1" x1="159.6" y1="100.44" x2="184.8" y2="117.18"></line></g><g><defs><marker id="arrow_2387918643" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918643)" stroke-dasharray="6 4" stroke-opacity="1" x1="268.8" y1="156.24" x2="327.6" y2="225.99"></line></g><g><defs><marker id="arrow_2387918656" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918656)" stroke-opacity="1" x1="113.4" y1="139.5" x2="134.4" y2="225.99"></line></g><g><defs><marker id="arrow_2387918696" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918696)" stroke-opacity="1" x1="210" y1="136.71" x2="109.2" y2="170.19"></line></g><g><defs><marker id="arrow_2387918708" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918708)" stroke-opacity="1" x1="247.8" y1="156.24" x2="256.2" y2="86.49"></line></g><g><defs><marker id="arrow_2387918724" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918724)" stroke-opacity="1" x1="273" y1="55.8" x2="264.6" y2="16.74"></line></g><g><defs><marker id="arrow_2387918727" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918727)" stroke-opacity="1" x1="180.6" y1="44.64" x2="92.4" y2="161.82"></line></g><g><defs><marker id="arrow_2387918731" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918731)" stroke-opacity="1" x1="226.8" y1="142.29" x2="256.2" y2="128.34"></line></g><g><defs><marker id="arrow_2387918735" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918735)" stroke-opacity="1" x1="151.2" y1="131.13" x2="117.6" y2="259.47"></line></g><g><defs><marker id="arrow_2387918737" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918737)" stroke-opacity="1" x1="134.4" y1="189.72" x2="105" y2="217.62"></line></g><g><defs><marker id="arrow_2387918748" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918748)" stroke-opacity="1" x1="184.8" y1="175.77" x2="268.8" y2="167.4"></line></g><g><defs><marker id="arrow_2387918753" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918753)" stroke-opacity="1" x1="193.2" y1="111.6" x2="130.2" y2="198.09"></line></g><g><defs><marker id="arrow_2387918756" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918756)" stroke-opacity="1" x1="222.6" y1="153.45" x2="260.4" y2="61.38"></line></g><g><defs><marker id="arrow_2387918768" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918768)" stroke-dasharray="6 4" stroke-opacity="1" x1="319.2" y1="181.35" x2="420" y2="279"></line></g></svg>',"Bryce":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387918260" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918260)" stroke-dasharray="6 4" stroke-opacity="1" x1="109.2" y1="22.32" x2="138.6" y2="36.27"></line></g><g><defs><marker id="arrow_2387918267" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918267)" stroke-opacity="1" x1="33.6" y1="25.11" x2="46.2" y2="53.01"></line></g><g><defs><marker id="arrow_2387918767" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918767)" stroke-opacity="1" x1="357" y1="181.35" x2="319.2" y2="181.35"></line></g><g><defs><marker id="arrow_2387918770" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918770)" stroke-opacity="1" x1="277.2" y1="231.57" x2="302.4" y2="195.3"></line></g><g><defs><marker id="arrow_2387918772" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918772)" stroke-opacity="1" x1="348.6" y1="228.78" x2="298.2" y2="237.15"></line></g><g><defs><marker id="arrow_2387918777" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918777)" stroke-opacity="1" x1="273" y1="242.73" x2="357" y2="189.72"></line></g></svg>',"Kai":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387918062" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918062)" stroke-opacity="1" x1="151.2" y1="108.81" x2="277.2" y2="212.04"></line></g><g><defs><marker id="arrow_2387918113" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918113)" stroke-opacity="1" x1="352.8" y1="242.73" x2="310.8" y2="237.15"></line></g><g><defs><marker id="arrow_2387918195" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918195)" stroke-opacity="1" x1="138.6" y1="153.45" x2="109.2" y2="156.24"></line></g><g><defs><marker id="arrow_2387918213" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918213)" stroke-opacity="1" x1="289.8" y1="253.89" x2="302.4" y2="267.84"></line></g><g><defs><marker id="arrow_2387918683" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918683)" stroke-opacity="1" x1="361.2" y1="114.39" x2="365.4" y2="150.66"></line></g><g><defs><marker id="arrow_2387918765" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918765)" stroke-opacity="1" x1="264.6" y1="61.38" x2="361.2" y2="245.52"></line></g></svg>',"Ryan":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387918261" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918261)" stroke-dasharray="6 4" stroke-opacity="1" x1="155.4" y1="53.01" x2="138.6" y2="108.81"></line></g><g><defs><marker id="arrow_2387918277" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918277)" stroke-opacity="1" x1="151.2" y1="106.02" x2="184.8" y2="80.91"></line></g><g><defs><marker id="arrow_2387918279" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918279)" stroke-opacity="1" x1="243.6" y1="147.87" x2="285.6" y2="206.46"></line></g><g><defs><marker id="arrow_2387918369" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918369)" stroke-opacity="1" x1="268.8" y1="111.6" x2="285.6" y2="231.57"></line></g><g><defs><marker id="arrow_2387918423" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918423)" stroke-opacity="1" x1="294" y1="66.96" x2="373.8" y2="53.01"></line></g></svg>',"Max":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387917834" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917834)" stroke-opacity="1" x1="319.2" y1="225.99" x2="344.4" y2="259.47"></line></g><g><defs><marker id="arrow_2387917836" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917836)" stroke-opacity="1" x1="327.6" y1="228.78" x2="268.8" y2="198.09"></line></g><g><defs><marker id="arrow_2387917952" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917952)" stroke-dasharray="6 4" stroke-opacity="1" x1="147" y1="75.33" x2="130.2" y2="83.7"></line></g><g><defs><marker id="arrow_2387917988" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917988)" stroke-opacity="1" x1="268.8" y1="248.31" x2="193.2" y2="133.92"></line></g><g><defs><marker id="arrow_2387917997" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917997)" stroke-opacity="1" x1="289.8" y1="253.89" x2="327.6" y2="200.88"></line></g><g><defs><marker id="arrow_2387918060" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918060)" stroke-opacity="1" x1="142.8" y1="145.08" x2="151.2" y2="108.81"></line></g><g><defs><marker id="arrow_2387918142" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918142)" stroke-dasharray="6 4" stroke-opacity="1" x1="189" y1="253.89" x2="344.4" y2="198.09"></line></g><g><defs><marker id="arrow_2387918161" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918161)" stroke-dasharray="6 4" stroke-opacity="1" x1="386.4" y1="259.47" x2="394.8" y2="195.3"></line></g><g><defs><marker id="arrow_2387918182" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918182)" stroke-opacity="1" x1="231" y1="259.47" x2="147" y2="245.52"></line></g><g><defs><marker id="arrow_2387918386" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918386)" stroke-opacity="1" x1="231" y1="128.34" x2="222.6" y2="153.45"></line></g><g><defs><marker id="arrow_2387918448" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918448)" stroke-opacity="1" x1="252" y1="212.04" x2="168" y2="253.89"></line></g><g><defs><marker id="arrow_2387918480" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918480)" stroke-opacity="1" x1="54.6" y1="175.77" x2="54.6" y2="253.89"></line></g><g><defs><marker id="arrow_2387918488" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918488)" stroke-opacity="1" x1="281.4" y1="55.8" x2="315" y2="25.11"></line></g><g><defs><marker id="arrow_2387918522" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918522)" stroke-dasharray="6 4" stroke-opacity="1" x1="273" y1="131.13" x2="264.6" y2="30.69"></line></g><g><defs><marker id="arrow_2387918660" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918660)" stroke-dasharray="6 4" stroke-opacity="1" x1="168" y1="217.62" x2="298.2" y2="239.94"></line></g><g><defs><marker id="arrow_2387918755" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918755)" stroke-opacity="1" x1="260.4" y1="167.4" x2="222.6" y2="153.45"></line></g><g><defs><marker id="arrow_2387918759" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918759)" stroke-dasharray="6 4" stroke-opacity="1" x1="319.2" y1="78.12" x2="399" y2="66.96"></line></g><g><defs><marker id="arrow_2387918763" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918763)" stroke-opacity="1" x1="163.8" y1="50.22" x2="117.6" y2="11.16"></line></g><g><defs><marker id="arrow_2387918771" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918771)" stroke-opacity="1" x1="302.4" y1="195.3" x2="352.8" y2="228.78"></line></g><g><defs><marker id="arrow_2387918783" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918783)" stroke-opacity="1" x1="109.2" y1="50.22" x2="113.4" y2="66.96"></line></g></svg>',"Mike":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387918758" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387918758)" stroke-opacity="1" x1="298.2" y1="47.43" x2="319.2" y2="78.12"></line></g></svg>',"Brian":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2387917871" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2387917871)" stroke-opacity="1" x1="168" y1="200.88" x2="201.6" y2="265.05"></line></g></svg>'}

# %%
players = []
for player in htmlPlayers:
    htmlPlayer = htmlPlayers[player]

    arrowLabels = htmlPlayer.split('<g>')
    arrows = []
    for label in arrowLabels[1:]:
        x1 = label.find("x1")
        y1 = label.find("y1")
        x2 = label.find("x2")
        y2 = label.find("y2")
        if "#0876ff" in label:
            result = True
            coords = label.split("=")[19:]
        else:
            result = False
            coords = label.split("=")[20:]
        if "#d800ff" in label:
            key =True
            result = True
            coords = label.split("=")[19:]
        else:
            key = False
        coordinates = []
        for i in range(4):
            if i%2==0:
                divided = 420/120
            else:
                divided = 280/80
            #divided=1
            val = coords[i]
            val = float(val.split('"')[1])/divided
            coordinates.append(val)
        coordinates.append(result)
        coordinates.append(key)
        arrows.append(coordinates)
    arrows = pd.DataFrame(arrows,columns=["x1",'y1',"x2","y2","result","key pass"])
    arrows.insert(0,"Player",player)
    players.append(arrows)

# %%
merged = players[0]
for player in players:
    merged = pd.merge(merged,player,how="outer")
def distance(startX,startY,endX,endY):
    return np.sqrt((endX-startX)**2+(endY-startY)**2)
merged = merged.assign(Distance = distance(merged.get("x1"),merged.get("y1"),merged.get("x2"),merged.get("y2")))
merged["angle"] = np.arctan((merged.y2-merged.y1)/(merged.x2-merged.x1),)
merged.to_csv("UCSBPasses.csv",index=False)

# %%
left = merged[(merged.get("y1")<40)&(merged.get("y2")<40)]
right = merged[(merged.get("y1")>40)&(merged.get("y2")>40)]
switch = merged[((merged.get("y1")>40)&(merged.get("y2")<=40)) | ((merged.get("y1")<45)&(merged.get("y2")>=40))]
leftPerc = left[left.get("result")].shape[0]/left.shape[0]
rightPerc = right[right.get("result")].shape[0]/right.shape[0]
switchPerc = switch[switch.get("result")].shape[0]/switch.shape[0]
print(leftPerc, rightPerc, switchPerc)
print(left.shape[0],right.shape[0],switch.shape[0])
print(merged["result"].mean())
# Out:
# 0.7570093457943925 0.7642276422764228 0.8552631578947368
# 107 123 76
# 0.7845117845117845

# %%
successful = merged[merged.get("result")]
unsuccessful = merged[~merged.get("result")]
key = merged[merged.get("key pass")]
forward = merged[(merged.get("angle")<=np.sqrt(2)/2) &(merged.get("angle")>=-1*np.sqrt(2)/2)]
forwardSuccessful = forward[forward.get("result")]
forwardUnsuccessful = forward[~forward.get("result")]
attackingThird = merged[merged.get("x2")>=80]
attackingThirdSuccessful = attackingThird[attackingThird.get("result")]
attackingThirdUnsuccessful = attackingThird[~attackingThird.get("result")]
allTheWay = merged[(merged.get("x2")>=80)&(merged.get("x1")>=80)]
allTheWaySuccessful = allTheWay[allTheWay.get("result")]
oppHalf = merged[(merged.get("x1")>=60)&(merged.get("x2")>=60)]
deepPasses = successful[(successful.get("x2")>102)&(successful.get("y2")<62)&(successful.get("y2")>18)&(successful.get("y1")<70)&(successful.get("y1")>5)]
longPasses = merged[merged.get("Distance")>=40]

# %%
left = forward[(forward.get("y1")<40)&(forward.get("y2")<40)]
right = forward[(forward.get("y1")>40)&(forward.get("y2")>40)]
switch = forward[((forward.get("y1")>40)&(forward.get("y2")<=40)) | ((merged.get("y1")<45)&(merged.get("y2")>=40))]
leftPerc = left[left.get("result")].shape[0]/left.shape[0]
rightPerc = right[right.get("result")].shape[0]/right.shape[0]
switchPerc = switch[switch.get("result")].shape[0]/switch.shape[0]
print(leftPerc, rightPerc, switchPerc)
print(left.shape[0],right.shape[0],switch.shape[0])
# Out:
# 0.696969696969697 0.7466666666666667 0.8125
# 66 75 16

# %%
left = attackingThirdSuccessful[(attackingThirdSuccessful.get("y1")<40)&(attackingThirdSuccessful.get("y2")<40)]
right = attackingThirdSuccessful[(attackingThirdSuccessful.get("y1")>40)&(attackingThirdSuccessful.get("y2")>40)]
switch = attackingThirdSuccessful[((attackingThirdSuccessful.get("y1")>40)&(attackingThirdSuccessful.get("y2")<=40)) | ((attackingThirdSuccessful.get("y1")<45)&(attackingThirdSuccessful.get("y2")>=40))]
leftPerc = left.shape[0]/attackingThirdSuccessful.shape[0]
rightPerc = right.shape[0]/attackingThirdSuccessful.shape[0]
switchPerc = switch.shape[0]/attackingThirdSuccessful.shape[0]
print(leftPerc, rightPerc, switchPerc)
print(left.shape[0],right.shape[0],switch.shape[0])
# Out:
# 0.4 0.48333333333333334 0.13333333333333333
# 24 29 8

# %%
left = attackingThird[(attackingThird.get("y1")<40)&(attackingThird.get("y2")<40)]
right = attackingThird[(attackingThird.get("y1")>40)&(attackingThird.get("y2")>40)]
switch = attackingThird[((attackingThird.get("y1")>40)&(attackingThird.get("y2")<=40)) | ((attackingThird.get("y1")<45)&(attackingThird.get("y2")>=40))]
leftPerc = left[left.get("result")].shape[0]/left.shape[0]
rightPerc = right[right.get("result")].shape[0]/right.shape[0]
switchPerc = switch[switch.get("result")].shape[0]/switch.shape[0]
print("Accuracy", leftPerc, rightPerc, switchPerc)
print(left.shape[0],right.shape[0],switch.shape[0])
# Out:
# Accuracy 0.6857142857142857 0.6041666666666666 0.6666666666666666
# 35 48 12

# %%
df = merged
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=df.get("x2"),y=df.get("y2"),fill = True,shade_lowest = False,alpha = .5,n_levels = 40,cmap = "magma")
for i in range(df.shape[0]):
    row = df.iloc[i]
    if row.get("key pass")==True:
        color = "purple"
    elif row.get("result"):
        color = "green"
    else:
        color = "red"
    
    plt.arrow(row.get("x1"),row.get("y1"),row.get("x2")-row.get("x1"),row.get("y2")-row.get("y1"),width = .2,alpha = .3,color = color)
plt.title("UCSD Passes")
# Out:
# Text(0.5, 1.0, 'UCSD Passes')

# %%
df_pass = merged
bins = (8,5)
pitch = Pitch(positional=True)
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')
# plot the heatmap - darker colors = more passes originating from that square
bs_heatmap = pitch.bin_statistic(df_pass.x1, df_pass.y1, statistic='count', bins=bins)
# successful_bins = pitch.bin_statistic(successful.x1, successful.y1, statistic='count', bins=bins)
# unsuccessful_bins = pitch.bin_statistic(unsuccessful.x1, unsuccessful.y1, statistic='count', bins=bins)
# accuracies = successful_bins["statistic"]/(successful_bins["statistic"]+unsuccessful_bins["statistic"])
# bs_heatmap["statistic"]=accuracies
hm = pitch.heatmap(bs_heatmap, ax=ax, cmap='Greens',alpha = .6)
# plot the pass flow map with a single color and the
# arrow length equal to the average distance in the cell
fm = pitch.flow(df_pass.x1, df_pass.y1, df_pass.x2, df_pass.y2, color='black',
                arrow_type='average', bins=bins, ax=ax)
plt.title("General Direction of Passes on Pitch",color = "white",fontsize = 18)
# Out:
# Text(0.5, 1.0, 'General Direction of Passes on Pitch')

# %%
df_pass = merged
bins = (6,5)
pitch = Pitch(positional=True)
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')
# plot the heatmap - darker colors = more passes originating from that square
bs_heatmap = pitch.bin_statistic(df_pass.x1, df_pass.y1, statistic='count', bins=bins)
successful_bins = pitch.bin_statistic(successful.x1, successful.y1, statistic='count', bins=bins)
unsuccessful_bins = pitch.bin_statistic(unsuccessful.x1, unsuccessful.y1, statistic='count', bins=bins)
accuracies = successful_bins["statistic"]/(successful_bins["statistic"]+unsuccessful_bins["statistic"])
bs_heatmap["statistic"]=accuracies
hm = pitch.heatmap(bs_heatmap, ax=ax, cmap='Greens',alpha = .6)

labels2 = pitch.label_heatmap(bs_heatmap, color='black', fontsize=18,
                              ax=ax, ha='center', va='center',
                              str_format='{:.0%}',)
plt.title("Passing Accuracy on Pitch",color = "white",fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Passing Accuracy on Pitch')

# %%
deepPasses.shape[0]
# Out:
# 3

# %%
df = allTheWay
pitch = VerticalPitch(half=True, axis=True)
fig, ax = pitch.draw()
kde = sns.kdeplot(y=df.get("x2"),x=df.get("y2"),fill = True,shade_lowest = False,alpha = .5,n_levels = 15,cmap = "magma")
for i in range(df.shape[0]):
    row = df.iloc[i]
    if row.get("key pass")==True:
        color = "purple"
        label = "Key Pass"
    elif row.get("result"):
        color = "green"
        label = "Successful Pass"
    else:
        color = "red"
        label = "Unsuccessful Pass"
    plt.arrow(row.get("y1"),row.get("x1"),(row.get("y2")-row.get("y1")),(row.get("x2")-row.get("x1")),width = .3,alpha = .4,color = color, label = label)
plt.title("UCSD's Attacking Passes")
handles, labels = plt.gca().get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
plt.legend(unique_labels.values(), unique_labels.keys())

# %%
perc = merged.groupby(["Player","result"]).count().reset_index()
for player in perc.get("Player").unique():
    limited = perc[perc.get("Player")==player]
    try:
        print("Player:",player, "Accuracy:",limited[limited.get("result")==True].get("x1").iloc[0]/limited.get("x1").sum(), "Num Passes:",limited.get("x1").sum())
    except:
        print(player, 0)
# Out:
# Player: Adam Accuracy: 0.8529411764705882 Num Passes: 34
# Player: Brian Accuracy: 1.0 Num Passes: 1
# Player: Bryce Accuracy: 0.8333333333333334 Num Passes: 6
# Player: Carter Accuracy: 0.7916666666666666 Num Passes: 24
# Player: Cole Accuracy: 0.6 Num Passes: 15
# Player: Connor Accuracy: 0.6666666666666666 Num Passes: 12
# Player: Evan Accuracy: 0.8064516129032258 Num Passes: 31
# Player: James Accuracy: 0.7878787878787878 Num Passes: 33
# Player: Jonah Accuracy: 0.813953488372093 Num Passes: 43
# Player: Kai Accuracy: 1.0 Num Passes: 6
# Player: Max Accuracy: 0.7 Num Passes: 20
# Player: Mike Accuracy: 1.0 Num Passes: 1
# Player: Nolan Accuracy: 0.9166666666666666 Num Passes: 12
# Player: Quinn Accuracy: 0.7586206896551724 Num Passes: 29
# Player: Ryan Accuracy: 0.8 Num Passes: 5
# Player: Val Accuracy: 0.7142857142857143 Num Passes: 21
# Player: Woody Accuracy: 0.75 Num Passes: 4

# %%
perc = forward.groupby(["Player","result"]).count().reset_index()
for player in perc.get("Player").unique():
    limited = perc[perc.get("Player")==player]
    try:
        print("Player:",player, "Accuracy:",limited[limited.get("result")==True].get("x1").iloc[0]/limited.get("x1").sum(), "Num Forward Passes:",limited.get("x1").sum())
    except:
        print(player, 0)
# Out:
# Player: Adam Accuracy: 0.8095238095238095 Num Forward Passes: 21
# Player: Bryce Accuracy: 0.75 Num Forward Passes: 4
# Player: Carter Accuracy: 0.7058823529411765 Num Forward Passes: 17
# Player: Cole Accuracy: 0.8333333333333334 Num Forward Passes: 6
# Player: Connor Accuracy: 0.5 Num Forward Passes: 6
# Player: Evan Accuracy: 0.6875 Num Forward Passes: 16
# Player: James Accuracy: 0.75 Num Forward Passes: 20
# Player: Jonah Accuracy: 0.8 Num Forward Passes: 15
# Player: Kai Accuracy: 1.0 Num Forward Passes: 3
# Player: Max Accuracy: 0.6 Num Forward Passes: 10
# Player: Nolan Accuracy: 0.875 Num Forward Passes: 8
# Player: Quinn Accuracy: 0.6 Num Forward Passes: 15
# Player: Ryan Accuracy: 1.0 Num Forward Passes: 2
# Player: Val Accuracy: 0.6 Num Forward Passes: 10
# Player: Woody Accuracy: 1.0 Num Forward Passes: 1

# %%
for player in merged.get("Player").unique():
    allPass = merged[merged.get("Player")==player].shape[0]
    forwardPass = forward[forward.get("Player")==player].shape[0]
    print("Player:",player,"Percentage Forward:",forwardPass/allPass, "Num Passes", allPass)
# Out:
# Player: Adam Percentage Forward: 0.6176470588235294 Num Passes 34
# Player: Brian Percentage Forward: 0.0 Num Passes 1
# Player: Bryce Percentage Forward: 0.6666666666666666 Num Passes 6
# Player: Carter Percentage Forward: 0.7083333333333334 Num Passes 24
# Player: Cole Percentage Forward: 0.4 Num Passes 15
# Player: Connor Percentage Forward: 0.5 Num Passes 12
# Player: Evan Percentage Forward: 0.5161290322580645 Num Passes 31
# Player: James Percentage Forward: 0.6060606060606061 Num Passes 33
# Player: Jonah Percentage Forward: 0.3488372093023256 Num Passes 43
# Player: Kai Percentage Forward: 0.5 Num Passes 6
# Player: Max Percentage Forward: 0.5 Num Passes 20
# Player: Mike Percentage Forward: 0.0 Num Passes 1
# Player: Nolan Percentage Forward: 0.6666666666666666 Num Passes 12
# Player: Quinn Percentage Forward: 0.5172413793103449 Num Passes 29
# Player: Ryan Percentage Forward: 0.4 Num Passes 5
# Player: Val Percentage Forward: 0.47619047619047616 Num Passes 21
# ...

# %%
print(longPasses.get("result").mean())
perc = longPasses.groupby(["Player","result"]).count().reset_index()
for player in perc.get("Player").unique():
    limited = perc[perc.get("Player")==player]
    try:
        print("Player:",player, "Percentage:",limited[limited.get("result")==True].get("x1").iloc[0]/limited.get("x1").sum(), "Num Long Passes:",limited.get("x1").sum())
    except:
        print(player, 0)
# Out:
# 0.5405405405405406
# Player: Adam Percentage: 0.6666666666666666 Num Long Passes: 3
# Player: Carter Percentage: 1.0 Num Long Passes: 3
# Cole 0
# Player: Evan Percentage: 0.75 Num Long Passes: 4
# Player: James Percentage: 0.375 Num Long Passes: 8
# Player: Jonah Percentage: 0.25 Num Long Passes: 4
# Player: Kai Percentage: 1.0 Num Long Passes: 2
# Max 0
# Player: Nolan Percentage: 0.8 Num Long Passes: 5
# Quinn 0
# Player: Val Percentage: 0.6666666666666666 Num Long Passes: 3
# Woody 0

# %%
(merged.groupby("Player").count()["result"]/merged.shape[0]).sort_values(ascending=False)
# Out:
# Player
# Jonah     0.144781
# Adam      0.114478
# James     0.111111
# Evan      0.104377
# Quinn     0.097643
# Carter    0.080808
# Val       0.070707
# Max       0.067340
# Cole      0.050505
# Connor    0.040404
# Nolan     0.040404
# Bryce     0.020202
# Kai       0.020202
# Ryan      0.016835
# Woody     0.013468
# Brian     0.003367
# Mike      0.003367
# Name: result, dtype: float64

# %%
for player in merged.get("Player").unique():   
    playerDf = merged[merged.get("Player")==player]
    df = playerDf
    pitch = Pitch(positional=True, axis=True,label=True)
    fig, ax = plt.subplots(figsize = (10,6))
    pitch.draw(ax=ax)
    kde = sns.kdeplot(x=df.get("x2"),y=df.get("y2"),fill = True,shade_lowest = False,alpha = .5,n_levels = 10,cmap = "magma")
    for i in range(df.shape[0]):
        row = df.iloc[i]
        if row.get("key pass")==True:
            color = "purple"
        elif row.get("result"):
            color = "green"
        else:
            color = "red"
        
        plt.arrow(row.get("x1"),row.get("y1"),row.get("x2")-row.get("x1"),row.get("y2")-row.get("y1"),width = .2,alpha = .3,color = color)
    plt.title(player+" Passes Destination")
    plt.show()
