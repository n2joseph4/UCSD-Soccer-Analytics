# %%
import pandas as pd
from mplsoccer import Pitch
from mplsoccer import VerticalPitch
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
htmlPlayers = {"Nolan":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356419" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356419)" stroke-dasharray="6 4" stroke-opacity="1" x1="58.8" y1="184.14" x2="327.6" y2="186.93"></line></g><g><defs><marker id="arrow_2291356453" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356453)" stroke-opacity="1" x1="46.2" y1="131.13" x2="277.2" y2="217.62"></line></g><g><defs><marker id="arrow_2291356459" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356459)" stroke-dasharray="6 4" stroke-opacity="1" x1="42" y1="136.71" x2="285.6" y2="53.01"></line></g><g><defs><marker id="arrow_2291356464" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356464)" stroke-opacity="1" x1="42" y1="170.19" x2="92.4" y2="225.99"></line></g><g><defs><marker id="arrow_2291356501" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356501)" stroke-opacity="1" x1="46.2" y1="147.87" x2="256.2" y2="231.57"></line></g><g><defs><marker id="arrow_2291356556" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356556)" stroke-dasharray="6 4" stroke-opacity="1" x1="42" y1="100.44" x2="260.4" y2="97.65"></line></g><g><defs><marker id="arrow_2291356581" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356581)" stroke-opacity="1" x1="8.4" y1="159.03" x2="25.2" y2="242.73"></line></g><g><defs><marker id="arrow_2291356589" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356589)" stroke-opacity="1" x1="63" y1="145.08" x2="256.2" y2="66.96"></line></g><g><defs><marker id="arrow_2291356751" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356751)" stroke-dasharray="6 4" stroke-opacity="1" x1="50.4" y1="156.24" x2="310.8" y2="189.72"></line></g><g><defs><marker id="arrow_2291356760" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356760)" stroke-opacity="1" x1="121.8" y1="147.87" x2="302.4" y2="142.29"></line></g><g><defs><marker id="arrow_2291356776" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356776)" stroke-dasharray="6 4" stroke-opacity="1" x1="58.8" y1="142.29" x2="268.8" y2="228.78"></line></g><g><defs><marker id="arrow_2291356830" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356830)" stroke-opacity="1" x1="50.4" y1="142.29" x2="147" y2="259.47"></line></g><g><defs><marker id="arrow_2291356886" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356886)" stroke-dasharray="6 4" stroke-opacity="1" x1="79.8" y1="145.08" x2="294" y2="69.75"></line></g><g><defs><marker id="arrow_2291357068" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357068)" stroke-opacity="1" x1="63" y1="131.13" x2="147" y2="27.9"></line></g><g><defs><marker id="arrow_2291357170" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357170)" stroke-dasharray="6 4" stroke-opacity="1" x1="88.2" y1="178.56" x2="294" y2="178.56"></line></g><g><defs><marker id="arrow_2291357187" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357187)" stroke-opacity="1" x1="75.6" y1="145.08" x2="285.6" y2="64.17"></line></g><g><defs><marker id="arrow_2291357208" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357208)" stroke-dasharray="6 4" stroke-opacity="1" x1="121.8" y1="136.71" x2="323.4" y2="92.07"></line></g><g><defs><marker id="arrow_2291357215" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357215)" stroke-opacity="1" x1="50.4" y1="192.51" x2="163.8" y2="256.68"></line></g><g><defs><marker id="arrow_2291357364" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357364)" stroke-dasharray="6 4" stroke-opacity="1" x1="37.8" y1="156.24" x2="189" y2="150.66"></line></g><g><defs><marker id="arrow_2291357443" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357443)" stroke-dasharray="6 4" stroke-opacity="1" x1="33.6" y1="203.67" x2="163.8" y2="248.31"></line></g></svg>',"Evan":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356423" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356423)" stroke-opacity="1" x1="180.6" y1="234.36" x2="399" y2="251.1"></line></g><g><defs><marker id="arrow_2291356436" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356436)" stroke-dasharray="6 4" stroke-opacity="1" x1="79.8" y1="36.27" x2="88.2" y2="36.27"></line></g><g><defs><marker id="arrow_2291356442" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356442)" stroke-opacity="1" x1="113.4" y1="200.88" x2="382.2" y2="231.57"></line></g><g><defs><marker id="arrow_2291356465" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356465)" stroke-opacity="1" x1="92.4" y1="225.99" x2="37.8" y2="186.93"></line></g><g><defs><marker id="arrow_2291356467" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356467)" stroke-dasharray="6 4" stroke-opacity="1" x1="75.6" y1="206.46" x2="306.6" y2="209.25"></line></g><g><defs><marker id="arrow_2291356483" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356483)" stroke-opacity="1" x1="109.2" y1="172.98" x2="256.2" y2="242.73"></line></g><g><defs><marker id="arrow_2291356493" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356493)" stroke-opacity="1" x1="42" y1="172.98" x2="100.8" y2="66.96"></line></g><g><defs><marker id="arrow_2291356499" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356499)" stroke-dasharray="6 4" stroke-opacity="1" x1="54.6" y1="170.19" x2="126" y2="192.51"></line></g><g><defs><marker id="arrow_2291356549" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356549)" stroke-dasharray="6 4" stroke-opacity="1" x1="189" y1="117.18" x2="252" y2="30.69"></line></g><g><defs><marker id="arrow_2291356550" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356550)" stroke-dasharray="6 4" stroke-opacity="1" x1="88.2" y1="111.6" x2="37.8" y2="69.75"></line></g><g><defs><marker id="arrow_2291356580" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356580)" stroke-opacity="1" x1="58.8" y1="231.57" x2="8.4" y2="159.03"></line></g><g><defs><marker id="arrow_2291356582" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356582)" stroke-opacity="1" x1="25.2" y1="242.73" x2="96.6" y2="209.25"></line></g><g><defs><marker id="arrow_2291356642" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356642)" stroke-opacity="1" x1="138.6" y1="209.25" x2="130.2" y2="136.71"></line></g><g><defs><marker id="arrow_2291356652" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356652)" stroke-opacity="1" x1="71.4" y1="200.88" x2="126" y2="217.62"></line></g><g><defs><marker id="arrow_2291356689" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356689)" stroke-dasharray="6 4" stroke-opacity="1" x1="197.4" y1="231.57" x2="420" y2="195.3"></line></g><g><defs><marker id="arrow_2291356691" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356691)" stroke-opacity="1" x1="126" y1="139.5" x2="184.8" y2="117.18"></line></g><g><defs><marker id="arrow_2291356705" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356705)" stroke-dasharray="6 4" stroke-opacity="1" x1="130.2" y1="92.07" x2="361.2" y2="75.33"></line></g><g><defs><marker id="arrow_2291356718" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356718)" stroke-opacity="1" x1="142.8" y1="212.04" x2="189" y2="256.68"></line></g><g><defs><marker id="arrow_2291356795" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356795)" stroke-dasharray="6 4" stroke-opacity="1" x1="155.4" y1="103.23" x2="373.8" y2="164.61"></line></g><g><defs><marker id="arrow_2291356824" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356824)" stroke-dasharray="6 4" stroke-opacity="1" x1="100.8" y1="203.67" x2="121.8" y2="234.36"></line></g><g><defs><marker id="arrow_2291356876" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356876)" stroke-opacity="1" x1="113.4" y1="184.14" x2="134.4" y2="164.61"></line></g><g><defs><marker id="arrow_2291356884" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356884)" stroke-opacity="1" x1="117.6" y1="189.72" x2="46.2" y2="147.87"></line></g><g><defs><marker id="arrow_2291356908" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356908)" stroke-opacity="1" x1="134.4" y1="228.78" x2="126" y2="175.77"></line></g><g><defs><marker id="arrow_2291356912" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356912)" stroke-opacity="1" x1="126" y1="203.67" x2="142.8" y2="145.08"></line></g><g><defs><marker id="arrow_2291356955" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356955)" stroke-opacity="1" x1="180.6" y1="195.3" x2="197.4" y2="122.76"></line></g><g><defs><marker id="arrow_2291357078" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357078)" stroke-dasharray="6 4" stroke-opacity="1" x1="155.4" y1="231.57" x2="239.4" y2="217.62"></line></g><g><defs><marker id="arrow_2291357080" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357080)" stroke-opacity="1" x1="121.8" y1="225.99" x2="163.8" y2="214.83"></line></g><g><defs><marker id="arrow_2291357140" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357140)" stroke-opacity="1" x1="46.2" y1="228.78" x2="58.8" y2="267.84"></line></g><g><defs><marker id="arrow_2291357254" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357254)" stroke-opacity="1" x1="184.8" y1="256.68" x2="184.8" y2="136.71"></line></g><g><defs><marker id="arrow_2291357262" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357262)" stroke-opacity="1" x1="176.4" y1="231.57" x2="243.6" y2="237.15"></line></g><g><defs><marker id="arrow_2291357347" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357347)" stroke-opacity="1" x1="42" y1="100.44" x2="33.6" y2="44.64"></line></g><g><defs><marker id="arrow_2291357362" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357362)" stroke-opacity="1" x1="63" y1="214.83" x2="37.8" y2="156.24"></line></g><g><defs><marker id="arrow_2291357439" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357439)" stroke-opacity="1" x1="134.4" y1="139.5" x2="159.6" y2="133.92"></line></g><g><defs><marker id="arrow_2291357459" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357459)" stroke-opacity="1" x1="100.8" y1="242.73" x2="310.8" y2="220.41"></line></g></svg>',"Adam":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356437" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356437)" stroke-dasharray="6 4" stroke-opacity="1" x1="71.4" y1="19.53" x2="109.2" y2="0"></line></g><g><defs><marker id="arrow_2291356447" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356447)" stroke-opacity="1" x1="197.4" y1="139.5" x2="273" y2="22.32"></line></g><g><defs><marker id="arrow_2291356450" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356450)" stroke-opacity="1" x1="117.6" y1="72.54" x2="42" y2="231.57"></line></g><g><defs><marker id="arrow_2291356463" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356463)" stroke-opacity="1" x1="109.2" y1="80.91" x2="42" y2="170.19"></line></g><g><defs><marker id="arrow_2291356482" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356482)" stroke-opacity="1" x1="105" y1="39.06" x2="109.2" y2="172.98"></line></g><g><defs><marker id="arrow_2291356526" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356526)" stroke-opacity="1" x1="142.8" y1="61.38" x2="193.2" y2="16.74"></line></g><g><defs><marker id="arrow_2291356542" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356542)" stroke-opacity="1" x1="121.8" y1="89.28" x2="235.2" y2="75.33"></line></g><g><defs><marker id="arrow_2291356600" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356600)" stroke-opacity="1" x1="42" y1="58.59" x2="121.8" y2="22.32"></line></g><g><defs><marker id="arrow_2291356602" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356602)" stroke-opacity="1" x1="96.6" y1="66.96" x2="113.4" y2="22.32"></line></g><g><defs><marker id="arrow_2291356604" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356604)" stroke-opacity="1" x1="84" y1="44.64" x2="151.2" y2="30.69"></line></g><g><defs><marker id="arrow_2291356643" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356643)" stroke-opacity="1" x1="130.2" y1="136.71" x2="155.4" y2="167.4"></line></g><g><defs><marker id="arrow_2291356645" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356645)" stroke-opacity="1" x1="117.6" y1="106.02" x2="193.2" y2="19.53"></line></g><g><defs><marker id="arrow_2291356648" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356648)" stroke-opacity="1" x1="172.2" y1="64.17" x2="159.6" y2="19.53"></line></g><g><defs><marker id="arrow_2291356651" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356651)" stroke-dasharray="6 4" stroke-opacity="1" x1="126" y1="108.81" x2="231" y2="136.71"></line></g><g><defs><marker id="arrow_2291356658" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356658)" stroke-opacity="1" x1="180.6" y1="30.69" x2="243.6" y2="50.22"></line></g><g><defs><marker id="arrow_2291356742" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356742)" stroke-opacity="1" x1="130.2" y1="103.23" x2="163.8" y2="192.51"></line></g><g><defs><marker id="arrow_2291356748" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356748)" stroke-dasharray="6 4" stroke-opacity="1" x1="100.8" y1="55.8" x2="138.6" y2="69.75"></line></g><g><defs><marker id="arrow_2291356758" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356758)" stroke-dasharray="6 4" stroke-opacity="1" x1="126" y1="72.54" x2="155.4" y2="78.12"></line></g><g><defs><marker id="arrow_2291356873" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356873)" stroke-opacity="1" x1="142.8" y1="139.5" x2="193.2" y2="142.29"></line></g><g><defs><marker id="arrow_2291356881" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356881)" stroke-opacity="1" x1="84" y1="44.64" x2="134.4" y2="16.74"></line></g><g><defs><marker id="arrow_2291356898" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356898)" stroke-opacity="1" x1="134.4" y1="86.49" x2="252" y2="97.65"></line></g><g><defs><marker id="arrow_2291356910" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356910)" stroke-dasharray="6 4" stroke-opacity="1" x1="126" y1="175.77" x2="109.2" y2="178.56"></line></g><g><defs><marker id="arrow_2291356930" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356930)" stroke-opacity="1" x1="96.6" y1="97.65" x2="130.2" y2="145.08"></line></g><g><defs><marker id="arrow_2291356934" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356934)" stroke-opacity="1" x1="84" y1="89.28" x2="84" y2="145.08"></line></g><g><defs><marker id="arrow_2291356936" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356936)" stroke-opacity="1" x1="100.8" y1="83.7" x2="189" y2="94.86"></line></g><g><defs><marker id="arrow_2291356956" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356956)" stroke-opacity="1" x1="197.4" y1="122.76" x2="247.8" y2="114.39"></line></g><g><defs><marker id="arrow_2291357167" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357167)" stroke-opacity="1" x1="71.4" y1="47.43" x2="46.2" y2="145.08"></line></g><g><defs><marker id="arrow_2291357256" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357256)" stroke-opacity="1" x1="184.8" y1="136.71" x2="252" y2="200.88"></line></g><g><defs><marker id="arrow_2291357334" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357334)" stroke-opacity="1" x1="155.4" y1="100.44" x2="273" y2="27.9"></line></g><g><defs><marker id="arrow_2291357349" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357349)" stroke-opacity="1" x1="33.6" y1="44.64" x2="134.4" y2="83.7"></line></g><g><defs><marker id="arrow_2291357431" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357431)" stroke-opacity="1" x1="42" y1="92.07" x2="138.6" y2="47.43"></line></g><g><defs><marker id="arrow_2291357442" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357442)" stroke-opacity="1" x1="63" y1="103.23" x2="33.6" y2="203.67"></line></g></svg>',"Cole":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356410" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356410)" stroke-opacity="1" x1="273" y1="245.52" x2="361.2" y2="200.88"></line></g><g><defs><marker id="arrow_2291356429" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356429)" stroke-opacity="1" x1="71.4" y1="131.13" x2="113.4" y2="61.38"></line></g><g><defs><marker id="arrow_2291356505" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356505)" stroke-dasharray="6 4" stroke-opacity="1" x1="163.8" y1="245.52" x2="130.2" y2="239.94"></line></g><g><defs><marker id="arrow_2291356538" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356538)" stroke-opacity="1" x1="268.8" y1="251.1" x2="239.4" y2="220.41"></line></g><g><defs><marker id="arrow_2291356560" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356560)" stroke-dasharray="6 4" stroke-opacity="1" x1="159.6" y1="220.41" x2="126" y2="209.25"></line></g><g><defs><marker id="arrow_2291356579" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356579)" stroke-dasharray="6 4" stroke-opacity="1" x1="348.6" y1="259.47" x2="365.4" y2="159.03"></line></g><g><defs><marker id="arrow_2291356587" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356587)" stroke-dasharray="6 4" stroke-opacity="1" x1="88.2" y1="142.29" x2="105" y2="108.81"></line></g><g><defs><marker id="arrow_2291356610" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356610)" stroke-opacity="1" x1="130.2" y1="203.67" x2="117.6" y2="164.61"></line></g><g><defs><marker id="arrow_2291356619" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356619)" stroke-opacity="1" x1="369.6" y1="225.99" x2="386.4" y2="142.29"></line></g><g><defs><marker id="arrow_2291356666" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356666)" stroke-opacity="1" x1="134.4" y1="214.83" x2="218.4" y2="214.83"></line></g><g><defs><marker id="arrow_2291356669" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356669)" stroke-opacity="1" x1="243.6" y1="237.15" x2="285.6" y2="256.68"></line></g><g><defs><marker id="arrow_2291356687" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356687)" stroke-opacity="1" x1="331.8" y1="248.31" x2="289.8" y2="242.73"></line></g><g><defs><marker id="arrow_2291356803" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356803)" stroke-dasharray="6 4" stroke-opacity="1" x1="331.8" y1="262.26" x2="386.4" y2="150.66"></line></g><g><defs><marker id="arrow_2291356811" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356811)" stroke-opacity="1" x1="256.2" y1="209.25" x2="235.2" y2="142.29"></line></g><g><defs><marker id="arrow_2291356838" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356838)" stroke-opacity="1" x1="319.2" y1="212.04" x2="310.8" y2="150.66"></line></g><g><defs><marker id="arrow_2291356920" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356920)" stroke-opacity="1" x1="319.2" y1="228.78" x2="407.4" y2="242.73"></line></g><g><defs><marker id="arrow_2291356964" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356964)" stroke-opacity="1" x1="281.4" y1="192.51" x2="260.4" y2="212.04"></line></g></svg>',"Quinn":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356409" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356409)" stroke-opacity="1" x1="155.4" y1="212.04" x2="273" y2="245.52"></line></g><g><defs><marker id="arrow_2291356446" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356446)" stroke-opacity="1" x1="247.8" y1="164.61" x2="197.4" y2="139.5"></line></g><g><defs><marker id="arrow_2291356473" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356473)" stroke-dasharray="6 4" stroke-opacity="1" x1="247.8" y1="206.46" x2="373.8" y2="251.1"></line></g><g><defs><marker id="arrow_2291356523" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356523)" stroke-dasharray="6 4" stroke-opacity="1" x1="193.2" y1="13.95" x2="231" y2="36.27"></line></g><g><defs><marker id="arrow_2291356536" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356536)" stroke-opacity="1" x1="184.8" y1="170.19" x2="243.6" y2="214.83"></line></g><g><defs><marker id="arrow_2291356571" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356571)" stroke-opacity="1" x1="197.4" y1="50.22" x2="231" y2="53.01"></line></g><g><defs><marker id="arrow_2291356573" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356573)" stroke-dasharray="6 4" stroke-opacity="1" x1="256.2" y1="27.9" x2="268.8" y2="41.85"></line></g><g><defs><marker id="arrow_2291356617" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356617)" stroke-opacity="1" x1="235.2" y1="200.88" x2="336" y2="251.1"></line></g><g><defs><marker id="arrow_2291356655" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356655)" stroke-opacity="1" x1="159.6" y1="64.17" x2="226.8" y2="78.12"></line></g><g><defs><marker id="arrow_2291356659" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356659)" stroke-opacity="1" x1="243.6" y1="50.22" x2="222.6" y2="5.58"></line></g><g><defs><marker id="arrow_2291356676" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356676)" stroke-dasharray="6 4" stroke-opacity="1" x1="155.4" y1="47.43" x2="184.8" y2="25.11"></line></g><g><defs><marker id="arrow_2291356677" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356677)" stroke-dasharray="6 4" stroke-opacity="1" x1="130.2" y1="58.59" x2="117.6" y2="0"></line></g><g><defs><marker id="arrow_2291356692" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356692)" stroke-opacity="1" x1="184.8" y1="117.18" x2="138.6" y2="97.65"></line></g><g><defs><marker id="arrow_2291356812" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356812)" stroke-dasharray="6 4" stroke-opacity="1" x1="235.2" y1="142.29" x2="285.6" y2="80.91"></line></g><g><defs><marker id="arrow_2291356836" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356836)" stroke-opacity="1" x1="235.2" y1="265.05" x2="281.4" y2="262.26"></line></g><g><defs><marker id="arrow_2291356897" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356897)" stroke-opacity="1" x1="176.4" y1="55.8" x2="134.4" y2="86.49"></line></g><g><defs><marker id="arrow_2291356914" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356914)" stroke-opacity="1" x1="142.8" y1="145.08" x2="159.6" y2="94.86"></line></g><g><defs><marker id="arrow_2291356958" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356958)" stroke-opacity="1" x1="247.8" y1="114.39" x2="252" y2="30.69"></line></g><g><defs><marker id="arrow_2291356960" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356960)" stroke-opacity="1" x1="252" y1="89.28" x2="231" y2="172.98"></line></g><g><defs><marker id="arrow_2291356971" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356971)" stroke-dasharray="6 4" stroke-opacity="1" x1="310.8" y1="86.49" x2="336" y2="117.18"></line></g><g><defs><marker id="arrow_2291357023" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357023)" stroke-opacity="1" x1="344.4" y1="92.07" x2="378" y2="33.48"></line></g><g><defs><marker id="arrow_2291357076" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357076)" stroke-opacity="1" x1="189" y1="50.22" x2="155.4" y2="231.57"></line></g><g><defs><marker id="arrow_2291357246" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357246)" stroke-opacity="1" x1="189" y1="231.57" x2="231" y2="259.47"></line></g><g><defs><marker id="arrow_2291357253" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357253)" stroke-opacity="1" x1="260.4" y1="242.73" x2="184.8" y2="256.68"></line></g><g><defs><marker id="arrow_2291357329" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357329)" stroke-dasharray="6 4" stroke-opacity="1" x1="294" y1="259.47" x2="310.8" y2="106.02"></line></g><g><defs><marker id="arrow_2291357365" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357365)" stroke-opacity="1" x1="147" y1="156.24" x2="172.2" y2="212.04"></line></g><g><defs><marker id="arrow_2291357436" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357436)" stroke-opacity="1" x1="163.8" y1="69.75" x2="168" y2="50.22"></line></g></svg>',"Val":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356636" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356636)" stroke-opacity="1" x1="281.4" y1="19.53" x2="302.4" y2="25.11"></line></g><g><defs><marker id="arrow_2291356695" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356695)" stroke-opacity="1" x1="142.8" y1="22.32" x2="117.6" y2="97.65"></line></g><g><defs><marker id="arrow_2291356698" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356698)" stroke-opacity="1" x1="151.2" y1="13.95" x2="134.4" y2="39.06"></line></g><g><defs><marker id="arrow_2291357138" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357138)" stroke-opacity="1" x1="79.8" y1="245.52" x2="46.2" y2="228.78"></line></g><g><defs><marker id="arrow_2291357227" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357227)" stroke-opacity="1" x1="147" y1="265.05" x2="252" y2="228.78"></line></g><g><defs><marker id="arrow_2291357247" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357247)" stroke-opacity="1" x1="231" y1="259.47" x2="147" y2="256.68"></line></g><g><defs><marker id="arrow_2291357265" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357265)" stroke-opacity="1" x1="273" y1="259.47" x2="231" y2="251.1"></line></g><g><defs><marker id="arrow_2291357323" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357323)" stroke-opacity="1" x1="184.8" y1="251.1" x2="252" y2="256.68"></line></g></svg>',"Jonah":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356404" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356404)" stroke-opacity="1" x1="126" y1="178.56" x2="109.2" y2="212.04"></line></g><g><defs><marker id="arrow_2291356458" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356458)" stroke-opacity="1" x1="130.2" y1="72.54" x2="42" y2="136.71"></line></g><g><defs><marker id="arrow_2291356472" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356472)" stroke-opacity="1" x1="189" y1="156.24" x2="247.8" y2="206.46"></line></g><g><defs><marker id="arrow_2291356539" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356539)" stroke-opacity="1" x1="239.4" y1="220.41" x2="273" y2="186.93"></line></g><g><defs><marker id="arrow_2291356541" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356541)" stroke-opacity="1" x1="239.4" y1="178.56" x2="121.8" y2="89.28"></line></g><g><defs><marker id="arrow_2291356543" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356543)" stroke-opacity="1" x1="235.2" y1="75.33" x2="231" y2="8.37"></line></g><g><defs><marker id="arrow_2291356557" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356557)" stroke-opacity="1" x1="155.4" y1="159.03" x2="130.2" y2="192.51"></line></g><g><defs><marker id="arrow_2291356562" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356562)" stroke-dasharray="6 4" stroke-opacity="1" x1="92.4" y1="94.86" x2="180.6" y2="111.6"></line></g><g><defs><marker id="arrow_2291356576" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356576)" stroke-opacity="1" x1="273" y1="170.19" x2="281.4" y2="248.31"></line></g><g><defs><marker id="arrow_2291356583" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356583)" stroke-opacity="1" x1="96.6" y1="209.25" x2="142.8" y2="256.68"></line></g><g><defs><marker id="arrow_2291356611" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356611)" stroke-opacity="1" x1="117.6" y1="164.61" x2="172.2" y2="192.51"></line></g><g><defs><marker id="arrow_2291356623" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356623)" stroke-opacity="1" x1="281.4" y1="86.49" x2="352.8" y2="33.48"></line></g><g><defs><marker id="arrow_2291356640" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356640)" stroke-opacity="1" x1="277.2" y1="80.91" x2="243.6" y2="239.94"></line></g><g><defs><marker id="arrow_2291356644" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356644)" stroke-opacity="1" x1="155.4" y1="167.4" x2="117.6" y2="106.02"></line></g><g><defs><marker id="arrow_2291356650" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356650)" stroke-opacity="1" x1="168" y1="114.39" x2="126" y2="108.81"></line></g><g><defs><marker id="arrow_2291356665" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356665)" stroke-opacity="1" x1="117.6" y1="136.71" x2="134.4" y2="214.83"></line></g><g><defs><marker id="arrow_2291356686" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356686)" stroke-opacity="1" x1="243.6" y1="206.46" x2="331.8" y2="248.31"></line></g><g><defs><marker id="arrow_2291356693" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356693)" stroke-opacity="1" x1="138.6" y1="97.65" x2="88.2" y2="55.8"></line></g><g><defs><marker id="arrow_2291356697" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356697)" stroke-opacity="1" x1="130.2" y1="66.96" x2="151.2" y2="13.95"></line></g><g><defs><marker id="arrow_2291356734" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356734)" stroke-opacity="1" x1="285.6" y1="78.12" x2="348.6" y2="36.27"></line></g><g><defs><marker id="arrow_2291356752" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356752)" stroke-opacity="1" x1="176.4" y1="170.19" x2="247.8" y2="225.99"></line></g><g><defs><marker id="arrow_2291356764" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356764)" stroke-dasharray="6 4" stroke-opacity="1" x1="289.8" y1="265.05" x2="382.2" y2="237.15"></line></g><g><defs><marker id="arrow_2291356781" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356781)" stroke-opacity="1" x1="176.4" y1="214.83" x2="155.4" y2="164.61"></line></g><g><defs><marker id="arrow_2291356883" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356883)" stroke-opacity="1" x1="121.8" y1="103.23" x2="117.6" y2="189.72"></line></g><g><defs><marker id="arrow_2291356933" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356933)" stroke-opacity="1" x1="130.2" y1="145.08" x2="84" y2="89.28"></line></g><g><defs><marker id="arrow_2291356935" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356935)" stroke-opacity="1" x1="84" y1="145.08" x2="100.8" y2="83.7"></line></g><g><defs><marker id="arrow_2291356946" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356946)" stroke-opacity="1" x1="197.4" y1="147.87" x2="235.2" y2="142.29"></line></g><g><defs><marker id="arrow_2291356961" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356961)" stroke-opacity="1" x1="231" y1="172.98" x2="294" y2="203.67"></line></g><g><defs><marker id="arrow_2291356965" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356965)" stroke-opacity="1" x1="260.4" y1="212.04" x2="189" y2="181.35"></line></g><g><defs><marker id="arrow_2291356968" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356968)" stroke-opacity="1" x1="201.6" y1="156.24" x2="231" y2="139.5"></line></g><g><defs><marker id="arrow_2291357225" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357225)" stroke-opacity="1" x1="155.4" y1="220.41" x2="147" y2="265.05"></line></g><g><defs><marker id="arrow_2291357258" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357258)" stroke-opacity="1" x1="252" y1="200.88" x2="294" y2="231.57"></line></g><g><defs><marker id="arrow_2291357264" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357264)" stroke-opacity="1" x1="243.6" y1="237.15" x2="273" y2="259.47"></line></g><g><defs><marker id="arrow_2291357266" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357266)" stroke-dasharray="6 4" stroke-opacity="1" x1="231" y1="251.1" x2="298.2" y2="279"></line></g><g><defs><marker id="arrow_2291357333" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357333)" stroke-opacity="1" x1="239.4" y1="167.4" x2="155.4" y2="100.44"></line></g><g><defs><marker id="arrow_2291357344" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357344)" stroke-dasharray="6 4" stroke-opacity="1" x1="285.6" y1="19.53" x2="306.6" y2="47.43"></line></g><g><defs><marker id="arrow_2291357418" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357418)" stroke-opacity="1" x1="151.2" y1="217.62" x2="12.6" y2="164.61"></line></g><g><defs><marker id="arrow_2291357440" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357440)" stroke-opacity="1" x1="159.6" y1="133.92" x2="63" y2="103.23"></line></g></svg>',"McGee":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356448" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356448)" stroke-opacity="1" x1="273" y1="22.32" x2="231" y2="19.53"></line></g><g><defs><marker id="arrow_2291356535" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356535)" stroke-dasharray="6 4" stroke-opacity="1" x1="403.2" y1="19.53" x2="403.2" y2="30.69"></line></g><g><defs><marker id="arrow_2291356548" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356548)" stroke-opacity="1" x1="357" y1="66.96" x2="378" y2="86.49"></line></g><g><defs><marker id="arrow_2291356568" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356568)" stroke-opacity="1" x1="201.6" y1="13.95" x2="172.2" y2="61.38"></line></g><g><defs><marker id="arrow_2291356784" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356784)" stroke-dasharray="6 4" stroke-opacity="1" x1="277.2" y1="83.7" x2="302.4" y2="97.65"></line></g><g><defs><marker id="arrow_2291356785" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356785)" stroke-dasharray="6 4" stroke-opacity="1" x1="117.6" y1="53.01" x2="96.6" y2="80.91"></line></g><g><defs><marker id="arrow_2291356895" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356895)" stroke-opacity="1" x1="239.4" y1="33.48" x2="176.4" y2="55.8"></line></g><g><defs><marker id="arrow_2291356917" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356917)" stroke-opacity="1" x1="226.8" y1="131.13" x2="281.4" y2="239.94"></line></g><g><defs><marker id="arrow_2291357026" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357026)" stroke-opacity="1" x1="382.2" y1="39.06" x2="390.6" y2="142.29"></line></g><g><defs><marker id="arrow_2291357126" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357126)" stroke-dasharray="6 4" stroke-opacity="1" x1="247.8" y1="27.9" x2="268.8" y2="89.28"></line></g><g><defs><marker id="arrow_2291357243" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357243)" stroke-opacity="1" x1="121.8" y1="94.86" x2="172.2" y2="212.04"></line></g><g><defs><marker id="arrow_2291357339" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357339)" stroke-dasharray="6 4" stroke-opacity="1" x1="306.6" y1="75.33" x2="323.4" y2="92.07"></line></g></svg>',"Connor":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356710" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356710)" stroke-dasharray="6 4" stroke-opacity="1" x1="159.6" y1="237.15" x2="163.8" y2="203.67"></line></g><g><defs><marker id="arrow_2291356743" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356743)" stroke-opacity="1" x1="163.8" y1="192.51" x2="193.2" y2="133.92"></line></g><g><defs><marker id="arrow_2291356753" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356753)" stroke-opacity="1" x1="247.8" y1="225.99" x2="294" y2="220.41"></line></g></svg>',"Woody":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356709" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356709)" stroke-opacity="1" x1="138.6" y1="198.09" x2="159.6" y2="237.15"></line></g><g><defs><marker id="arrow_2291356744" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356744)" stroke-opacity="1" x1="193.2" y1="133.92" x2="256.2" y2="117.18"></line></g><g><defs><marker id="arrow_2291356783" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356783)" stroke-opacity="1" x1="222.6" y1="106.02" x2="277.2" y2="83.7"></line></g></svg>',"James":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356405" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356405)" stroke-dasharray="6 4" stroke-opacity="1" x1="109.2" y1="212.04" x2="264.6" y2="206.46"></line></g><g><defs><marker id="arrow_2291356422" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356422)" stroke-opacity="1" x1="273" y1="253.89" x2="180.6" y2="234.36"></line></g><g><defs><marker id="arrow_2291356445" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356445)" stroke-opacity="1" x1="273" y1="237.15" x2="247.8" y2="164.61"></line></g><g><defs><marker id="arrow_2291356484" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356484)" stroke-dasharray="6 4" stroke-opacity="1" x1="256.2" y1="242.73" x2="386.4" y2="200.88"></line></g><g><defs><marker id="arrow_2291356558" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356558)" stroke-opacity="1" x1="130.2" y1="192.51" x2="168" y2="212.04"></line></g><g><defs><marker id="arrow_2291356577" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356577)" stroke-opacity="1" x1="281.4" y1="248.31" x2="331.8" y2="259.47"></line></g><g><defs><marker id="arrow_2291356584" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356584)" stroke-opacity="1" x1="142.8" y1="256.68" x2="197.4" y2="212.04"></line></g><g><defs><marker id="arrow_2291356615" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356615)" stroke-opacity="1" x1="235.2" y1="239.94" x2="264.6" y2="214.83"></line></g><g><defs><marker id="arrow_2291356641" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356641)" stroke-opacity="1" x1="243.6" y1="239.94" x2="138.6" y2="209.25"></line></g><g><defs><marker id="arrow_2291356717" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356717)" stroke-opacity="1" x1="243.6" y1="251.1" x2="142.8" y2="212.04"></line></g><g><defs><marker id="arrow_2291356739" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356739)" stroke-dasharray="6 4" stroke-opacity="1" x1="281.4" y1="122.76" x2="289.8" y2="27.9"></line></g><g><defs><marker id="arrow_2291356779" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356779)" stroke-dasharray="6 4" stroke-opacity="1" x1="163.8" y1="225.99" x2="310.8" y2="234.36"></line></g><g><defs><marker id="arrow_2291356808" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356808)" stroke-opacity="1" x1="142.8" y1="256.68" x2="264.6" y2="245.52"></line></g><g><defs><marker id="arrow_2291356820" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356820)" stroke-opacity="1" x1="71.4" y1="262.26" x2="147" y2="253.89"></line></g><g><defs><marker id="arrow_2291356832" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356832)" stroke-opacity="1" x1="147" y1="259.47" x2="205.8" y2="239.94"></line></g><g><defs><marker id="arrow_2291357016" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357016)" stroke-opacity="1" x1="50.4" y1="256.68" x2="151.2" y2="225.99"></line></g><g><defs><marker id="arrow_2291357083" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357083)" stroke-dasharray="6 4" stroke-opacity="1" x1="155.4" y1="262.26" x2="243.6" y2="279"></line></g><g><defs><marker id="arrow_2291357101" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357101)" stroke-opacity="1" x1="58.8" y1="237.15" x2="172.2" y2="198.09"></line></g><g><defs><marker id="arrow_2291357141" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357141)" stroke-opacity="1" x1="58.8" y1="267.84" x2="168" y2="203.67"></line></g><g><defs><marker id="arrow_2291357217" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357217)" stroke-dasharray="6 4" stroke-opacity="1" x1="163.8" y1="256.68" x2="239.4" y2="251.1"></line></g><g><defs><marker id="arrow_2291357224" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357224)" stroke-opacity="1" x1="130.2" y1="231.57" x2="155.4" y2="220.41"></line></g><g><defs><marker id="arrow_2291357248" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357248)" stroke-opacity="1" x1="147" y1="256.68" x2="319.2" y2="265.05"></line></g><g><defs><marker id="arrow_2291357367" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357367)" stroke-dasharray="6 4" stroke-opacity="1" x1="155.4" y1="253.89" x2="361.2" y2="279"></line></g><g><defs><marker id="arrow_2291357445" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357445)" stroke-dasharray="6 4" stroke-opacity="1" x1="117.6" y1="259.47" x2="163.8" y2="279"></line></g></svg>',"Carter":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356416" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356416)" stroke-dasharray="6 4" stroke-opacity="1" x1="294" y1="25.11" x2="327.6" y2="72.54"></line></g><g><defs><marker id="arrow_2291356449" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356449)" stroke-opacity="1" x1="231" y1="19.53" x2="117.6" y2="72.54"></line></g><g><defs><marker id="arrow_2291356462" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356462)" stroke-opacity="1" x1="138.6" y1="16.74" x2="109.2" y2="80.91"></line></g><g><defs><marker id="arrow_2291356477" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356477)" stroke-dasharray="6 4" stroke-opacity="1" x1="155.4" y1="27.9" x2="168" y2="33.48"></line></g><g><defs><marker id="arrow_2291356525" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356525)" stroke-opacity="1" x1="239.4" y1="8.37" x2="142.8" y2="61.38"></line></g><g><defs><marker id="arrow_2291356528" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356528)" stroke-opacity="1" x1="231" y1="19.53" x2="268.8" y2="39.06"></line></g><g><defs><marker id="arrow_2291356544" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356544)" stroke-dasharray="6 4" stroke-opacity="1" x1="231" y1="8.37" x2="302.4" y2="25.11"></line></g><g><defs><marker id="arrow_2291356555" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356555)" stroke-dasharray="6 4" stroke-opacity="1" x1="176.4" y1="50.22" x2="256.2" y2="64.17"></line></g><g><defs><marker id="arrow_2291356566" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356566)" stroke-opacity="1" x1="184.8" y1="22.32" x2="222.6" y2="8.37"></line></g><g><defs><marker id="arrow_2291356572" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356572)" stroke-opacity="1" x1="231" y1="53.01" x2="256.2" y2="27.9"></line></g><g><defs><marker id="arrow_2291356594" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356594)" stroke-dasharray="6 4" stroke-opacity="1" x1="222.6" y1="33.48" x2="247.8" y2="0"></line></g><g><defs><marker id="arrow_2291356601" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356601)" stroke-opacity="1" x1="121.8" y1="22.32" x2="96.6" y2="66.96"></line></g><g><defs><marker id="arrow_2291356603" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356603)" stroke-opacity="1" x1="113.4" y1="22.32" x2="84" y2="44.64"></line></g><g><defs><marker id="arrow_2291356633" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356633)" stroke-opacity="1" x1="151.2" y1="19.53" x2="247.8" y2="39.06"></line></g><g><defs><marker id="arrow_2291356646" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356646)" stroke-opacity="1" x1="193.2" y1="19.53" x2="134.4" y2="64.17"></line></g><g><defs><marker id="arrow_2291356649" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356649)" stroke-opacity="1" x1="159.6" y1="19.53" x2="168" y2="114.39"></line></g><g><defs><marker id="arrow_2291356660" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356660)" stroke-opacity="1" x1="222.6" y1="5.58" x2="306.6" y2="13.95"></line></g><g><defs><marker id="arrow_2291356675" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356675)" stroke-dasharray="6 4" stroke-opacity="1" x1="121.8" y1="30.69" x2="130.2" y2="33.48"></line></g><g><defs><marker id="arrow_2291356694" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356694)" stroke-opacity="1" x1="88.2" y1="55.8" x2="142.8" y2="22.32"></line></g><g><defs><marker id="arrow_2291356699" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356699)" stroke-dasharray="6 4" stroke-opacity="1" x1="134.4" y1="39.06" x2="168" y2="30.69"></line></g><g><defs><marker id="arrow_2291356757" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356757)" stroke-dasharray="6 4" stroke-opacity="1" x1="96.6" y1="72.54" x2="142.8" y2="50.22"></line></g><g><defs><marker id="arrow_2291356767" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356767)" stroke-opacity="1" x1="294" y1="53.01" x2="369.6" y2="111.6"></line></g><g><defs><marker id="arrow_2291356880" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356880)" stroke-dasharray="6 4" stroke-opacity="1" x1="121.8" y1="22.32" x2="294" y2="39.06"></line></g><g><defs><marker id="arrow_2291356882" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356882)" stroke-opacity="1" x1="134.4" y1="16.74" x2="121.8" y2="103.23"></line></g><g><defs><marker id="arrow_2291356928" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356928)" stroke-opacity="1" x1="130.2" y1="55.8" x2="96.6" y2="97.65"></line></g><g><defs><marker id="arrow_2291356959" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356959)" stroke-opacity="1" x1="252" y1="30.69" x2="252" y2="89.28"></line></g><g><defs><marker id="arrow_2291357091" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357091)" stroke-dasharray="6 4" stroke-opacity="1" x1="121.8" y1="75.33" x2="163.8" y2="47.43"></line></g><g><defs><marker id="arrow_2291357130" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357130)" stroke-dasharray="6 4" stroke-opacity="1" x1="348.6" y1="25.11" x2="340.2" y2="86.49"></line></g><g><defs><marker id="arrow_2291357331" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357331)" stroke-opacity="1" x1="235.2" y1="136.71" x2="239.4" y2="167.4"></line></g><g><defs><marker id="arrow_2291357434" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357434)" stroke-dasharray="6 4" stroke-opacity="1" x1="193.2" y1="44.64" x2="268.8" y2="0"></line></g></svg>',"Kai":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356612" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356612)" stroke-opacity="1" x1="172.2" y1="192.51" x2="239.4" y2="242.73"></line></g><g><defs><marker id="arrow_2291356662" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356662)" stroke-opacity="1" x1="273" y1="13.95" x2="243.6" y2="19.53"></line></g><g><defs><marker id="arrow_2291356778" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356778)" stroke-dasharray="6 4" stroke-opacity="1" x1="373.8" y1="251.1" x2="420" y2="89.28"></line></g></svg>',"Brian":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356412" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#d800ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#d800ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356412)" stroke-opacity="1" x1="411.6" y1="189.72" x2="382.2" y2="108.81"></line></g><g><defs><marker id="arrow_2291356444" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356444)" stroke-dasharray="6 4" stroke-opacity="1" x1="403.2" y1="253.89" x2="373.8" y2="167.4"></line></g><g><defs><marker id="arrow_2291356471" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356471)" stroke-opacity="1" x1="226.8" y1="198.09" x2="189" y2="156.24"></line></g><g><defs><marker id="arrow_2291356537" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356537)" stroke-opacity="1" x1="243.6" y1="214.83" x2="268.8" y2="251.1"></line></g><g><defs><marker id="arrow_2291356574" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356574)" stroke-opacity="1" x1="256.2" y1="83.7" x2="214.2" y2="147.87"></line></g><g><defs><marker id="arrow_2291356804" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356804)" stroke-opacity="1" x1="390.6" y1="259.47" x2="331.8" y2="262.26"></line></g><g><defs><marker id="arrow_2291356809" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356809)" stroke-opacity="1" x1="264.6" y1="245.52" x2="252" y2="265.05"></line></g><g><defs><marker id="arrow_2291357081" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357081)" stroke-opacity="1" x1="163.8" y1="214.83" x2="180.6" y2="242.73"></line></g></svg>',"Max":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356430" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356430)" stroke-dasharray="6 4" stroke-opacity="1" x1="113.4" y1="61.38" x2="84" y2="75.33"></line></g><g><defs><marker id="arrow_2291356529" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356529)" stroke-dasharray="6 4" stroke-opacity="1" x1="268.8" y1="39.06" x2="352.8" y2="19.53"></line></g><g><defs><marker id="arrow_2291356533" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356533)" stroke-opacity="1" x1="365.4" y1="30.69" x2="373.8" y2="8.37"></line></g><g><defs><marker id="arrow_2291356540" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356540)" stroke-opacity="1" x1="273" y1="186.93" x2="239.4" y2="178.56"></line></g><g><defs><marker id="arrow_2291356547" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356547)" stroke-opacity="1" x1="378" y1="66.96" x2="357" y2="66.96"></line></g><g><defs><marker id="arrow_2291356586" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356586)" stroke-dasharray="6 4" stroke-opacity="1" x1="247.8" y1="203.67" x2="277.2" y2="66.96"></line></g><g><defs><marker id="arrow_2291356592" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356592)" stroke-opacity="1" x1="222.6" y1="78.12" x2="180.6" y2="30.69"></line></g><g><defs><marker id="arrow_2291356613" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356613)" stroke-opacity="1" x1="239.4" y1="242.73" x2="189" y2="248.31"></line></g><g><defs><marker id="arrow_2291356616" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356616)" stroke-opacity="1" x1="264.6" y1="214.83" x2="235.2" y2="200.88"></line></g><g><defs><marker id="arrow_2291356634" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356634)" stroke-opacity="1" x1="247.8" y1="39.06" x2="285.6" y2="22.32"></line></g><g><defs><marker id="arrow_2291356639" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356639)" stroke-dasharray="6 4" stroke-opacity="1" x1="407.4" y1="66.96" x2="373.8" y2="125.55"></line></g><g><defs><marker id="arrow_2291356667" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356667)" stroke-opacity="1" x1="218.4" y1="214.83" x2="189" y2="231.57"></line></g><g><defs><marker id="arrow_2291356671" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356671)" stroke-dasharray="6 4" stroke-opacity="1" x1="247.8" y1="259.47" x2="226.8" y2="239.94"></line></g><g><defs><marker id="arrow_2291356894" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356894)" stroke-opacity="1" x1="239.4" y1="58.59" x2="239.4" y2="33.48"></line></g><g><defs><marker id="arrow_2291356901" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356901)" stroke-opacity="1" x1="273" y1="86.49" x2="268.8" y2="30.69"></line></g><g><defs><marker id="arrow_2291356921" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356921)" stroke-dasharray="6 4" stroke-opacity="1" x1="407.4" y1="242.73" x2="407.4" y2="231.57"></line></g><g><defs><marker id="arrow_2291356948" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356948)" stroke-opacity="1" x1="235.2" y1="142.29" x2="214.2" y2="133.92"></line></g><g><defs><marker id="arrow_2291356969" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356969)" stroke-opacity="1" x1="231" y1="139.5" x2="239.4" y2="66.96"></line></g><g><defs><marker id="arrow_2291357020" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357020)" stroke-opacity="1" x1="281.4" y1="217.62" x2="285.6" y2="114.39"></line></g><g><defs><marker id="arrow_2291357082" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357082)" stroke-opacity="1" x1="180.6" y1="242.73" x2="155.4" y2="262.26"></line></g><g><defs><marker id="arrow_2291357104" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357104)" stroke-dasharray="6 4" stroke-opacity="1" x1="172.2" y1="198.09" x2="268.8" y2="253.89"></line></g><g><defs><marker id="arrow_2291357366" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291357366)" stroke-opacity="1" x1="172.2" y1="212.04" x2="155.4" y2="253.89"></line></g></svg>',"Ryan":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2291356708" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356708)" stroke-opacity="1" x1="151.2" y1="242.73" x2="138.6" y2="198.09"></line></g><g><defs><marker id="arrow_2291356754" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2291356754)" stroke-opacity="1" x1="294" y1="220.41" x2="281.4" y2="245.52"></line></g></svg>'}

# %%
players = []
for player in htmlPlayers:
    htmlPlayer = htmlPlayers[player]
    print(player)

    arrowLabels = htmlPlayer.split('<g>')
    arrows = []
    for label in arrowLabels[1:]:
        x1 = label.find("x1")
        y1 = label.find("y1")
        x2 = label.find("x2")
        y2 = label.find("y2")
        if "#0876ff" in label:
            result = True
            coords = label.split("=")[19:]
        else:
            result = False
            coords = label.split("=")[20:]
        if "#d800ff" in label:
            key =True
            result = True
            coords = label.split("=")[19:]
        else:
            key = False
        coordinates = []
        for i in range(4):
            if i%2==0:
                divided = 420/120
            else:
                divided = 280/80
            #divided=1
            val = coords[i]
            val = float(val.split('"')[1])/divided
            coordinates.append(val)
        coordinates.append(result)
        coordinates.append(key)
        arrows.append(coordinates)
    arrows = pd.DataFrame(arrows,columns=["x1",'y1',"x2","y2","result","key pass"])
    arrows.insert(0,"Player",player)
    players.append(arrows)
players
# Out:
# Nolan
# Evan
# Adam
# Cole
# Quinn
# Val
# Jonah
# McGee
# Connor
# Woody
# James
# Carter
# Kai
# Brian
# Max
# Ryan
# [   Player    x1         y1    x2         y2  result  key pass
#  0   Nolan  16.8  52.611429  93.6  53.408571   False     False
#  1   Nolan  13.2  37.465714  79.2  62.177143    True     False
#  2   Nolan  12.0  39.060000  81.6  15.145714   False     False
#  3   Nolan  12.0  48.625714  26.4  64.568571    True     False
#  4   Nolan  13.2  42.248571  73.2  66.162857    True     False
#  5   Nolan  12.0  28.697143  74.4  27.900000   False     False
#  6   Nolan   2.4  45.437143   7.2  69.351429    True     False
#  7   Nolan  18.0  41.451429  73.2  19.131429    True     False
#  8   Nolan  14.4  44.640000  88.8  54.205714   False     False
#  9   Nolan  34.8  42.248571  86.4  40.654286    True     False
#  10  Nolan  16.8  40.654286  76.8  65.365714   False     False
#  11  Nolan  14.4  40.654286  42.0  74.134286    True     False
# ...

# %%
merged = players[0]
for player in players:
    merged = pd.merge(merged,player,how="outer")
def distance(startX,startY,endX,endY):
    return np.sqrt((endX-startX)**2+(endY-startY)**2)
merged = merged.assign(Distance = distance(merged.get("x1"),merged.get("y1"),merged.get("x2"),merged.get("y2")))
merged.to_csv("USDPasses.csv",index=False)

# %%
left = merged[(merged.get("y1")<40)&(merged.get("y2")<40)]
right = merged[(merged.get("y1")>40)&(merged.get("y2")>40)]
switch = merged[((merged.get("y1")>40)&(merged.get("y2")<=40)) | ((merged.get("y1")<45)&(merged.get("y2")>=40))]
leftPerc = left[left.get("result")].shape[0]/left.shape[0]
rightPerc = right[right.get("result")].shape[0]/right.shape[0]
switchPerc = switch[switch.get("result")].shape[0]/switch.shape[0]
print(leftPerc, rightPerc, switchPerc)
print(left.shape[0],right.shape[0],switch.shape[0])
# Out:
# 0.6454545454545455 0.753968253968254 0.8214285714285714
# 110 126 56

# %%
successful = merged[merged.get("result")]
unsuccessful = merged[~merged.get("result")]
key = merged[merged.get("key pass")]
forward = merged[merged.get("x2")>merged.get("x1")]
forwardSuccessful = forward[forward.get("result")]
forwardUnsuccessful = forward[~forward.get("result")]
attackingThird = merged[merged.get("x2")>=80]
attackingThirdSuccessful = attackingThird[attackingThird.get("result")]
attackingThirdUnsuccessful = attackingThird[~attackingThird.get("result")]
allTheWay = merged[(merged.get("x2")>=80)&(merged.get("x1")>=80)]
allTheWaySuccessful = allTheWay[allTheWay.get("result")]
deepPasses = successful[(successful.get("x2")>102)&(successful.get("y2")<62)&(successful.get("y2")>18)&(successful.get("y1")<70)&(successful.get("y1")>5)]
longPasses = merged[merged.get("Distance")>=40]

# %%
df = attackingThird
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=df.get("x2"),y=df.get("y2"),fill = True,shade_lowest = False,alpha = .5,n_levels = 40,cmap = "magma")
for i in range(df.shape[0]):
    row = df.iloc[i]
    if row.get("key pass")==True:
        color = "purple"
    elif row.get("result"):
        color = "green"
    else:
        color = "red"
    
    plt.arrow(row.get("x1"),row.get("y1"),row.get("x2")-row.get("x1"),row.get("y2")-row.get("y1"),width = .2,alpha = .3,color = color)
plt.title("UCSD Attacking Passes")
# Out:
# Text(0.5, 1.0, 'UCSD Attacking Passes')

# %%
deepPasses.shape[0]
# Out:
# 5

# %%
df = allTheWay
pitch = VerticalPitch(half=True, axis=True)
fig, ax = pitch.draw()
kde = sns.kdeplot(y=df.get("x2"),x=df.get("y2"),fill = True,shade_lowest = False,alpha = .5,n_levels = 15,cmap = "magma")
for i in range(df.shape[0]):
    row = df.iloc[i]
    if row.get("key pass")==True:
        color = "purple"
        label = "Key Pass"
    elif row.get("result"):
        color = "green"
        label = "Successful Pass"
    else:
        color = "red"
        label = "Unsuccessful Pass"
    plt.arrow(row.get("y1"),row.get("x1"),(row.get("y2")-row.get("y1")),(row.get("x2")-row.get("x1")),width = .3,alpha = .4,color = color, label = label)
plt.title("UCSD's Deep Completed Passes")
handles, labels = plt.gca().get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
plt.legend(unique_labels.values(), unique_labels.keys())

# %%
perc = forward.groupby(["Player","result"]).count().reset_index()
for player in perc.get("Player").unique():
    limited = perc[perc.get("Player")==player]
    try:
        print("Player:",player, "Percentage:",limited[limited.get("result")==True].get("x1").iloc[0]/limited.get("x1").sum(), "Num Forward Passes:",limited.get("x1").sum())
    except:
        print(player, 0)
# Out:
# Player: Adam Percentage: 0.84 Num Forward Passes: 25
# Player: Brian Percentage: 1.0 Num Forward Passes: 2
# Player: Carter Percentage: 0.45 Num Forward Passes: 20
# Player: Cole Percentage: 0.6666666666666666 Num Forward Passes: 9
# Player: Connor Percentage: 0.6666666666666666 Num Forward Passes: 3
# Player: Evan Percentage: 0.64 Num Forward Passes: 25
# Player: James Percentage: 0.6 Num Forward Passes: 20
# Player: Jonah Percentage: 0.8095238095238095 Num Forward Passes: 21
# Player: Kai Percentage: 0.5 Num Forward Passes: 2
# Player: Max Percentage: 0.5714285714285714 Num Forward Passes: 7
# Player: McGee Percentage: 0.5714285714285714 Num Forward Passes: 7
# Player: Nolan Percentage: 0.5 Num Forward Passes: 20
# Player: Quinn Percentage: 0.631578947368421 Num Forward Passes: 19
# Player: Val Percentage: 1.0 Num Forward Passes: 3
# Player: Woody Percentage: 1.0 Num Forward Passes: 3

# %%
for player in merged.get("Player").unique():
    allPass = merged[merged.get("Player")==player].shape[0]
    forwardPass = forward[forward.get("Player")==player].shape[0]
    print("Player:",player,"Percentage Forward:",forwardPass/allPass, "Num Passes", allPass)
# Out:
# Player: Adam Percentage Forward: 0.78125 Num Passes 32
# Player: Brian Percentage Forward: 0.25 Num Passes 8
# Player: Carter Percentage Forward: 0.6666666666666666 Num Passes 30
# Player: Cole Percentage Forward: 0.5294117647058824 Num Passes 17
# Player: Connor Percentage Forward: 1.0 Num Passes 3
# Player: Evan Percentage Forward: 0.7352941176470589 Num Passes 34
# Player: James Percentage Forward: 0.8333333333333334 Num Passes 24
# Player: Jonah Percentage Forward: 0.5526315789473685 Num Passes 38
# Player: Kai Percentage Forward: 0.6666666666666666 Num Passes 3
# Player: Max Percentage Forward: 0.3181818181818182 Num Passes 22
# Player: McGee Percentage Forward: 0.5833333333333334 Num Passes 12
# Player: Nolan Percentage Forward: 1.0 Num Passes 20
# Player: Quinn Percentage Forward: 0.7037037037037037 Num Passes 27
# Player: Ryan Percentage Forward: 0.0 Num Passes 2
# Player: Val Percentage Forward: 0.375 Num Passes 8
# Player: Woody Percentage Forward: 1.0 Num Passes 3

# %%
print(longPasses.get("result").mean())
perc = longPasses.groupby(["Player","result"]).count().reset_index()
for player in perc.get("Player").unique():
    limited = perc[perc.get("Player")==player]
    try:
        print("Player:",player, "Percentage:",limited[limited.get("result")==True].get("x1").iloc[0]/limited.get("x1").sum(), "Num Long Passes:",limited.get("x1").sum())
    except:
        print(player, 0)
# Out:
# 0.45714285714285713
# Player: Adam Percentage: 1.0 Num Long Passes: 1
# Carter 0
# Player: Evan Percentage: 0.5 Num Long Passes: 8
# Player: James Percentage: 0.25 Num Long Passes: 4
# Player: Jonah Percentage: 1.0 Num Long Passes: 3
# Kai 0
# Player: Nolan Percentage: 0.4 Num Long Passes: 15
# Player: Quinn Percentage: 0.5 Num Long Passes: 2

# %%
for player in merged.get("Player").unique():   
    playerDf = merged[merged.get("Player")==player]
    df = playerDf
    pitch = Pitch(positional=True, axis=True,label=True)
    fig, ax = plt.subplots(figsize = (10,6))
    pitch.draw(ax=ax)
    kde = sns.kdeplot(x=df.get("x2"),y=df.get("y2"),fill = True,shade_lowest = False,alpha = .5,n_levels = 10,cmap = "magma")
    for i in range(df.shape[0]):
        row = df.iloc[i]
        if row.get("key pass")==True:
            color = "purple"
        elif row.get("result"):
            color = "green"
        else:
            color = "red"
        
        plt.arrow(row.get("x1"),row.get("y1"),row.get("x2")-row.get("x1"),row.get("y2")-row.get("y1"),width = .2,alpha = .3,color = color)
    plt.title(player+" Passes Destination")
    plt.show()
