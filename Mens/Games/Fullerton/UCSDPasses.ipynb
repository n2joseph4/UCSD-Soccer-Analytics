# %%
import pandas as pd
from mplsoccer import Pitch
from mplsoccer import VerticalPitch
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
htmlPlayers = {"Nolan":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330432870" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432870)" stroke-opacity="1" x1="54.6" y1="242.73" x2="96.6" y2="206.46"></line></g><g><defs><marker id="arrow_2330432877" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432877)" stroke-dasharray="6 4" stroke-opacity="1" x1="75.6" y1="75.33" x2="260.4" y2="89.28"></line></g><g><defs><marker id="arrow_2330432879" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432879)" stroke-opacity="1" x1="63" y1="122.76" x2="100.8" y2="78.12"></line></g><g><defs><marker id="arrow_2330432883" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432883)" stroke-dasharray="6 4" stroke-opacity="1" x1="12.6" y1="64.17" x2="184.8" y2="27.9"></line></g><g><defs><marker id="arrow_2330432914" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432914)" stroke-opacity="1" x1="37.8" y1="142.29" x2="113.4" y2="206.46"></line></g><g><defs><marker id="arrow_2330433014" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433014)" stroke-opacity="1" x1="29.4" y1="139.5" x2="54.6" y2="72.54"></line></g><g><defs><marker id="arrow_2330433080" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433080)" stroke-dasharray="6 4" stroke-opacity="1" x1="75.6" y1="136.71" x2="294" y2="75.33"></line></g><g><defs><marker id="arrow_2330433321" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433321)" stroke-opacity="1" x1="37.8" y1="167.4" x2="54.6" y2="206.46"></line></g><g><defs><marker id="arrow_2330433439" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433439)" stroke-opacity="1" x1="29.4" y1="150.66" x2="58.8" y2="242.73"></line></g><g><defs><marker id="arrow_2330433492" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433492)" stroke-opacity="1" x1="79.8" y1="69.75" x2="235.2" y2="36.27"></line></g><g><defs><marker id="arrow_2330433539" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433539)" stroke-opacity="1" x1="54.6" y1="125.55" x2="75.6" y2="131.13"></line></g><g><defs><marker id="arrow_2330433542" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433542)" stroke-opacity="1" x1="54.6" y1="136.71" x2="54.6" y2="198.09"></line></g><g><defs><marker id="arrow_2330433612" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433612)" stroke-opacity="1" x1="29.4" y1="139.5" x2="42" y2="212.04"></line></g><g><defs><marker id="arrow_2330433681" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433681)" stroke-dasharray="6 4" stroke-opacity="1" x1="25.2" y1="136.71" x2="142.8" y2="0"></line></g><g><defs><marker id="arrow_2330433690" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433690)" stroke-opacity="1" x1="58.8" y1="212.04" x2="247.8" y2="248.31"></line></g><g><defs><marker id="arrow_2330433816" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433816)" stroke-opacity="1" x1="50.4" y1="164.61" x2="84" y2="64.17"></line></g><g><defs><marker id="arrow_2330433820" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433820)" stroke-opacity="1" x1="29.4" y1="145.08" x2="63" y2="214.83"></line></g><g><defs><marker id="arrow_2330433851" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433851)" stroke-opacity="1" x1="21" y1="153.45" x2="197.4" y2="256.68"></line></g><g><defs><marker id="arrow_2330433896" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433896)" stroke-opacity="1" x1="54.6" y1="86.49" x2="109.2" y2="69.75"></line></g><g><defs><marker id="arrow_2330433904" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433904)" stroke-opacity="1" x1="25.2" y1="153.45" x2="54.6" y2="206.46"></line></g><g><defs><marker id="arrow_2330433926" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433926)" stroke-opacity="1" x1="63" y1="92.07" x2="92.4" y2="72.54"></line></g><g><defs><marker id="arrow_2330434191" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434191)" stroke-opacity="1" x1="25.2" y1="128.34" x2="155.4" y2="50.22"></line></g><g><defs><marker id="arrow_2330434347" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434347)" stroke-opacity="1" x1="84" y1="111.6" x2="109.2" y2="47.43"></line></g><g><defs><marker id="arrow_2330434523" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434523)" stroke-opacity="1" x1="63" y1="133.92" x2="96.6" y2="206.46"></line></g><g><defs><marker id="arrow_2330434594" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434594)" stroke-opacity="1" x1="37.8" y1="97.65" x2="105" y2="217.62"></line></g><g><defs><marker id="arrow_2330434636" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434636)" stroke-dasharray="6 4" stroke-opacity="1" x1="46.2" y1="111.6" x2="71.4" y2="36.27"></line></g></svg>',"Evan":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330432871" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432871)" stroke-dasharray="6 4" stroke-opacity="1" x1="96.6" y1="206.46" x2="281.4" y2="150.66"></line></g><g><defs><marker id="arrow_2330432913" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432913)" stroke-opacity="1" x1="113.4" y1="186.93" x2="37.8" y2="142.29"></line></g><g><defs><marker id="arrow_2330432915" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432915)" stroke-opacity="1" x1="113.4" y1="206.46" x2="121.8" y2="256.68"></line></g><g><defs><marker id="arrow_2330433076" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433076)" stroke-opacity="1" x1="147" y1="200.88" x2="151.2" y2="251.1"></line></g><g><defs><marker id="arrow_2330433092" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433092)" stroke-opacity="1" x1="117.6" y1="170.19" x2="109.2" y2="100.44"></line></g><g><defs><marker id="arrow_2330433323" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433323)" stroke-opacity="1" x1="54.6" y1="206.46" x2="84" y2="265.05"></line></g><g><defs><marker id="arrow_2330433328" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433328)" stroke-opacity="1" x1="33.6" y1="242.73" x2="176.4" y2="231.57"></line></g><g><defs><marker id="arrow_2330433375" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433375)" stroke-dasharray="6 4" stroke-opacity="1" x1="100.8" y1="251.1" x2="336" y2="279"></line></g><g><defs><marker id="arrow_2330433386" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433386)" stroke-dasharray="6 4" stroke-opacity="1" x1="142.8" y1="225.99" x2="302.4" y2="153.45"></line></g><g><defs><marker id="arrow_2330433490" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433490)" stroke-opacity="1" x1="126" y1="167.4" x2="63" y2="92.07"></line></g><g><defs><marker id="arrow_2330433521" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433521)" stroke-opacity="1" x1="117.6" y1="248.31" x2="147" y2="237.15"></line></g><g><defs><marker id="arrow_2330433541" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433541)" stroke-opacity="1" x1="75.6" y1="131.13" x2="54.6" y2="136.71"></line></g><g><defs><marker id="arrow_2330433544" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433544)" stroke-opacity="1" x1="88.2" y1="209.25" x2="180.6" y2="231.57"></line></g><g><defs><marker id="arrow_2330433584" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433584)" stroke-opacity="1" x1="151.2" y1="225.99" x2="256.2" y2="198.09"></line></g><g><defs><marker id="arrow_2330433614" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433614)" stroke-opacity="1" x1="42" y1="212.04" x2="231" y2="161.82"></line></g><g><defs><marker id="arrow_2330433797" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433797)" stroke-opacity="1" x1="105" y1="139.5" x2="306.6" y2="92.07"></line></g><g><defs><marker id="arrow_2330433826" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433826)" stroke-opacity="1" x1="71.4" y1="239.94" x2="130.2" y2="267.84"></line></g><g><defs><marker id="arrow_2330433907" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433907)" stroke-opacity="1" x1="113.4" y1="214.83" x2="193.2" y2="131.13"></line></g><g><defs><marker id="arrow_2330433935" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433935)" stroke-opacity="1" x1="121.8" y1="203.67" x2="126" y2="259.47"></line></g><g><defs><marker id="arrow_2330434158" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434158)" stroke-dasharray="6 4" stroke-opacity="1" x1="29.4" y1="192.51" x2="42" y2="214.83"></line></g><g><defs><marker id="arrow_2330434186" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434186)" stroke-opacity="1" x1="63" y1="200.88" x2="100.8" y2="195.3"></line></g><g><defs><marker id="arrow_2330434282" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434282)" stroke-dasharray="6 4" stroke-opacity="1" x1="105" y1="217.62" x2="138.6" y2="103.23"></line></g><g><defs><marker id="arrow_2330434297" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434297)" stroke-opacity="1" x1="130.2" y1="164.61" x2="302.4" y2="50.22"></line></g><g><defs><marker id="arrow_2330434423" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434423)" stroke-opacity="1" x1="218.4" y1="273.42" x2="340.2" y2="209.25"></line></g><g><defs><marker id="arrow_2330434484" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434484)" stroke-opacity="1" x1="138.6" y1="212.04" x2="235.2" y2="245.52"></line></g><g><defs><marker id="arrow_2330434488" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434488)" stroke-opacity="1" x1="184.8" y1="217.62" x2="189" y2="75.33"></line></g><g><defs><marker id="arrow_2330434502" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434502)" stroke-opacity="1" x1="92.4" y1="94.86" x2="180.6" y2="41.85"></line></g><g><defs><marker id="arrow_2330434517" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434517)" stroke-dasharray="6 4" stroke-opacity="1" x1="126" y1="265.05" x2="226.8" y2="279"></line></g><g><defs><marker id="arrow_2330434524" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434524)" stroke-opacity="1" x1="96.6" y1="206.46" x2="147" y2="203.67"></line></g><g><defs><marker id="arrow_2330434544" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434544)" stroke-opacity="1" x1="151.2" y1="186.93" x2="176.4" y2="69.75"></line></g><g><defs><marker id="arrow_2330434560" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434560)" stroke-dasharray="6 4" stroke-opacity="1" x1="151.2" y1="78.12" x2="310.8" y2="39.06"></line></g><g><defs><marker id="arrow_2330434568" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434568)" stroke-opacity="1" x1="117.6" y1="217.62" x2="138.6" y2="242.73"></line></g><g><defs><marker id="arrow_2330434585" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434585)" stroke-opacity="1" x1="130.2" y1="164.61" x2="189" y2="72.54"></line></g><g><defs><marker id="arrow_2330434635" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434635)" stroke-opacity="1" x1="117.6" y1="167.4" x2="46.2" y2="111.6"></line></g><g><defs><marker id="arrow_2330434640" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434640)" stroke-dasharray="6 4" stroke-opacity="1" x1="63" y1="228.78" x2="197.4" y2="279"></line></g></svg>',"Adam":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330432875" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432875)" stroke-opacity="1" x1="134.4" y1="30.69" x2="58.8" y2="80.91"></line></g><g><defs><marker id="arrow_2330432880" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432880)" stroke-opacity="1" x1="100.8" y1="78.12" x2="130.2" y2="100.44"></line></g><g><defs><marker id="arrow_2330432882" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432882)" stroke-opacity="1" x1="63" y1="36.27" x2="12.6" y2="64.17"></line></g><g><defs><marker id="arrow_2330432894" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432894)" stroke-dasharray="6 4" stroke-opacity="1" x1="117.6" y1="50.22" x2="138.6" y2="55.8"></line></g><g><defs><marker id="arrow_2330432932" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432932)" stroke-opacity="1" x1="4.2" y1="234.36" x2="126" y2="239.94"></line></g><g><defs><marker id="arrow_2330432963" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432963)" stroke-opacity="1" x1="168" y1="139.5" x2="235.2" y2="175.77"></line></g><g><defs><marker id="arrow_2330433000" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433000)" stroke-opacity="1" x1="50.4" y1="64.17" x2="117.6" y2="78.12"></line></g><g><defs><marker id="arrow_2330433012" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433012)" stroke-opacity="1" x1="33.6" y1="117.18" x2="29.4" y2="139.5"></line></g><g><defs><marker id="arrow_2330433015" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433015)" stroke-opacity="1" x1="54.6" y1="72.54" x2="117.6" y2="22.32"></line></g><g><defs><marker id="arrow_2330433093" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433093)" stroke-opacity="1" x1="109.2" y1="100.44" x2="121.8" y2="16.74"></line></g><g><defs><marker id="arrow_2330433247" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433247)" stroke-opacity="1" x1="201.6" y1="119.97" x2="260.4" y2="44.64"></line></g><g><defs><marker id="arrow_2330433250" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433250)" stroke-opacity="1" x1="226.8" y1="75.33" x2="264.6" y2="22.32"></line></g><g><defs><marker id="arrow_2330433346" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433346)" stroke-opacity="1" x1="79.8" y1="69.75" x2="109.2" y2="11.16"></line></g><g><defs><marker id="arrow_2330433411" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433411)" stroke-opacity="1" x1="142.8" y1="36.27" x2="168" y2="8.37"></line></g><g><defs><marker id="arrow_2330433413" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433413)" stroke-dasharray="6 4" stroke-opacity="1" x1="126" y1="39.06" x2="285.6" y2="61.38"></line></g><g><defs><marker id="arrow_2330433487" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433487)" stroke-opacity="1" x1="193.2" y1="122.76" x2="235.2" y2="181.35"></line></g><g><defs><marker id="arrow_2330433526" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433526)" stroke-opacity="1" x1="151.2" y1="114.39" x2="197.4" y2="36.27"></line></g><g><defs><marker id="arrow_2330433818" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433818)" stroke-opacity="1" x1="84" y1="64.17" x2="29.4" y2="145.08"></line></g><g><defs><marker id="arrow_2330433849" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433849)" stroke-opacity="1" x1="88.2" y1="161.82" x2="21" y2="153.45"></line></g><g><defs><marker id="arrow_2330433903" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433903)" stroke-opacity="1" x1="58.8" y1="30.69" x2="25.2" y2="153.45"></line></g><g><defs><marker id="arrow_2330433927" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433927)" stroke-opacity="1" x1="92.4" y1="72.54" x2="121.8" y2="86.49"></line></g><g><defs><marker id="arrow_2330433931" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433931)" stroke-dasharray="6 4" stroke-opacity="1" x1="58.8" y1="19.53" x2="100.8" y2="33.48"></line></g><g><defs><marker id="arrow_2330433941" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433941)" stroke-opacity="1" x1="113.4" y1="125.55" x2="168" y2="117.18"></line></g><g><defs><marker id="arrow_2330433992" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433992)" stroke-opacity="1" x1="92.4" y1="72.54" x2="121.8" y2="72.54"></line></g><g><defs><marker id="arrow_2330433996" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433996)" stroke-opacity="1" x1="142.8" y1="55.8" x2="172.2" y2="69.75"></line></g><g><defs><marker id="arrow_2330434026" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434026)" stroke-dasharray="6 4" stroke-opacity="1" x1="33.6" y1="139.5" x2="268.8" y2="212.04"></line></g><g><defs><marker id="arrow_2330434060" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434060)" stroke-dasharray="6 4" stroke-opacity="1" x1="50.4" y1="133.92" x2="168" y2="256.68"></line></g><g><defs><marker id="arrow_2330434077" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434077)" stroke-opacity="1" x1="42" y1="103.23" x2="63" y2="64.17"></line></g><g><defs><marker id="arrow_2330434132" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434132)" stroke-opacity="1" x1="92.4" y1="55.8" x2="176.4" y2="36.27"></line></g><g><defs><marker id="arrow_2330434188" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434188)" stroke-opacity="1" x1="109.2" y1="86.49" x2="134.4" y2="44.64"></line></g><g><defs><marker id="arrow_2330434190" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434190)" stroke-opacity="1" x1="33.6" y1="89.28" x2="25.2" y2="128.34"></line></g><g><defs><marker id="arrow_2330434203" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434203)" stroke-opacity="1" x1="88.2" y1="66.96" x2="281.4" y2="27.9"></line></g><g><defs><marker id="arrow_2330434240" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434240)" stroke-opacity="1" x1="168" y1="33.48" x2="239.4" y2="58.59"></line></g><g><defs><marker id="arrow_2330434264" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434264)" stroke-opacity="1" x1="176.4" y1="50.22" x2="348.6" y2="44.64"></line></g><g><defs><marker id="arrow_2330434308" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434308)" stroke-dasharray="6 4" stroke-opacity="1" x1="247.8" y1="58.59" x2="298.2" y2="80.91"></line></g><g><defs><marker id="arrow_2330434311" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434311)" stroke-opacity="1" x1="58.8" y1="47.43" x2="151.2" y2="47.43"></line></g><g><defs><marker id="arrow_2330434348" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434348)" stroke-opacity="1" x1="109.2" y1="47.43" x2="176.4" y2="58.59"></line></g><g><defs><marker id="arrow_2330434374" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434374)" stroke-opacity="1" x1="172.2" y1="22.32" x2="252" y2="53.01"></line></g><g><defs><marker id="arrow_2330434395" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434395)" stroke-dasharray="6 4" stroke-opacity="1" x1="210" y1="13.95" x2="235.2" y2="64.17"></line></g><g><defs><marker id="arrow_2330434489" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434489)" stroke-opacity="1" x1="189" y1="75.33" x2="289.8" y2="41.85"></line></g><g><defs><marker id="arrow_2330434492" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434492)" stroke-dasharray="6 4" stroke-opacity="1" x1="256.2" y1="30.69" x2="247.8" y2="0"></line></g><g><defs><marker id="arrow_2330434493" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434493)" stroke-opacity="1" x1="126" y1="58.59" x2="193.2" y2="69.75"></line></g><g><defs><marker id="arrow_2330434522" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434522)" stroke-opacity="1" x1="126" y1="25.11" x2="63" y2="133.92"></line></g><g><defs><marker id="arrow_2330434543" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434543)" stroke-opacity="1" x1="184.8" y1="78.12" x2="151.2" y2="186.93"></line></g><g><defs><marker id="arrow_2330434545" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434545)" stroke-opacity="1" x1="176.4" y1="69.75" x2="239.4" y2="27.9"></line></g><g><defs><marker id="arrow_2330434555" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434555)" stroke-opacity="1" x1="163.8" y1="72.54" x2="247.8" y2="27.9"></line></g><g><defs><marker id="arrow_2330434557" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434557)" stroke-opacity="1" x1="159.6" y1="8.37" x2="231" y2="41.85"></line></g></svg>',"Keenai":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330434564" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434564)" stroke-opacity="1" x1="117.6" y1="75.33" x2="147" y2="80.91"></line></g><g><defs><marker id="arrow_2330434572" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434572)" stroke-opacity="1" x1="222.6" y1="145.08" x2="277.2" y2="203.67"></line></g><g><defs><marker id="arrow_2330434586" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434586)" stroke-opacity="1" x1="189" y1="72.54" x2="235.2" y2="41.85"></line></g><g><defs><marker id="arrow_2330434599" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434599)" stroke-opacity="1" x1="84" y1="83.7" x2="130.2" y2="16.74"></line></g></svg>',"Carter":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330432898" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432898)" stroke-opacity="1" x1="142.8" y1="5.58" x2="134.4" y2="30.69"></line></g><g><defs><marker id="arrow_2330432924" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432924)" stroke-dasharray="6 4" stroke-opacity="1" x1="46.2" y1="64.17" x2="222.6" y2="55.8"></line></g><g><defs><marker id="arrow_2330433016" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433016)" stroke-opacity="1" x1="117.6" y1="22.32" x2="163.8" y2="61.38"></line></g><g><defs><marker id="arrow_2330433018" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433018)" stroke-opacity="1" x1="147" y1="27.9" x2="218.4" y2="5.58"></line></g><g><defs><marker id="arrow_2330433029" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433029)" stroke-opacity="1" x1="298.2" y1="72.54" x2="361.2" y2="39.06"></line></g><g><defs><marker id="arrow_2330433064" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433064)" stroke-opacity="1" x1="105" y1="8.37" x2="138.6" y2="11.16"></line></g><g><defs><marker id="arrow_2330433095" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433095)" stroke-opacity="1" x1="121.8" y1="16.74" x2="184.8" y2="72.54"></line></g><g><defs><marker id="arrow_2330433131" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433131)" stroke-opacity="1" x1="138.6" y1="78.12" x2="163.8" y2="128.34"></line></g><g><defs><marker id="arrow_2330433141" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433141)" stroke-opacity="1" x1="289.8" y1="172.98" x2="264.6" y2="186.93"></line></g><g><defs><marker id="arrow_2330433163" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433163)" stroke-opacity="1" x1="126" y1="108.81" x2="113.4" y2="253.89"></line></g><g><defs><marker id="arrow_2330433195" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433195)" stroke-opacity="1" x1="285.6" y1="33.48" x2="310.8" y2="64.17"></line></g><g><defs><marker id="arrow_2330433249" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433249)" stroke-opacity="1" x1="260.4" y1="44.64" x2="226.8" y2="75.33"></line></g><g><defs><marker id="arrow_2330433252" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433252)" stroke-opacity="1" x1="264.6" y1="22.32" x2="256.2" y2="80.91"></line></g><g><defs><marker id="arrow_2330433284" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433284)" stroke-opacity="1" x1="176.4" y1="11.16" x2="176.4" y2="47.43"></line></g><g><defs><marker id="arrow_2330433347" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433347)" stroke-dasharray="6 4" stroke-opacity="1" x1="109.2" y1="11.16" x2="163.8" y2="19.53"></line></g><g><defs><marker id="arrow_2330433410" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433410)" stroke-opacity="1" x1="201.6" y1="33.48" x2="142.8" y2="36.27"></line></g><g><defs><marker id="arrow_2330433412" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433412)" stroke-opacity="1" x1="168" y1="8.37" x2="126" y2="39.06"></line></g><g><defs><marker id="arrow_2330433528" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433528)" stroke-opacity="1" x1="289.8" y1="41.85" x2="327.6" y2="103.23"></line></g><g><defs><marker id="arrow_2330433589" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433589)" stroke-dasharray="6 4" stroke-opacity="1" x1="197.4" y1="86.49" x2="235.2" y2="89.28"></line></g><g><defs><marker id="arrow_2330433626" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433626)" stroke-opacity="1" x1="58.8" y1="122.76" x2="138.6" y2="147.87"></line></g><g><defs><marker id="arrow_2330433656" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433656)" stroke-opacity="1" x1="218.4" y1="22.32" x2="302.4" y2="8.37"></line></g><g><defs><marker id="arrow_2330433659" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433659)" stroke-opacity="1" x1="247.8" y1="41.85" x2="302.4" y2="50.22"></line></g><g><defs><marker id="arrow_2330433671" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433671)" stroke-opacity="1" x1="159.6" y1="2.79" x2="235.2" y2="8.37"></line></g><g><defs><marker id="arrow_2330433902" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433902)" stroke-opacity="1" x1="142.8" y1="16.74" x2="58.8" y2="30.69"></line></g><g><defs><marker id="arrow_2330433914" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433914)" stroke-dasharray="6 4" stroke-opacity="1" x1="373.8" y1="75.33" x2="361.2" y2="83.7"></line></g><g><defs><marker id="arrow_2330433930" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433930)" stroke-opacity="1" x1="134.4" y1="19.53" x2="58.8" y2="19.53"></line></g><g><defs><marker id="arrow_2330434013" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434013)" stroke-dasharray="6 4" stroke-opacity="1" x1="252" y1="64.17" x2="252" y2="100.44"></line></g><g><defs><marker id="arrow_2330434079" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434079)" stroke-dasharray="6 4" stroke-opacity="1" x1="63" y1="64.17" x2="134.4" y2="50.22"></line></g><g><defs><marker id="arrow_2330434189" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434189)" stroke-opacity="1" x1="134.4" y1="44.64" x2="33.6" y2="89.28"></line></g><g><defs><marker id="arrow_2330434213" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434213)" stroke-opacity="1" x1="151.2" y1="22.32" x2="126" y2="13.95"></line></g><g><defs><marker id="arrow_2330434217" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434217)" stroke-opacity="1" x1="235.2" y1="16.74" x2="243.6" y2="19.53"></line></g><g><defs><marker id="arrow_2330434256" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434256)" stroke-opacity="1" x1="260.4" y1="47.43" x2="306.6" y2="89.28"></line></g><g><defs><marker id="arrow_2330434262" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434262)" stroke-opacity="1" x1="277.2" y1="13.95" x2="176.4" y2="50.22"></line></g><g><defs><marker id="arrow_2330434306" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434306)" stroke-opacity="1" x1="289.8" y1="5.58" x2="306.6" y2="41.85"></line></g><g><defs><marker id="arrow_2330434310" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434310)" stroke-opacity="1" x1="121.8" y1="22.32" x2="58.8" y2="47.43"></line></g><g><defs><marker id="arrow_2330434371" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434371)" stroke-opacity="1" x1="231" y1="30.69" x2="172.2" y2="22.32"></line></g><g><defs><marker id="arrow_2330434389" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434389)" stroke-dasharray="6 4" stroke-opacity="1" x1="147" y1="25.11" x2="281.4" y2="66.96"></line></g><g><defs><marker id="arrow_2330434451" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434451)" stroke-dasharray="6 4" stroke-opacity="1" x1="193.2" y1="39.06" x2="298.2" y2="72.54"></line></g><g><defs><marker id="arrow_2330434457" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434457)" stroke-opacity="1" x1="260.4" y1="22.32" x2="264.6" y2="50.22"></line></g><g><defs><marker id="arrow_2330434508" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434508)" stroke-dasharray="6 4" stroke-opacity="1" x1="92.4" y1="97.65" x2="235.2" y2="184.14"></line></g><g><defs><marker id="arrow_2330434509" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434509)" stroke-opacity="1" x1="117.6" y1="55.8" x2="163.8" y2="156.24"></line></g><g><defs><marker id="arrow_2330434534" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434534)" stroke-opacity="1" x1="294" y1="156.24" x2="357" y2="36.27"></line></g><g><defs><marker id="arrow_2330434536" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434536)" stroke-dasharray="6 4" stroke-opacity="1" x1="378" y1="33.48" x2="420" y2="209.25"></line></g></svg>',"Cole":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330432908" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432908)" stroke-opacity="1" x1="331.8" y1="242.73" x2="323.4" y2="186.93"></line></g><g><defs><marker id="arrow_2330432917" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432917)" stroke-opacity="1" x1="197.4" y1="234.36" x2="189" y2="189.72"></line></g><g><defs><marker id="arrow_2330432934" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432934)" stroke-opacity="1" x1="105" y1="270.63" x2="105" y2="217.62"></line></g><g><defs><marker id="arrow_2330432940" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432940)" stroke-dasharray="6 4" stroke-opacity="1" x1="361.2" y1="234.36" x2="411.6" y2="139.5"></line></g><g><defs><marker id="arrow_2330433003" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433003)" stroke-opacity="1" x1="134.4" y1="122.76" x2="134.4" y2="153.45"></line></g><g><defs><marker id="arrow_2330433007" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433007)" stroke-opacity="1" x1="134.4" y1="153.45" x2="189" y2="128.34"></line></g><g><defs><marker id="arrow_2330433073" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433073)" stroke-opacity="1" x1="231" y1="223.2" x2="172.2" y2="231.57"></line></g><g><defs><marker id="arrow_2330433084" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433084)" stroke-opacity="1" x1="142.8" y1="242.73" x2="172.2" y2="234.36"></line></g><g><defs><marker id="arrow_2330433090" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433090)" stroke-opacity="1" x1="134.4" y1="234.36" x2="84" y2="245.52"></line></g><g><defs><marker id="arrow_2330433104" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433104)" stroke-dasharray="6 4" stroke-opacity="1" x1="411.6" y1="206.46" x2="403.2" y2="192.51"></line></g><g><defs><marker id="arrow_2330433145" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433145)" stroke-opacity="1" x1="336" y1="259.47" x2="302.4" y2="192.51"></line></g><g><defs><marker id="arrow_2330433240" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433240)" stroke-dasharray="6 4" stroke-opacity="1" x1="382.2" y1="234.36" x2="373.8" y2="164.61"></line></g><g><defs><marker id="arrow_2330433293" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433293)" stroke-opacity="1" x1="130.2" y1="265.05" x2="189" y2="195.3"></line></g><g><defs><marker id="arrow_2330433858" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433858)" stroke-opacity="1" x1="193.2" y1="270.63" x2="193.2" y2="203.67"></line></g><g><defs><marker id="arrow_2330433864" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433864)" stroke-dasharray="6 4" stroke-opacity="1" x1="281.4" y1="273.42" x2="231" y2="245.52"></line></g><g><defs><marker id="arrow_2330433952" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433952)" stroke-opacity="1" x1="327.6" y1="267.84" x2="260.4" y2="262.26"></line></g><g><defs><marker id="arrow_2330433967" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433967)" stroke-opacity="1" x1="344.4" y1="265.05" x2="298.2" y2="273.42"></line></g><g><defs><marker id="arrow_2330434036" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434036)" stroke-dasharray="6 4" stroke-opacity="1" x1="54.6" y1="170.19" x2="117.6" y2="89.28"></line></g><g><defs><marker id="arrow_2330434067" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434067)" stroke-opacity="1" x1="113.4" y1="265.05" x2="113.4" y2="276.21"></line></g><g><defs><marker id="arrow_2330434092" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434092)" stroke-dasharray="6 4" stroke-opacity="1" x1="142.8" y1="279" x2="197.4" y2="223.2"></line></g><g><defs><marker id="arrow_2330434113" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434113)" stroke-opacity="1" x1="147" y1="270.63" x2="117.6" y2="253.89"></line></g><g><defs><marker id="arrow_2330434171" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434171)" stroke-opacity="1" x1="142.8" y1="267.84" x2="117.6" y2="209.25"></line></g></svg>',"Woody":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330433661" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433661)" stroke-opacity="1" x1="344.4" y1="53.01" x2="386.4" y2="25.11"></line></g><g><defs><marker id="arrow_2330434480" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434480)" stroke-opacity="1" x1="142.8" y1="200.88" x2="184.8" y2="195.3"></line></g><g><defs><marker id="arrow_2330434510" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434510)" stroke-opacity="1" x1="163.8" y1="156.24" x2="151.2" y2="234.36"></line></g><g><defs><marker id="arrow_2330434533" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434533)" stroke-opacity="1" x1="306.6" y1="220.41" x2="294" y2="156.24"></line></g><g><defs><marker id="arrow_2330434547" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434547)" stroke-opacity="1" x1="226.8" y1="64.17" x2="273" y2="78.12"></line></g><g><defs><marker id="arrow_2330434548" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434548)" stroke-opacity="1" x1="226.8" y1="50.22" x2="294" y2="30.69"></line></g><g><defs><marker id="arrow_2330434578" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434578)" stroke-opacity="1" x1="256.2" y1="214.83" x2="319.2" y2="206.46"></line></g><g><defs><marker id="arrow_2330434579" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434579)" stroke-dasharray="6 4" stroke-opacity="1" x1="319.2" y1="206.46" x2="302.4" y2="161.82"></line></g><g><defs><marker id="arrow_2330434624" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434624)" stroke-opacity="1" x1="277.2" y1="41.85" x2="298.2" y2="13.95"></line></g><g><defs><marker id="arrow_2330434626" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434626)" stroke-opacity="1" x1="268.8" y1="39.06" x2="277.2" y2="61.38"></line></g></svg>',"Quinn":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330432906" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432906)" stroke-opacity="1" x1="302.4" y1="248.31" x2="285.6" y2="212.04"></line></g><g><defs><marker id="arrow_2330432920" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432920)" stroke-dasharray="6 4" stroke-opacity="1" x1="231" y1="220.41" x2="323.4" y2="78.12"></line></g><g><defs><marker id="arrow_2330432965" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432965)" stroke-dasharray="6 4" stroke-opacity="1" x1="235.2" y1="175.77" x2="327.6" y2="203.67"></line></g><g><defs><marker id="arrow_2330433072" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433072)" stroke-opacity="1" x1="168" y1="159.03" x2="231" y2="223.2"></line></g><g><defs><marker id="arrow_2330433193" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433193)" stroke-opacity="1" x1="147" y1="159.03" x2="285.6" y2="33.48"></line></g><g><defs><marker id="arrow_2330433225" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433225)" stroke-opacity="1" x1="105" y1="170.19" x2="109.2" y2="111.6"></line></g><g><defs><marker id="arrow_2330433264" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433264)" stroke-dasharray="6 4" stroke-opacity="1" x1="256.2" y1="80.91" x2="176.4" y2="0"></line></g><g><defs><marker id="arrow_2330433383" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433383)" stroke-opacity="1" x1="222.6" y1="245.52" x2="201.6" y2="259.47"></line></g><g><defs><marker id="arrow_2330433389" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433389)" stroke-opacity="1" x1="252" y1="234.36" x2="264.6" y2="256.68"></line></g><g><defs><marker id="arrow_2330433441" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433441)" stroke-dasharray="6 4" stroke-opacity="1" x1="109.2" y1="270.63" x2="113.4" y2="206.46"></line></g><g><defs><marker id="arrow_2330433473" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433473)" stroke-opacity="1" x1="344.4" y1="251.1" x2="357" y2="270.63"></line></g><g><defs><marker id="arrow_2330433479" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433479)" stroke-dasharray="6 4" stroke-opacity="1" x1="331.8" y1="256.68" x2="315" y2="239.94"></line></g><g><defs><marker id="arrow_2330433567" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433567)" stroke-dasharray="6 4" stroke-opacity="1" x1="147" y1="139.5" x2="252" y2="41.85"></line></g><g><defs><marker id="arrow_2330433587" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433587)" stroke-opacity="1" x1="226.8" y1="142.29" x2="197.4" y2="86.49"></line></g><g><defs><marker id="arrow_2330433848" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433848)" stroke-opacity="1" x1="138.6" y1="242.73" x2="88.2" y2="161.82"></line></g><g><defs><marker id="arrow_2330433860" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433860)" stroke-opacity="1" x1="197.4" y1="259.47" x2="159.6" y2="270.63"></line></g><g><defs><marker id="arrow_2330433887" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433887)" stroke-opacity="1" x1="264.6" y1="195.3" x2="336" y2="83.7"></line></g><g><defs><marker id="arrow_2330433901" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433901)" stroke-opacity="1" x1="109.2" y1="69.75" x2="142.8" y2="16.74"></line></g><g><defs><marker id="arrow_2330433911" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433911)" stroke-opacity="1" x1="231" y1="125.55" x2="336" y2="64.17"></line></g><g><defs><marker id="arrow_2330433929" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433929)" stroke-opacity="1" x1="121.8" y1="86.49" x2="134.4" y2="19.53"></line></g><g><defs><marker id="arrow_2330433950" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433950)" stroke-dasharray="6 4" stroke-opacity="1" x1="222.6" y1="131.13" x2="226.8" y2="150.66"></line></g><g><defs><marker id="arrow_2330433971" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433971)" stroke-opacity="1" x1="285.6" y1="234.36" x2="348.6" y2="239.94"></line></g><g><defs><marker id="arrow_2330433993" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433993)" stroke-opacity="1" x1="121.8" y1="72.54" x2="100.8" y2="55.8"></line></g><g><defs><marker id="arrow_2330434066" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434066)" stroke-opacity="1" x1="96.6" y1="212.04" x2="113.4" y2="265.05"></line></g><g><defs><marker id="arrow_2330434090" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434090)" stroke-opacity="1" x1="63" y1="145.08" x2="142.8" y2="279"></line></g><g><defs><marker id="arrow_2330434118" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434118)" stroke-opacity="1" x1="147" y1="203.67" x2="193.2" y2="203.67"></line></g><g><defs><marker id="arrow_2330434212" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434212)" stroke-opacity="1" x1="172.2" y1="44.64" x2="151.2" y2="22.32"></line></g><g><defs><marker id="arrow_2330434303" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434303)" stroke-opacity="1" x1="319.2" y1="30.69" x2="289.8" y2="5.58"></line></g><g><defs><marker id="arrow_2330434307" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434307)" stroke-dasharray="6 4" stroke-opacity="1" x1="306.6" y1="41.85" x2="336" y2="36.27"></line></g><g><defs><marker id="arrow_2330434314" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434314)" stroke-opacity="1" x1="151.2" y1="47.43" x2="201.6" y2="39.06"></line></g><g><defs><marker id="arrow_2330434353" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434353)" stroke-opacity="1" x1="147" y1="72.54" x2="130.2" y2="44.64"></line></g><g><defs><marker id="arrow_2330434375" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434375)" stroke-dasharray="6 4" stroke-opacity="1" x1="252" y1="53.01" x2="411.6" y2="19.53"></line></g><g><defs><marker id="arrow_2330434428" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434428)" stroke-opacity="1" x1="113.4" y1="150.66" x2="113.4" y2="58.59"></line></g><g><defs><marker id="arrow_2330434458" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434458)" stroke-opacity="1" x1="264.6" y1="50.22" x2="260.4" y2="8.37"></line></g></svg>',"Val":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330433406" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433406)" stroke-opacity="1" x1="289.8" y1="55.8" x2="243.6" y2="58.59"></line></g><g><defs><marker id="arrow_2330433569" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433569)" stroke-opacity="1" x1="226.8" y1="11.16" x2="260.4" y2="13.95"></line></g><g><defs><marker id="arrow_2330433658" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433658)" stroke-opacity="1" x1="302.4" y1="8.37" x2="247.8" y2="41.85"></line></g><g><defs><marker id="arrow_2330433663" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433663)" stroke-dasharray="6 4" stroke-opacity="1" x1="399" y1="19.53" x2="407.4" y2="231.57"></line></g><g><defs><marker id="arrow_2330433670" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433670)" stroke-opacity="1" x1="126" y1="33.48" x2="159.6" y2="2.79"></line></g><g><defs><marker id="arrow_2330434214" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434214)" stroke-opacity="1" x1="126" y1="13.95" x2="163.8" y2="47.43"></line></g><g><defs><marker id="arrow_2330434269" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434269)" stroke-opacity="1" x1="331.8" y1="36.27" x2="306.6" y2="58.59"></line></g><g><defs><marker id="arrow_2330434453" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434453)" stroke-opacity="1" x1="310.8" y1="58.59" x2="323.4" y2="89.28"></line></g><g><defs><marker id="arrow_2330434456" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434456)" stroke-opacity="1" x1="331.8" y1="11.16" x2="260.4" y2="22.32"></line></g><g><defs><marker id="arrow_2330434521" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434521)" stroke-opacity="1" x1="130.2" y1="128.34" x2="126" y2="25.11"></line></g><g><defs><marker id="arrow_2330434535" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434535)" stroke-opacity="1" x1="357" y1="36.27" x2="315" y2="69.75"></line></g><g><defs><marker id="arrow_2330434546" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434546)" stroke-dasharray="6 4" stroke-opacity="1" x1="239.4" y1="27.9" x2="260.4" y2="55.8"></line></g><g><defs><marker id="arrow_2330434550" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434550)" stroke-dasharray="6 4" stroke-opacity="1" x1="327.6" y1="19.53" x2="323.4" y2="58.59"></line></g><g><defs><marker id="arrow_2330434553" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434553)" stroke-opacity="1" x1="277.2" y1="8.37" x2="218.4" y2="30.69"></line></g><g><defs><marker id="arrow_2330434556" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434556)" stroke-opacity="1" x1="247.8" y1="27.9" x2="159.6" y2="8.37"></line></g><g><defs><marker id="arrow_2330434558" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434558)" stroke-dasharray="6 4" stroke-opacity="1" x1="231" y1="41.85" x2="176.4" y2="78.12"></line></g><g><defs><marker id="arrow_2330434587" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434587)" stroke-opacity="1" x1="235.2" y1="41.85" x2="273" y2="36.27"></line></g><g><defs><marker id="arrow_2330434590" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434590)" stroke-opacity="1" x1="310.8" y1="19.53" x2="264.6" y2="64.17"></line></g><g><defs><marker id="arrow_2330434593" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434593)" stroke-dasharray="6 4" stroke-opacity="1" x1="319.2" y1="53.01" x2="315" y2="61.38"></line></g></svg>',"James":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330432902" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432902)" stroke-opacity="1" x1="306.6" y1="217.62" x2="390.6" y2="242.73"></line></g><g><defs><marker id="arrow_2330432912" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432912)" stroke-opacity="1" x1="159.6" y1="195.3" x2="113.4" y2="186.93"></line></g><g><defs><marker id="arrow_2330432916" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432916)" stroke-opacity="1" x1="121.8" y1="256.68" x2="197.4" y2="234.36"></line></g><g><defs><marker id="arrow_2330432936" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432936)" stroke-opacity="1" x1="117.6" y1="251.1" x2="189" y2="225.99"></line></g><g><defs><marker id="arrow_2330432949" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432949)" stroke-opacity="1" x1="117.6" y1="253.89" x2="277.2" y2="225.99"></line></g><g><defs><marker id="arrow_2330432962" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432962)" stroke-opacity="1" x1="239.4" y1="270.63" x2="168" y2="139.5"></line></g><g><defs><marker id="arrow_2330433075" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433075)" stroke-opacity="1" x1="172.2" y1="231.57" x2="147" y2="200.88"></line></g><g><defs><marker id="arrow_2330433078" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433078)" stroke-opacity="1" x1="151.2" y1="251.1" x2="63" y2="136.71"></line></g><g><defs><marker id="arrow_2330433083" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433083)" stroke-opacity="1" x1="8.4" y1="200.88" x2="142.8" y2="242.73"></line></g><g><defs><marker id="arrow_2330433091" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433091)" stroke-opacity="1" x1="84" y1="245.52" x2="117.6" y2="170.19"></line></g><g><defs><marker id="arrow_2330433118" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433118)" stroke-dasharray="6 4" stroke-opacity="1" x1="29.4" y1="251.1" x2="54.6" y2="237.15"></line></g><g><defs><marker id="arrow_2330433120" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433120)" stroke-dasharray="6 4" stroke-opacity="1" x1="42" y1="239.94" x2="117.6" y2="228.78"></line></g><g><defs><marker id="arrow_2330433154" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433154)" stroke-opacity="1" x1="310.8" y1="200.88" x2="365.4" y2="100.44"></line></g><g><defs><marker id="arrow_2330433159" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433159)" stroke-opacity="1" x1="142.8" y1="225.99" x2="126" y2="108.81"></line></g><g><defs><marker id="arrow_2330433165" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433165)" stroke-dasharray="6 4" stroke-opacity="1" x1="113.4" y1="253.89" x2="323.4" y2="228.78"></line></g><g><defs><marker id="arrow_2330433245" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433245)" stroke-opacity="1" x1="302.4" y1="248.31" x2="201.6" y2="119.97"></line></g><g><defs><marker id="arrow_2330433291" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433291)" stroke-opacity="1" x1="88.2" y1="203.67" x2="130.2" y2="265.05"></line></g><g><defs><marker id="arrow_2330433324" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433324)" stroke-opacity="1" x1="84" y1="265.05" x2="96.6" y2="217.62"></line></g><g><defs><marker id="arrow_2330433327" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433327)" stroke-opacity="1" x1="71.4" y1="267.84" x2="33.6" y2="242.73"></line></g><g><defs><marker id="arrow_2330433355" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433355)" stroke-dasharray="6 4" stroke-opacity="1" x1="37.8" y1="178.56" x2="105" y2="159.03"></line></g><g><defs><marker id="arrow_2330433385" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433385)" stroke-opacity="1" x1="201.6" y1="259.47" x2="142.8" y2="225.99"></line></g><g><defs><marker id="arrow_2330433421" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433421)" stroke-dasharray="6 4" stroke-opacity="1" x1="226.8" y1="248.31" x2="319.2" y2="200.88"></line></g><g><defs><marker id="arrow_2330433438" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433438)" stroke-opacity="1" x1="109.2" y1="256.68" x2="29.4" y2="150.66"></line></g><g><defs><marker id="arrow_2330433440" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433440)" stroke-opacity="1" x1="58.8" y1="242.73" x2="109.2" y2="270.63"></line></g><g><defs><marker id="arrow_2330433454" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433454)" stroke-opacity="1" x1="285.6" y1="231.57" x2="239.4" y2="200.88"></line></g><g><defs><marker id="arrow_2330433486" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433486)" stroke-opacity="1" x1="285.6" y1="259.47" x2="193.2" y2="122.76"></line></g><g><defs><marker id="arrow_2330433489" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433489)" stroke-opacity="1" x1="210" y1="248.31" x2="126" y2="167.4"></line></g><g><defs><marker id="arrow_2330433827" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433827)" stroke-opacity="1" x1="130.2" y1="267.84" x2="163.8" y2="248.31"></line></g><g><defs><marker id="arrow_2330433840" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433840)" stroke-dasharray="6 4" stroke-opacity="1" x1="96.6" y1="273.42" x2="163.8" y2="248.31"></line></g><g><defs><marker id="arrow_2330433862" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433862)" stroke-opacity="1" x1="159.6" y1="270.63" x2="281.4" y2="273.42"></line></g><g><defs><marker id="arrow_2330433936" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433936)" stroke-dasharray="6 4" stroke-opacity="1" x1="126" y1="259.47" x2="239.4" y2="242.73"></line></g><g><defs><marker id="arrow_2330433940" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433940)" stroke-opacity="1" x1="159.6" y1="267.84" x2="113.4" y2="125.55"></line></g><g><defs><marker id="arrow_2330433954" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433954)" stroke-opacity="1" x1="260.4" y1="262.26" x2="382.2" y2="231.57"></line></g><g><defs><marker id="arrow_2330433964" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433964)" stroke-opacity="1" x1="340.2" y1="262.26" x2="344.4" y2="265.05"></line></g><g><defs><marker id="arrow_2330433969" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433969)" stroke-opacity="1" x1="298.2" y1="273.42" x2="285.6" y2="234.36"></line></g><g><defs><marker id="arrow_2330434065" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434065)" stroke-opacity="1" x1="29.4" y1="228.78" x2="96.6" y2="212.04"></line></g><g><defs><marker id="arrow_2330434071" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434071)" stroke-opacity="1" x1="105" y1="262.26" x2="96.6" y2="225.99"></line></g><g><defs><marker id="arrow_2330434114" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434114)" stroke-opacity="1" x1="117.6" y1="253.89" x2="155.4" y2="212.04"></line></g><g><defs><marker id="arrow_2330434116" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434116)" stroke-opacity="1" x1="130.2" y1="259.47" x2="163.8" y2="228.78"></line></g><g><defs><marker id="arrow_2330434167" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434167)" stroke-dasharray="6 4" stroke-opacity="1" x1="71.4" y1="206.46" x2="117.6" y2="203.67"></line></g><g><defs><marker id="arrow_2330434169" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434169)" stroke-opacity="1" x1="67.2" y1="234.36" x2="142.8" y2="267.84"></line></g><g><defs><marker id="arrow_2330434173" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434173)" stroke-opacity="1" x1="67.2" y1="242.73" x2="126" y2="198.09"></line></g><g><defs><marker id="arrow_2330434221" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434221)" stroke-opacity="1" x1="88.2" y1="234.36" x2="138.6" y2="259.47"></line></g><g><defs><marker id="arrow_2330434337" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434337)" stroke-opacity="1" x1="218.4" y1="253.89" x2="306.6" y2="217.62"></line></g><g><defs><marker id="arrow_2330434343" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434343)" stroke-opacity="1" x1="130.2" y1="267.84" x2="63" y2="178.56"></line></g><g><defs><marker id="arrow_2330434419" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434419)" stroke-opacity="1" x1="277.2" y1="259.47" x2="310.8" y2="273.42"></line></g><g><defs><marker id="arrow_2330434422" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434422)" stroke-opacity="1" x1="281.4" y1="259.47" x2="218.4" y2="273.42"></line></g><g><defs><marker id="arrow_2330434467" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434467)" stroke-dasharray="6 4" stroke-opacity="1" x1="138.6" y1="259.47" x2="382.2" y2="237.15"></line></g><g><defs><marker id="arrow_2330434470" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434470)" stroke-opacity="1" x1="336" y1="273.42" x2="277.2" y2="253.89"></line></g><g><defs><marker id="arrow_2330434483" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434483)" stroke-opacity="1" x1="130.2" y1="234.36" x2="138.6" y2="212.04"></line></g><g><defs><marker id="arrow_2330434487" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434487)" stroke-opacity="1" x1="222.6" y1="267.84" x2="184.8" y2="217.62"></line></g><g><defs><marker id="arrow_2330434511" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434511)" stroke-opacity="1" x1="151.2" y1="234.36" x2="256.2" y2="253.89"></line></g><g><defs><marker id="arrow_2330434513" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434513)" stroke-dasharray="6 4" stroke-opacity="1" x1="126" y1="267.84" x2="285.6" y2="239.94"></line></g><g><defs><marker id="arrow_2330434527" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434527)" stroke-dasharray="6 4" stroke-opacity="1" x1="247.8" y1="270.63" x2="302.4" y2="206.46"></line></g><g><defs><marker id="arrow_2330434570" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434570)" stroke-opacity="1" x1="151.2" y1="242.73" x2="126" y2="167.4"></line></g><g><defs><marker id="arrow_2330434575" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434575)" stroke-opacity="1" x1="298.2" y1="267.84" x2="294" y2="256.68"></line></g><g><defs><marker id="arrow_2330434577" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434577)" stroke-opacity="1" x1="277.2" y1="273.42" x2="256.2" y2="214.83"></line></g><g><defs><marker id="arrow_2330434595" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434595)" stroke-dasharray="6 4" stroke-opacity="1" x1="105" y1="217.62" x2="134.4" y2="223.2"></line></g><g><defs><marker id="arrow_2330434621" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434621)" stroke-opacity="1" x1="373.8" y1="248.31" x2="394.8" y2="128.34"></line></g><g><defs><marker id="arrow_2330434632" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434632)" stroke-dasharray="6 4" stroke-opacity="1" x1="285.6" y1="156.24" x2="365.4" y2="86.49"></line></g></svg>',"Jonah":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330432872" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432872)" stroke-dasharray="6 4" stroke-opacity="1" x1="210" y1="167.4" x2="273" y2="111.6"></line></g><g><defs><marker id="arrow_2330432881" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432881)" stroke-opacity="1" x1="130.2" y1="100.44" x2="63" y2="36.27"></line></g><g><defs><marker id="arrow_2330432893" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432893)" stroke-opacity="1" x1="163.8" y1="114.39" x2="117.6" y2="50.22"></line></g><g><defs><marker id="arrow_2330432907" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432907)" stroke-opacity="1" x1="285.6" y1="212.04" x2="331.8" y2="242.73"></line></g><g><defs><marker id="arrow_2330432910" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432910)" stroke-opacity="1" x1="289.8" y1="195.3" x2="294" y2="128.34"></line></g><g><defs><marker id="arrow_2330432935" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432935)" stroke-opacity="1" x1="105" y1="217.62" x2="88.2" y2="265.05"></line></g><g><defs><marker id="arrow_2330433036" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433036)" stroke-opacity="1" x1="289.8" y1="78.12" x2="369.6" y2="55.8"></line></g><g><defs><marker id="arrow_2330433051" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433051)" stroke-dasharray="6 4" stroke-opacity="1" x1="268.8" y1="225.99" x2="243.6" y2="212.04"></line></g><g><defs><marker id="arrow_2330433114" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433114)" stroke-opacity="1" x1="50.4" y1="198.09" x2="37.8" y2="212.04"></line></g><g><defs><marker id="arrow_2330433144" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433144)" stroke-opacity="1" x1="264.6" y1="186.93" x2="336" y2="259.47"></line></g><g><defs><marker id="arrow_2330433148" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433148)" stroke-opacity="1" x1="273" y1="206.46" x2="340.2" y2="139.5"></line></g><g><defs><marker id="arrow_2330433227" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433227)" stroke-opacity="1" x1="109.2" y1="111.6" x2="155.4" y2="58.59"></line></g><g><defs><marker id="arrow_2330433295" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433295)" stroke-dasharray="6 4" stroke-opacity="1" x1="189" y1="195.3" x2="273" y2="279"></line></g><g><defs><marker id="arrow_2330433325" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433325)" stroke-opacity="1" x1="96.6" y1="217.62" x2="71.4" y2="267.84"></line></g><g><defs><marker id="arrow_2330433388" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433388)" stroke-opacity="1" x1="231" y1="181.35" x2="252" y2="234.36"></line></g><g><defs><marker id="arrow_2330433408" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433408)" stroke-opacity="1" x1="243.6" y1="58.59" x2="201.6" y2="33.48"></line></g><g><defs><marker id="arrow_2330433414" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433414)" stroke-opacity="1" x1="180.6" y1="86.49" x2="235.2" y2="114.39"></line></g><g><defs><marker id="arrow_2330433419" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433419)" stroke-opacity="1" x1="222.6" y1="150.66" x2="226.8" y2="248.31"></line></g><g><defs><marker id="arrow_2330433456" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433456)" stroke-opacity="1" x1="239.4" y1="200.88" x2="289.8" y2="206.46"></line></g><g><defs><marker id="arrow_2330433485" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433485)" stroke-opacity="1" x1="281.4" y1="212.04" x2="285.6" y2="259.47"></line></g><g><defs><marker id="arrow_2330433488" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433488)" stroke-opacity="1" x1="235.2" y1="181.35" x2="210" y2="248.31"></line></g><g><defs><marker id="arrow_2330433500" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433500)" stroke-dasharray="6 4" stroke-opacity="1" x1="159.6" y1="175.77" x2="155.4" y2="167.4"></line></g><g><defs><marker id="arrow_2330433511" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433511)" stroke-opacity="1" x1="105" y1="184.14" x2="155.4" y2="228.78"></line></g><g><defs><marker id="arrow_2330433524" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433524)" stroke-opacity="1" x1="121.8" y1="206.46" x2="113.4" y2="106.02"></line></g><g><defs><marker id="arrow_2330433679" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433679)" stroke-opacity="1" x1="92.4" y1="189.72" x2="25.2" y2="136.71"></line></g><g><defs><marker id="arrow_2330433796" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433796)" stroke-opacity="1" x1="210" y1="139.5" x2="105" y2="139.5"></line></g><g><defs><marker id="arrow_2330433802" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433802)" stroke-opacity="1" x1="285.6" y1="136.71" x2="285.6" y2="33.48"></line></g><g><defs><marker id="arrow_2330434064" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434064)" stroke-opacity="1" x1="21" y1="273.42" x2="29.4" y2="228.78"></line></g><g><defs><marker id="arrow_2330434074" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434074)" stroke-opacity="1" x1="96.6" y1="225.99" x2="113.4" y2="270.63"></line></g><g><defs><marker id="arrow_2330434096" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434096)" stroke-opacity="1" x1="100.8" y1="209.25" x2="163.8" y2="181.35"></line></g><g><defs><marker id="arrow_2330434112" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434112)" stroke-opacity="1" x1="130.2" y1="214.83" x2="147" y2="270.63"></line></g><g><defs><marker id="arrow_2330434115" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434115)" stroke-opacity="1" x1="155.4" y1="212.04" x2="130.2" y2="259.47"></line></g><g><defs><marker id="arrow_2330434136" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434136)" stroke-opacity="1" x1="151.2" y1="58.59" x2="176.4" y2="55.8"></line></g><g><defs><marker id="arrow_2330434172" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434172)" stroke-opacity="1" x1="117.6" y1="209.25" x2="67.2" y2="242.73"></line></g><g><defs><marker id="arrow_2330434187" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434187)" stroke-opacity="1" x1="100.8" y1="195.3" x2="109.2" y2="86.49"></line></g><g><defs><marker id="arrow_2330434211" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434211)" stroke-opacity="1" x1="138.6" y1="50.22" x2="172.2" y2="44.64"></line></g><g><defs><marker id="arrow_2330434236" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434236)" stroke-dasharray="6 4" stroke-opacity="1" x1="210" y1="139.5" x2="201.6" y2="39.06"></line></g><g><defs><marker id="arrow_2330434260" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434260)" stroke-opacity="1" x1="235.2" y1="55.8" x2="277.2" y2="13.95"></line></g><g><defs><marker id="arrow_2330434295" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434295)" stroke-opacity="1" x1="214.2" y1="139.5" x2="130.2" y2="164.61"></line></g><g><defs><marker id="arrow_2330434388" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434388)" stroke-opacity="1" x1="163.8" y1="86.49" x2="147" y2="25.11"></line></g><g><defs><marker id="arrow_2330434452" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434452)" stroke-opacity="1" x1="239.4" y1="119.97" x2="310.8" y2="58.59"></line></g><g><defs><marker id="arrow_2330434482" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434482)" stroke-opacity="1" x1="172.2" y1="220.41" x2="130.2" y2="234.36"></line></g><g><defs><marker id="arrow_2330434525" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434525)" stroke-opacity="1" x1="147" y1="203.67" x2="151.2" y2="262.26"></line></g><g><defs><marker id="arrow_2330434529" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434529)" stroke-dasharray="6 4" stroke-opacity="1" x1="340.2" y1="245.52" x2="310.8" y2="195.3"></line></g><g><defs><marker id="arrow_2330434532" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434532)" stroke-opacity="1" x1="327.6" y1="237.15" x2="306.6" y2="220.41"></line></g><g><defs><marker id="arrow_2330434584" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434584)" stroke-opacity="1" x1="214.2" y1="139.5" x2="130.2" y2="164.61"></line></g><g><defs><marker id="arrow_2330434591" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434591)" stroke-opacity="1" x1="264.6" y1="64.17" x2="264.6" y2="11.16"></line></g><g><defs><marker id="arrow_2330434601" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434601)" stroke-opacity="1" x1="285.6" y1="13.95" x2="319.2" y2="61.38"></line></g><g><defs><marker id="arrow_2330434607" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434607)" stroke-dasharray="6 4" stroke-opacity="1" x1="210" y1="136.71" x2="298.2" y2="220.41"></line></g></svg>',"Connor":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330433399" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433399)" stroke-opacity="1" x1="54.6" y1="239.94" x2="147" y2="220.41"></line></g><g><defs><marker id="arrow_2330433474" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433474)" stroke-opacity="1" x1="357" y1="270.63" x2="331.8" y2="256.68"></line></g><g><defs><marker id="arrow_2330433483" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433483)" stroke-opacity="1" x1="319.2" y1="234.36" x2="281.4" y2="212.04"></line></g><g><defs><marker id="arrow_2330433607" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433607)" stroke-dasharray="6 4" stroke-opacity="1" x1="130.2" y1="265.05" x2="126" y2="214.83"></line></g></svg>',"Nikita":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330434552" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434552)" stroke-opacity="1" x1="289.8" y1="47.43" x2="277.2" y2="8.37"></line></g><g><defs><marker id="arrow_2330434574" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434574)" stroke-opacity="1" x1="243.6" y1="256.68" x2="298.2" y2="267.84"></line></g><g><defs><marker id="arrow_2330434576" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434576)" stroke-opacity="1" x1="294" y1="256.68" x2="277.2" y2="273.42"></line></g><g><defs><marker id="arrow_2330434618" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434618)" stroke-opacity="1" x1="273" y1="128.34" x2="289.8" y2="214.83"></line></g><g><defs><marker id="arrow_2330434631" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434631)" stroke-opacity="1" x1="315" y1="153.45" x2="285.6" y2="156.24"></line></g></svg>',"Matt":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330434554" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434554)" stroke-opacity="1" x1="218.4" y1="30.69" x2="163.8" y2="72.54"></line></g><g><defs><marker id="arrow_2330434589" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434589)" stroke-opacity="1" x1="264.6" y1="19.53" x2="310.8" y2="19.53"></line></g><g><defs><marker id="arrow_2330434592" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434592)" stroke-opacity="1" x1="264.6" y1="11.16" x2="319.2" y2="53.01"></line></g><g><defs><marker id="arrow_2330434600" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434600)" stroke-opacity="1" x1="130.2" y1="16.74" x2="285.6" y2="13.95"></line></g><g><defs><marker id="arrow_2330434625" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434625)" stroke-opacity="1" x1="298.2" y1="13.95" x2="268.8" y2="39.06"></line></g></svg>',"McGee":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330432874" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432874)" stroke-dasharray="6 4" stroke-opacity="1" x1="289.8" y1="44.64" x2="315" y2="78.12"></line></g><g><defs><marker id="arrow_2330432897" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432897)" stroke-opacity="1" x1="142.8" y1="22.32" x2="142.8" y2="5.58"></line></g><g><defs><marker id="arrow_2330432900" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432900)" stroke-opacity="1" x1="214.2" y1="97.65" x2="277.2" y2="223.2"></line></g><g><defs><marker id="arrow_2330433025" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433025)" stroke-opacity="1" x1="218.4" y1="5.58" x2="226.8" y2="66.96"></line></g><g><defs><marker id="arrow_2330433038" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433038)" stroke-dasharray="6 4" stroke-opacity="1" x1="369.6" y1="50.22" x2="420" y2="198.09"></line></g><g><defs><marker id="arrow_2330433059" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433059)" stroke-opacity="1" x1="84" y1="36.27" x2="121.8" y2="58.59"></line></g><g><defs><marker id="arrow_2330433068" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433068)" stroke-opacity="1" x1="147" y1="2.79" x2="147" y2="44.64"></line></g><g><defs><marker id="arrow_2330433097" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433097)" stroke-opacity="1" x1="302.4" y1="136.71" x2="340.2" y2="212.04"></line></g><g><defs><marker id="arrow_2330433149" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433149)" stroke-opacity="1" x1="340.2" y1="139.5" x2="378" y2="103.23"></line></g><g><defs><marker id="arrow_2330433237" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433237)" stroke-opacity="1" x1="155.4" y1="58.59" x2="306.6" y2="66.96"></line></g><g><defs><marker id="arrow_2330433913" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433913)" stroke-opacity="1" x1="336" y1="64.17" x2="373.8" y2="75.33"></line></g><g><defs><marker id="arrow_2330433933" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433933)" stroke-opacity="1" x1="134.4" y1="64.17" x2="67.2" y2="119.97"></line></g><g><defs><marker id="arrow_2330434048" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434048)" stroke-opacity="1" x1="180.6" y1="22.32" x2="159.6" y2="80.91"></line></g><g><defs><marker id="arrow_2330434120" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434120)" stroke-dasharray="6 4" stroke-opacity="1" x1="222.6" y1="142.29" x2="239.4" y2="133.92"></line></g><g><defs><marker id="arrow_2330434130" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434130)" stroke-dasharray="6 4" stroke-opacity="1" x1="163.8" y1="22.32" x2="117.6" y2="47.43"></line></g></svg>',"Kai":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330433404" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433404)" stroke-opacity="1" x1="168" y1="172.98" x2="289.8" y2="55.8"></line></g><g><defs><marker id="arrow_2330433571" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433571)" stroke-dasharray="6 4" stroke-opacity="1" x1="260.4" y1="13.95" x2="378" y2="170.19"></line></g><g><defs><marker id="arrow_2330433585" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433585)" stroke-dasharray="6 4" stroke-opacity="1" x1="256.2" y1="198.09" x2="289.8" y2="195.3"></line></g><g><defs><marker id="arrow_2330434603" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434603)" stroke-opacity="1" x1="277.2" y1="69.75" x2="268.8" y2="172.98"></line></g><g><defs><marker id="arrow_2330434617" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434617)" stroke-opacity="1" x1="294" y1="83.7" x2="273" y2="128.34"></line></g></svg>',"Ryan":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330432933" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432933)" stroke-opacity="1" x1="126" y1="239.94" x2="105" y2="270.63"></line></g><g><defs><marker id="arrow_2330432939" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432939)" stroke-opacity="1" x1="268.8" y1="189.72" x2="361.2" y2="234.36"></line></g><g><defs><marker id="arrow_2330433002" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433002)" stroke-opacity="1" x1="117.6" y1="78.12" x2="134.4" y2="122.76"></line></g><g><defs><marker id="arrow_2330433017" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433017)" stroke-opacity="1" x1="163.8" y1="61.38" x2="147" y2="27.9"></line></g><g><defs><marker id="arrow_2330433052" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433052)" stroke-opacity="1" x1="306.6" y1="234.36" x2="365.4" y2="237.15"></line></g><g><defs><marker id="arrow_2330433190" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433190)" stroke-opacity="1" x1="147" y1="217.62" x2="147" y2="159.03"></line></g><g><defs><marker id="arrow_2330434010" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434010)" stroke-dasharray="6 4" stroke-opacity="1" x1="407.4" y1="11.16" x2="390.6" y2="78.12"></line></g><g><defs><marker id="arrow_2330434111" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434111)" stroke-opacity="1" x1="163.8" y1="181.35" x2="130.2" y2="214.83"></line></g><g><defs><marker id="arrow_2330434117" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434117)" stroke-opacity="1" x1="163.8" y1="228.78" x2="147" y2="203.67"></line></g><g><defs><marker id="arrow_2330434119" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434119)" stroke-opacity="1" x1="193.2" y1="203.67" x2="222.6" y2="142.29"></line></g><g><defs><marker id="arrow_2330434145" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434145)" stroke-opacity="1" x1="407.4" y1="13.95" x2="365.4" y2="44.64"></line></g><g><defs><marker id="arrow_2330434405" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434405)" stroke-opacity="1" x1="205.8" y1="220.41" x2="361.2" y2="206.46"></line></g><g><defs><marker id="arrow_2330434455" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434455)" stroke-opacity="1" x1="315" y1="86.49" x2="331.8" y2="11.16"></line></g><g><defs><marker id="arrow_2330434481" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434481)" stroke-opacity="1" x1="184.8" y1="195.3" x2="172.2" y2="220.41"></line></g><g><defs><marker id="arrow_2330434491" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434491)" stroke-dasharray="6 4" stroke-opacity="1" x1="268.8" y1="30.69" x2="273" y2="33.48"></line></g><g><defs><marker id="arrow_2330434497" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434497)" stroke-opacity="1" x1="277.2" y1="80.91" x2="289.8" y2="33.48"></line></g><g><defs><marker id="arrow_2330434531" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434531)" stroke-opacity="1" x1="365.4" y1="262.26" x2="327.6" y2="237.15"></line></g></svg>',"Max":'<svg viewBox="0 0 420 279" class="Index__directions___253Wa"><g><defs><marker id="arrow_2330432886" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432886)" stroke-dasharray="6 4" stroke-opacity="1" x1="126" y1="122.76" x2="71.4" y2="0"></line></g><g><defs><marker id="arrow_2330432909" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432909)" stroke-opacity="1" x1="319.2" y1="189.72" x2="289.8" y2="195.3"></line></g><g><defs><marker id="arrow_2330432918" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432918)" stroke-opacity="1" x1="189" y1="189.72" x2="172.2" y2="217.62"></line></g><g><defs><marker id="arrow_2330432960" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432960)" stroke-opacity="1" x1="260.4" y1="228.78" x2="239.4" y2="270.63"></line></g><g><defs><marker id="arrow_2330432992" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#d800ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#d800ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330432992)" stroke-opacity="1" x1="394.8" y1="228.78" x2="361.2" y2="164.61"></line></g><g><defs><marker id="arrow_2330433032" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433032)" stroke-opacity="1" x1="344.4" y1="72.54" x2="289.8" y2="80.91"></line></g><g><defs><marker id="arrow_2330433060" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433060)" stroke-opacity="1" x1="121.8" y1="58.59" x2="105" y2="30.69"></line></g><g><defs><marker id="arrow_2330433066" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433066)" stroke-opacity="1" x1="138.6" y1="11.16" x2="147" y2="2.79"></line></g><g><defs><marker id="arrow_2330433070" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433070)" stroke-opacity="1" x1="147" y1="44.64" x2="168" y2="159.03"></line></g><g><defs><marker id="arrow_2330433089" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433089)" stroke-opacity="1" x1="142.8" y1="212.04" x2="134.4" y2="234.36"></line></g><g><defs><marker id="arrow_2330433133" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433133)" stroke-opacity="1" x1="163.8" y1="128.34" x2="180.6" y2="117.18"></line></g><g><defs><marker id="arrow_2330433146" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433146)" stroke-opacity="1" x1="310.8" y1="217.62" x2="273" y2="206.46"></line></g><g><defs><marker id="arrow_2330433238" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433238)" stroke-opacity="1" x1="306.6" y1="66.96" x2="369.6" y2="231.57"></line></g><g><defs><marker id="arrow_2330433417" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433417)" stroke-dasharray="6 4" stroke-opacity="1" x1="231" y1="128.34" x2="260.4" y2="181.35"></line></g><g><defs><marker id="arrow_2330433523" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433523)" stroke-opacity="1" x1="147" y1="237.15" x2="121.8" y2="206.46"></line></g><g><defs><marker id="arrow_2330433529" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433529)" stroke-dasharray="6 4" stroke-opacity="1" x1="327.6" y1="103.23" x2="344.4" y2="89.28"></line></g><g><defs><marker id="arrow_2330433804" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433804)" stroke-dasharray="6 4" stroke-opacity="1" x1="285.6" y1="33.48" x2="247.8" y2="64.17"></line></g><g><defs><marker id="arrow_2330433962" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330433962)" stroke-dasharray="6 4" stroke-opacity="1" x1="415.8" y1="214.83" x2="369.6" y2="209.25"></line></g><g><defs><marker id="arrow_2330434068" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434068)" stroke-dasharray="6 4" stroke-opacity="1" x1="113.4" y1="276.21" x2="92.4" y2="242.73"></line></g><g><defs><marker id="arrow_2330434075" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434075)" stroke-dasharray="6 4" stroke-opacity="1" x1="113.4" y1="270.63" x2="189" y2="245.52"></line></g><g><defs><marker id="arrow_2330434258" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434258)" stroke-opacity="1" x1="298.2" y1="72.54" x2="235.2" y2="55.8"></line></g><g><defs><marker id="arrow_2330434320" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434320)" stroke-dasharray="6 4" stroke-opacity="1" x1="264.6" y1="41.85" x2="294" y2="55.8"></line></g><g><defs><marker id="arrow_2330434420" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434420)" stroke-opacity="1" x1="310.8" y1="273.42" x2="281.4" y2="259.47"></line></g><g><defs><marker id="arrow_2330434469" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434469)" stroke-opacity="1" x1="289.8" y1="262.26" x2="336" y2="273.42"></line></g><g><defs><marker id="arrow_2330434512" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434512)" stroke-opacity="1" x1="256.2" y1="253.89" x2="126" y2="267.84"></line></g><g><defs><marker id="arrow_2330434573" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434573)" stroke-opacity="1" x1="277.2" y1="203.67" x2="243.6" y2="256.68"></line></g><g><defs><marker id="arrow_2330434612" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#909090" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#909090" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434612)" stroke-dasharray="6 4" stroke-opacity="1" x1="407.4" y1="231.57" x2="420" y2="161.82"></line></g><g><defs><marker id="arrow_2330434619" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434619)" stroke-opacity="1" x1="289.8" y1="214.83" x2="340.2" y2="239.94"></line></g><g><defs><marker id="arrow_2330434627" markerWidth="8" markerHeight="10" refX="6" refY="4" orient="auto" markerUnits="strokeWidth" viewBox="0 0 15 15"><path d="M0,0 L0,8 L9,4 z" fill="#0876ff" fill-opacity="1"></path></marker></defs><line fill="none" stroke="#0876ff" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round" marker-end="url(#arrow_2330434627)" stroke-opacity="1" x1="277.2" y1="61.38" x2="415.8" y2="80.91"></line></g></svg>'}

# %%
players = []
for player in htmlPlayers:
    htmlPlayer = htmlPlayers[player]
    print(player)

    arrowLabels = htmlPlayer.split('<g>')
    arrows = []
    for label in arrowLabels[1:]:
        x1 = label.find("x1")
        y1 = label.find("y1")
        x2 = label.find("x2")
        y2 = label.find("y2")
        if "#0876ff" in label:
            result = True
            coords = label.split("=")[19:]
        else:
            result = False
            coords = label.split("=")[20:]
        if "#d800ff" in label:
            key =True
            result = True
            coords = label.split("=")[19:]
        else:
            key = False
        coordinates = []
        for i in range(4):
            if i%2==0:
                divided = 420/120
            else:
                divided = 280/80
            #divided=1
            val = coords[i]
            val = float(val.split('"')[1])/divided
            coordinates.append(val)
        coordinates.append(result)
        coordinates.append(key)
        arrows.append(coordinates)
    arrows = pd.DataFrame(arrows,columns=["x1",'y1',"x2","y2","result","key pass"])
    arrows.insert(0,"Player",player)
    players.append(arrows)
players
# Out:
# Nolan
# Evan
# Adam
# Keenai
# Carter
# Cole
# Woody
# Quinn
# Val
# James
# Jonah
# Connor
# Nikita
# Matt
# McGee
# Kai
# Ryan
# Max
# [   Player    x1         y1    x2         y2  result  key pass
#  0   Nolan  15.6  69.351429  27.6  58.988571    True     False
#  1   Nolan  21.6  21.522857  74.4  25.508571   False     False
#  2   Nolan  18.0  35.074286  28.8  22.320000    True     False
#  3   Nolan   3.6  18.334286  52.8   7.971429   False     False
#  4   Nolan  10.8  40.654286  32.4  58.988571    True     False
#  5   Nolan   8.4  39.857143  15.6  20.725714    True     False
#  6   Nolan  21.6  39.060000  84.0  21.522857   False     False
#  7   Nolan  10.8  47.828571  15.6  58.988571    True     False
#  8   Nolan   8.4  43.045714  16.8  69.351429    True     False
#  9   Nolan  22.8  19.928571  67.2  10.362857    True     False
#  10  Nolan  15.6  35.871429  21.6  37.465714    True     False
#  11  Nolan  15.6  39.060000  15.6  56.597143    True     False
# ...

# %%
merged = players[0]
for player in players:
    merged = pd.merge(merged,player,how="outer")
def distance(startX,startY,endX,endY):
    return np.sqrt((endX-startX)**2+(endY-startY)**2)
merged = merged.assign(Distance = distance(merged.get("x1"),merged.get("y1"),merged.get("x2"),merged.get("y2")))
merged["angle"] = np.arctan((merged.y2-merged.y1)/(merged.x2-merged.x1),)
merged.to_csv("fullertonPasses.csv",index=False)

# %%
left = merged[(merged.get("y1")<40)&(merged.get("y2")<40)]
right = merged[(merged.get("y1")>40)&(merged.get("y2")>40)]
switch = merged[((merged.get("y1")>40)&(merged.get("y2")<=40)) | ((merged.get("y1")<45)&(merged.get("y2")>=40))]
leftPerc = left[left.get("result")].shape[0]/left.shape[0]
rightPerc = right[right.get("result")].shape[0]/right.shape[0]
switchPerc = switch[switch.get("result")].shape[0]/switch.shape[0]
print(leftPerc, rightPerc, switchPerc)
print(left.shape[0],right.shape[0],switch.shape[0])
# Out:
# 0.7955801104972375 0.8 0.782051282051282
# 181 180 78

# %%
successful = merged[merged.get("result")]
unsuccessful = merged[~merged.get("result")]
key = merged[merged.get("key pass")]
forward = merged[(merged.get("angle")<=np.sqrt(2)/2) &(merged.get("angle")>=-1*np.sqrt(2)/2)]
forwardSuccessful = forward[forward.get("result")]
forwardUnsuccessful = forward[~forward.get("result")]
attackingThird = merged[merged.get("x2")>=80]
attackingThirdSuccessful = attackingThird[attackingThird.get("result")]
attackingThirdUnsuccessful = attackingThird[~attackingThird.get("result")]
allTheWay = merged[(merged.get("x2")>=80)&(merged.get("x1")>=80)]
allTheWaySuccessful = allTheWay[allTheWay.get("result")]
deepPasses = successful[(successful.get("x2")>102)&(successful.get("y2")<62)&(successful.get("y2")>18)&(successful.get("y1")<70)&(successful.get("y1")>5)]
longPasses = merged[merged.get("Distance")>=40]

# %%
left = forward[(forward.get("y1")<40)&(forward.get("y2")<40)]
right = forward[(forward.get("y1")>40)&(forward.get("y2")>40)]
switch = forward[((forward.get("y1")>40)&(forward.get("y2")<=40)) | ((merged.get("y1")<45)&(merged.get("y2")>=40))]
leftPerc = left[left.get("result")].shape[0]/left.shape[0]
rightPerc = right[right.get("result")].shape[0]/right.shape[0]
switchPerc = switch[switch.get("result")].shape[0]/switch.shape[0]
print(leftPerc, rightPerc, switchPerc)
print(left.shape[0],right.shape[0],switch.shape[0])
# Out:
# 0.7830188679245284 0.7684210526315789 0.7857142857142857
# 106 95 14

# %%
left = attackingThirdSuccessful[(attackingThirdSuccessful.get("y1")<40)&(attackingThirdSuccessful.get("y2")<40)]
right = attackingThirdSuccessful[(attackingThirdSuccessful.get("y1")>40)&(attackingThirdSuccessful.get("y2")>40)]
switch = attackingThirdSuccessful[((attackingThirdSuccessful.get("y1")>40)&(attackingThirdSuccessful.get("y2")<=40)) | ((attackingThirdSuccessful.get("y1")<45)&(attackingThirdSuccessful.get("y2")>=40))]
leftPerc = left.shape[0]/attackingThirdSuccessful.shape[0]
rightPerc = right.shape[0]/attackingThirdSuccessful.shape[0]
switchPerc = switch.shape[0]/attackingThirdSuccessful.shape[0]
print(leftPerc, rightPerc, switchPerc)
print(left.shape[0],right.shape[0],switch.shape[0])
# Out:
# 0.41975308641975306 0.43209876543209874 0.16049382716049382
# 34 35 13

# %%
left = attackingThird[(attackingThird.get("y1")<40)&(attackingThird.get("y2")<40)]
right = attackingThird[(attackingThird.get("y1")>40)&(attackingThird.get("y2")>40)]
switch = attackingThird[((attackingThird.get("y1")>40)&(attackingThird.get("y2")<=40)) | ((attackingThird.get("y1")<45)&(attackingThird.get("y2")>=40))]
leftPerc = left[left.get("result")].shape[0]/left.shape[0]
rightPerc = right[right.get("result")].shape[0]/right.shape[0]
switchPerc = switch[switch.get("result")].shape[0]/switch.shape[0]
print("Accuracy", leftPerc, rightPerc, switchPerc)
print(left.shape[0],right.shape[0],switch.shape[0])
# Out:
# Accuracy 0.6938775510204082 0.6730769230769231 0.6190476190476191
# 49 52 21

# %%
df = attackingThird
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=df.get("x2"),y=df.get("y2"),fill = True,shade_lowest = False,alpha = .5,n_levels = 40,cmap = "magma")
for i in range(df.shape[0]):
    row = df.iloc[i]
    if row.get("key pass")==True:
        color = "purple"
    elif row.get("result"):
        color = "green"
    else:
        color = "red"
    
    plt.arrow(row.get("x1"),row.get("y1"),row.get("x2")-row.get("x1"),row.get("y2")-row.get("y1"),width = .2,alpha = .3,color = color)
plt.title("UCSD Attacking Third Passes")
# Out:
# Text(0.5, 1.0, 'UCSD Attacking Third Passes')

# %%
df_pass = merged
bins = (8,5)
pitch = Pitch(positional=True)
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')
# plot the heatmap - darker colors = more passes originating from that square
bs_heatmap = pitch.bin_statistic(df_pass.x1, df_pass.y1, statistic='count', bins=bins)
# successful_bins = pitch.bin_statistic(successful.x1, successful.y1, statistic='count', bins=bins)
# unsuccessful_bins = pitch.bin_statistic(unsuccessful.x1, unsuccessful.y1, statistic='count', bins=bins)
# accuracies = successful_bins["statistic"]/(successful_bins["statistic"]+unsuccessful_bins["statistic"])
# bs_heatmap["statistic"]=accuracies
hm = pitch.heatmap(bs_heatmap, ax=ax, cmap='Greens',alpha = .6)
# plot the pass flow map with a single color and the
# arrow length equal to the average distance in the cell
fm = pitch.flow(df_pass.x1, df_pass.y1, df_pass.x2, df_pass.y2, color='black',
                arrow_type='average', bins=bins, ax=ax)
plt.title("General Direction of Passes on Pitch",color = "white",fontsize = 18)
# Out:
# Text(0.5, 1.0, 'General Direction of Passes on Pitch')

# %%
df_pass = merged
bins = (6,5)
pitch = Pitch(positional=True)
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')
# plot the heatmap - darker colors = more passes originating from that square
bs_heatmap = pitch.bin_statistic(df_pass.x1, df_pass.y1, statistic='count', bins=bins)
successful_bins = pitch.bin_statistic(successful.x1, successful.y1, statistic='count', bins=bins)
unsuccessful_bins = pitch.bin_statistic(unsuccessful.x1, unsuccessful.y1, statistic='count', bins=bins)
accuracies = successful_bins["statistic"]/(successful_bins["statistic"]+unsuccessful_bins["statistic"])
bs_heatmap["statistic"]=accuracies
hm = pitch.heatmap(bs_heatmap, ax=ax, cmap='Greens',alpha = .6)

labels2 = pitch.label_heatmap(bs_heatmap, color='black', fontsize=18,
                              ax=ax, ha='center', va='center',
                              str_format='{:.0%}',)
plt.title("Passing Accuracy on Pitch",color = "white",fontsize = 18)
# Out:
# C:\Users\zcoch\AppData\Local\Temp\ipykernel_16464\758709221.py:10: RuntimeWarning: invalid value encountered in divide
#   accuracies = successful_bins["statistic"]/(successful_bins["statistic"]+unsuccessful_bins["statistic"])
# Text(0.5, 1.0, 'Passing Accuracy on Pitch')

# %%
deepPasses.shape[0]
# Out:
# 6

# %%
df = allTheWay
pitch = VerticalPitch(half=True, axis=True)
fig, ax = pitch.draw()
kde = sns.kdeplot(y=df.get("x2"),x=df.get("y2"),fill = True,shade_lowest = False,alpha = .5,n_levels = 15,cmap = "magma")
for i in range(df.shape[0]):
    row = df.iloc[i]
    if row.get("key pass")==True:
        color = "purple"
        label = "Key Pass"
    elif row.get("result"):
        color = "green"
        label = "Successful Pass"
    else:
        color = "red"
        label = "Unsuccessful Pass"
    plt.arrow(row.get("y1"),row.get("x1"),(row.get("y2")-row.get("y1")),(row.get("x2")-row.get("x1")),width = .3,alpha = .4,color = color, label = label)
plt.title("UCSD's Attacking Passes")
handles, labels = plt.gca().get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
plt.legend(unique_labels.values(), unique_labels.keys())

# %%
perc = forward.groupby(["Player","result"]).count().reset_index()
for player in perc.get("Player").unique():
    limited = perc[perc.get("Player")==player]
    try:
        print("Player:",player, "Accuracy:",limited[limited.get("result")==True].get("x1").iloc[0]/limited.get("x1").sum(), "Num Forward Passes:",limited.get("x1").sum())
    except:
        print(player, 0)
# Out:
# Player: Adam Accuracy: 0.8275862068965517 Num Forward Passes: 29
# Player: Carter Accuracy: 0.7037037037037037 Num Forward Passes: 27
# Player: Cole Accuracy: 0.875 Num Forward Passes: 8
# Player: Connor Accuracy: 1.0 Num Forward Passes: 3
# Player: Evan Accuracy: 0.7272727272727273 Num Forward Passes: 22
# Player: James Accuracy: 0.6764705882352942 Num Forward Passes: 34
# Player: Jonah Accuracy: 0.9375 Num Forward Passes: 16
# Kai 0
# Player: Keenai Accuracy: 1.0 Num Forward Passes: 2
# Player: Matt Accuracy: 1.0 Num Forward Passes: 5
# Player: Max Accuracy: 0.6666666666666666 Num Forward Passes: 15
# Player: McGee Accuracy: 0.6666666666666666 Num Forward Passes: 6
# Player: Nikita Accuracy: 1.0 Num Forward Passes: 2
# Player: Nolan Accuracy: 0.7272727272727273 Num Forward Passes: 11
# Player: Quinn Accuracy: 0.7272727272727273 Num Forward Passes: 11
# Player: Ryan Accuracy: 0.8333333333333334 Num Forward Passes: 6
# Player: Val Accuracy: 0.8888888888888888 Num Forward Passes: 9
# ...

# %%
for player in merged.get("Player").unique():
    allPass = merged[merged.get("Player")==player].shape[0]
    forwardPass = forward[forward.get("Player")==player].shape[0]
    print("Player:",player,"Percentage Forward:",forwardPass/allPass, "Num Passes", allPass)
# Out:
# Player: Adam Percentage Forward: 0.6170212765957447 Num Passes 47
# Player: Carter Percentage Forward: 0.627906976744186 Num Passes 43
# Player: Cole Percentage Forward: 0.36363636363636365 Num Passes 22
# Player: Connor Percentage Forward: 0.75 Num Passes 4
# Player: Evan Percentage Forward: 0.6285714285714286 Num Passes 35
# Player: James Percentage Forward: 0.5666666666666667 Num Passes 60
# Player: Jonah Percentage Forward: 0.32653061224489793 Num Passes 49
# Player: Kai Percentage Forward: 0.2 Num Passes 5
# Player: Keenai Percentage Forward: 0.5 Num Passes 4
# Player: Matt Percentage Forward: 1.0 Num Passes 5
# Player: Max Percentage Forward: 0.5172413793103449 Num Passes 29
# Player: McGee Percentage Forward: 0.4 Num Passes 15
# Player: Nikita Percentage Forward: 0.4 Num Passes 5
# Player: Nolan Percentage Forward: 0.4230769230769231 Num Passes 26
# Player: Quinn Percentage Forward: 0.3235294117647059 Num Passes 34
# ...

# %%
print(longPasses.get("result").mean())
perc = longPasses.groupby(["Player","result"]).count().reset_index()
for player in perc.get("Player").unique():
    limited = perc[perc.get("Player")==player]
    try:
        print("Player:",player, "Percentage:",limited[limited.get("result")==True].get("x1").iloc[0]/limited.get("x1").sum(), "Num Long Passes:",limited.get("x1").sum())
    except:
        print(player, 0)
# Out:
# 0.5192307692307693
# Player: Adam Percentage: 0.4 Num Long Passes: 5
# Player: Carter Percentage: 0.2 Num Long Passes: 5
# Player: Evan Percentage: 0.5 Num Long Passes: 10
# Player: James Percentage: 0.7 Num Long Passes: 10
# Player: Kai Percentage: 0.5 Num Long Passes: 2
# Player: Matt Percentage: 1.0 Num Long Passes: 1
# Player: Max Percentage: 1.0 Num Long Passes: 1
# Player: McGee Percentage: 0.6666666666666666 Num Long Passes: 3
# Player: Nolan Percentage: 0.5 Num Long Passes: 8
# Player: Quinn Percentage: 0.4 Num Long Passes: 5
# Player: Ryan Percentage: 1.0 Num Long Passes: 1
# Val 0

# %%
for player in merged.get("Player").unique():   
    playerDf = merged[merged.get("Player")==player]
    df = playerDf
    pitch = Pitch(positional=True, axis=True,label=True)
    fig, ax = plt.subplots(figsize = (10,6))
    pitch.draw(ax=ax)
    kde = sns.kdeplot(x=df.get("x2"),y=df.get("y2"),fill = True,shade_lowest = False,alpha = .5,n_levels = 10,cmap = "magma")
    for i in range(df.shape[0]):
        row = df.iloc[i]
        if row.get("key pass")==True:
            color = "purple"
        elif row.get("result"):
            color = "green"
        else:
            color = "red"
        
        plt.arrow(row.get("x1"),row.get("y1"),row.get("x2")-row.get("x1"),row.get("y2")-row.get("y1"),width = .2,alpha = .3,color = color)
    plt.title(player+" Passes Destination")
    plt.show()
