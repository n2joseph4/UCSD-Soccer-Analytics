# %%
import pandas as pd
from mplsoccer import Pitch
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
fullHtml = '<div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 21%; left: 73%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 18%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 90%; left: 59%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 89%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 88%; left: 15%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 73%; left: 7%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 81%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 27%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 83%; left: 95%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 23%; left: 10%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 30%; left: 15%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 81%; left: 41%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 91%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 57%; left: 41%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 74%; left: 5%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 74%; left: 18%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 6%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 44%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 87%; left: 35%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 90%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 10%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 22%; left: 85%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 62%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 73%; left: 9%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 69%; left: 72%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 84%; left: 10%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 58%; left: 18%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 76%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 67%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 72%; left: 8%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 73%; left: 71%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 83%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>2</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 13%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 80%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 73%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 54%; left: 35%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>29</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 85%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 57%; left: 20%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 88%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 28%; left: 70%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 30%; left: 8%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 75%; left: 10%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 73%; left: 8%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 52%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 55%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 30%; left: 5%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 26%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 97%; left: 35%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 80%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 15%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 76%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 76%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>20</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 76%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 15%; left: 14%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 17%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 15%; left: 44%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 74%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 81%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 26%; left: 70%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 82%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 26%; left: 51%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 27%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 60%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 91%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 72%; left: 14%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 15%; left: 69%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 38%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 25%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 15%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 8%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 12%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 23%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 7%; left: 68%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 29%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 34%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 90%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 45%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 14%; left: 43%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 31%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 62%; left: 10%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 73%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 29%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>32</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 88%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>12</span></div></div>'

# %%
dots =fullHtml.find("teamstats__Dots-module__dots")
dotsData = fullHtml[dots:]

labels = dotsData.split('<div class="teamstats__Dots-module__dot')
positions = []
for label in labels[1:]:
    left = label.find("left:")
    left = int(label[left+6:left+8].replace("%",""))/100*120
    top = label.find("top:")
    top = int(label[top+5:top+7].replace("%",""))/100*80
    player = int(label.split("span")[-2].replace(">","").replace("<","").replace("/",""))
    positions.append([left,top,"module__successful" in label, player])
positions = pd.DataFrame(positions,columns=["x1","y1","won","player"])
duelsOwnHalf = positions[positions.get("x1")<60]
def assignSide(y1):
    if y1<40:
        return "Left"
    else:
        return "Right"
duelsOwnHalf = duelsOwnHalf.assign(Side = duelsOwnHalf.get("y1").apply(assignSide))
left = duelsOwnHalf[duelsOwnHalf.get("Side")=="Left"]
right = duelsOwnHalf[duelsOwnHalf.get("Side")=="Right"]

# %%
def distanceFromMiddle6(x,y):
    return np.sqrt((x-6)**2+(y-40)**2)
positions = positions.assign(Distance = distanceFromMiddle6(positions.get("x1"),positions.get("y1")))
print(positions[positions.get("x1")<=60]["Distance"].mean())
print(positions[positions.get("x1")<=60]["x1"].mean())
print(lost[lost.get("x1")<=60]["x1"].mean())
# Out:
# 35.11450330583762
# 30.916666666666668
# 30.654545454545453

# %%
print(duelsOwnHalf.get("won").mean(),left.get("won").mean(),right.get("won").mean())
# Out:
# 0.5416666666666666 0.5806451612903226 0.5121951219512195

# %%
positions.head(60)
positions.get("won").mean()
# Out:
# 0.5434782608695652

# %%
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=positions.get("x1"),y=positions.get("y1"),fill = True,shade_lowest = False,alpha = .5,n_levels = 15,cmap = "magma")
for i in range(positions.shape[0]):
    row = positions.iloc[i]
    if row.get("won"):
        color = "og"
    else:
        color = "ro"
    plt.plot(row.get("x1"),row.get("y1"),color)
plt.title("UCSD Defensive Duels")
plt.show()
won = positions[positions.get("won")]
lost = positions[~positions.get("won")]
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=lost.get("x1"),y=lost.get("y1"),fill = True,shade_lowest = False,alpha = .5,n_levels = 15,cmap = "magma")
for i in range(lost.shape[0]):
    row = lost.iloc[i]
    if row.get("won"):
        color = "og"
    else:
        color = "ro"
    plt.plot(row.get("x1"),row.get("y1"),color)
plt.title("UCSD Defensive Duels lost")
plt.show()
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=won.get("x1"),y=won.get("y1"),fill = True,shade_lowest = False,alpha = .5,n_levels = 15,cmap = "magma")
for i in range(won.shape[0]):
    row = won.iloc[i]
    if row.get("won"):
        color = "og"
    else:
        color = "ro"
    plt.plot(row.get("x1"),row.get("y1"),color)
plt.title("UCSD Defensive Duels Won")
plt.show()

# %%
bins = (6,5)
pitch = Pitch(positional=True)
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')
# plot the heatmap - darker colors = more passes originating from that square
bs_heatmap = pitch.bin_statistic(positions.x1, positions.y1, statistic='count', bins=bins)
successful_bins = pitch.bin_statistic(won.x1, won.y1, statistic='count', bins=bins)
unsuccessful_bins = pitch.bin_statistic(lost.x1, lost.y1, statistic='count', bins=bins)
accuracies = successful_bins["statistic"]/(successful_bins["statistic"]+unsuccessful_bins["statistic"])
bs_heatmap["statistic"]=accuracies
hm = pitch.heatmap(bs_heatmap, ax=ax, cmap='Greens',alpha = .6)

labels2 = pitch.label_heatmap(bs_heatmap, color='black', fontsize=18,
                              ax=ax, ha='center', va='center',
                              str_format='{:.0%}',)
plt.title("Defensive Duels Accuracy on Pitch",color = "white",fontsize = 18)
# Out:
# C:\Users\zcoch\AppData\Local\Temp\ipykernel_89412\2847469636.py:9: RuntimeWarning: invalid value encountered in divide
#   accuracies = successful_bins["statistic"]/(successful_bins["statistic"]+unsuccessful_bins["statistic"])
# Text(0.5, 1.0, 'Defensive Duels Accuracy on Pitch')

# %%
playerDuels = positions.groupby("player").agg({"won":"mean","x1":'count'}).sort_values("won",ascending=False)
playerDuels.rename(columns={"won":"Accuracy","x1":"Count"})
# Out:
#         Accuracy  Count
# player
# 1       1.000000      1
# 2       1.000000      2
# 17      1.000000      3
# 20      0.857143      7
# 10      0.769231     13
# 22      0.750000      4
# 6       0.666667      6
# 32      0.666667      3
# 19      0.571429      7
# 8       0.545455     11
# 23      0.454545     11
# 9       0.250000      4
# 12      0.214286     14
# 5       0.000000      2
# 7       0.000000      3
# 29      0.000000      1
