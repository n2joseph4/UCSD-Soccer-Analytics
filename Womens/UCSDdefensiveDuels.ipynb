# %%
import pandas as pd
from mplsoccer import Pitch
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
games = {"Pacific":'<div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 90%; left: 53%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 26%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 30%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 68%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 65%; left: 36%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 48%; left: 44%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 15%; left: 61%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 54%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 37%; left: 35%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 16%; left: 13%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 34%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 24%; left: 54%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 19%; left: 63%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 23%; left: 63%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 15%; left: 16%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 24%; left: 13%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 44%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 93%; left: 47%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 61%; left: 22%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 29%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 94%; left: 82%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 65%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 44%; left: 72%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 77%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 74%; left: 60%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 73%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 24%; left: 96%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 11%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 20%; left: 88%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 90%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 32%; left: 28%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 25%; left: 26%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 38%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 9%; left: 51%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 89%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 81%; left: 55%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 12%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 20%; left: 13%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 6%; left: 14%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 81%; left: 69%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 92%; left: 71%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 90%; left: 65%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 28%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 71%; left: 13%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 84%; left: 62%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 5%; left: 59%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 47%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 41%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 59%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 33%; left: 54%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 20%; left: 80%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 20%; left: 80%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 70%; left: 34%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 34%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 42%; left: 55%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 9%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 87%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 42%; left: 86%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 97%; left: 49%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 87%; left: 51%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 79%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 87%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 33%; left: 21%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 94%; left: 70%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 59%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 82%; left: 59%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 88%; left: 64%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 61%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 60%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 25%; left: 65%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 74%; left: 70%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 19%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 69%; left: 6%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 93%; left: 39%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 86%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 83%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 22%; left: 24%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 33%; left: 36%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 42%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 72%; left: 61%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 14%; left: 65%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 44%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 74%; left: 53%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 88%; left: 23%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 94%; left: 25%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 44%; left: 25%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>0</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 62%; left: 42%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 63%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 70%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 40%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 68%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 51%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 55%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 44%; left: 56%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 36%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div></div>',"Irvine":'<div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 42%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 12%; left: 78%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 82%; left: 94%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 75%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 44%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 81%; left: 9%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 33%; left: 27%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 87%; left: 71%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 54%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 30%; left: 27%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 60%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 40%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 3%; left: 53%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 23%; left: 65%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 24%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 15%; left: 25%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 35%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 23%; left: 30%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 3%; left: 59%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 58%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 9%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 11%; left: 34%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 58%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 6%; left: 50%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 79%; left: 64%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 29%; left: 42%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 29%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 13%; left: 58%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 53%; left: 13%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 91%; left: 30%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 17%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 21%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 27%; left: 11%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 4%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 10%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 30%; left: 12%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 39%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>18</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 13%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 33%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 14%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 86%; left: 75%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 54%; left: 51%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 68%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 89%; left: 59%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 75%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 46%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 48%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 70%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 52%; left: 45%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 17%; left: 9%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 27%; left: 25%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 10%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 26%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 36%; left: 29%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 88%; left: 11%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 18%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 62%; left: 64%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 32%; left: 55%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 35%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 72%; left: 74%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 97%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 21%; left: 61%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 39%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 46%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 23%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 14%; left: 16%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 24%; left: 9%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 7%; left: 21%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 17%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 18%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 5%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 3%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 57%; left: 44%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 98%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 74%; left: 68%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 78%; left: 64%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 30%; left: 42%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 96%; left: 40%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 53%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 56%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 85%; left: 90%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 85%; left: 58%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 68%; left: 33%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 33%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div></div>',"SDSU":'<div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 82%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 2%; left: 72%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 3%; left: 70%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 69%; left: 51%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 82%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 45%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 65%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 54%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 72%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 56%; left: 46%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 3%; left: 46%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 62%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 76%; left: 49%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 2%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 18%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 97%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 88%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 72%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 78%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 64%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 76%; left: 78%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 18%; left: 43%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 82%; left: 24%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 84%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 90%; left: 47%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 61%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 66%; left: 14%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 84%; left: 35%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 90%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 39%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 65%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 42%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 78%; left: 72%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 33%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 55%; left: 46%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 83%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 21%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 93%; left: 75%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>18</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 49%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 6%; left: 58%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 14%; left: 57%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 80%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 90%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 81%; left: 21%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 9%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 14%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 14%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 94%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 68%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 97%; left: 43%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 35%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 78%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 32%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 56%; left: 35%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 10%; left: 15%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 59%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 17%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 61%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 90%; left: 95%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 81%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 69%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 83%; left: 59%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 65%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 67%; left: 12%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 46%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 45%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 36%; left: 71%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 28%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 82%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 84%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 85%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 3%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 97%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 77%; left: 63%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 71%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 98%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 89%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 89%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 94%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 35%; left: 45%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 63%; left: 44%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 49%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 24%; left: 5%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 85%; left: 65%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 29%; left: 82%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 27%; left: 90%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 77%; left: 56%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 18%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 62%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 89%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 66%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 11%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 98%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div></div>',"Washington State":'<div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 76%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 76%; left: 80%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 56%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 6%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 79%; left: 68%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 49%; left: 66%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 31%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 61%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 82%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 77%; left: 46%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 50%; left: 66%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 58%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 4%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 78%; left: 44%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 70%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 59%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 64%; left: 76%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 28%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 4%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 20%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 34%; left: 18%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 68%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 74%; left: 63%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 80%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 83%; left: 7%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 14%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 31%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 7%; left: 2%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 44%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 37%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 25%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 14%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 3%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 76%; left: 7%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 14%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 10%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>28</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 33%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 40%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 8%; left: 68%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 95%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 3%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>18</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 49%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 38%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 35%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 69%; left: 62%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 15%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 2%; left: 21%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 96%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 85%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 67%; left: 58%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 68%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 69%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 86%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 18%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 8%; left: 14%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 14%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 85%; left: 21%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 94%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 87%; left: 79%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 91%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 17%; left: 6%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 8%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 15%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 13%; left: 82%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 82%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 28%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 45%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 40%; left: 14%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 21%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 27%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 88%; left: 16%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 43%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 90%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 39%; left: 69%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 79%; left: 66%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 96%; left: 57%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 58%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 84%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 79%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 84%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 28%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 77%; left: 9%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 16%; left: 10%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 88%; left: 41%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 41%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 71%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 61%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 60%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 93%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 88%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 30%; left: 21%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 96%; left: 24%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>26</span></div></div>',"Idaho":'<div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 83%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 78%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 50%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 14%; left: 20%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 18%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 29%; left: 7%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 76%; left: 45%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 22%; left: 63%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 52%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 32%; left: 46%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 59%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 88%; left: 75%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 57%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 9%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 10%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 81%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 94%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 85%; left: 59%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 84%; left: 63%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 15%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 41%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 87%; left: 58%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 76%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 90%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 25%; left: 90%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 77%; left: 48%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 32%; left: 62%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 74%; left: 70%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 17%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 16%; left: 12%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 11%; left: 53%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>18</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 56%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 89%; left: 66%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 62%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 88%; left: 57%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 35%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 41%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 20%; left: 52%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 53%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 83%; left: 49%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 8%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 24%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 13%; left: 7%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 72%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 89%; left: 66%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 83%; left: 52%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 67%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 64%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 62%; left: 63%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 81%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 69%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 89%; left: 80%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 70%; left: 65%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 24%; left: 48%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 24%; left: 69%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 22%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 9%; left: 70%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 83%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 19%; left: 51%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 9%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 12%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 90%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 9%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 75%; left: 69%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>18</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 18%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 39%; left: 68%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 85%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 78%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 21%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 17%; left: 20%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 64%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 57%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 73%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 14%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 6%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 83%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 35%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 11%; left: 56%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 57%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div></div>',"CBU":'<div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 7%; left: 48%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 68%; left: 52%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 53%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 25%; left: 35%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 95%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 75%; left: 91%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 23%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 42%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 15%; left: 50%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 35%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 78%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>28</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 47%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 54%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 40%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 37%; left: 30%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 29%; left: 21%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 11%; left: 93%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>28</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 98%; left: 62%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 89%; left: 51%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 69%; left: 45%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 73%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 19%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 82%; left: 36%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 99%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 11%; left: 69%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 17%; left: 59%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 59%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 26%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 38%; left: 33%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 54%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 66%; left: 34%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 13%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 76%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 92%; left: 63%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 46%; left: 45%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 94%; left: 62%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 18%; left: 55%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 53%; left: 46%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 74%; left: 25%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 34%; left: 55%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 26%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 97%; left: 27%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 5%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 3%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 97%; left: 12%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 97%; left: 10%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 97%; left: 15%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 11%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 97%; left: 6%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 96%; left: 7%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 97%; left: 7%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 98%; left: 5%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 4%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div></div>',"Nevada":'<div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 27%; left: 44%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 8%; left: 53%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 38%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 62%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 63%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 33%; left: 71%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 90%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 17%; left: 58%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 27%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 36%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 56%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 30%; left: 67%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 67%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 80%; left: 65%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 63%; left: 75%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 54%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 30%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 29%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 87%; left: 5%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 64%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 55%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 22%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 44%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 21%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 9%; left: 14%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 20%; left: 54%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 62%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 81%; left: 42%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 30%; left: 29%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 24%; left: 12%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 11%; left: 55%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 11%; left: 42%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 16%; left: 14%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 52%; left: 3%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 43%; left: 33%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>28</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 65%; left: 28%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>27</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 33%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 47%; left: 45%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 34%; left: 60%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 71%; left: 30%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 87%; left: 21%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 68%; left: 25%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 88%; left: 24%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 40%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 23%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 17%; left: 52%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 11%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 36%; left: 35%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 45%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 24%; left: 28%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 25%; left: 25%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 22%; left: 28%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 23%; left: 20%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 33%; left: 13%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 40%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 37%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 82%; left: 56%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 35%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 72%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 25%; left: 56%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 94%; left: 56%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 91%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 66%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 13%; left: 21%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 89%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 88%; left: 67%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 65%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 68%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 74%; left: 65%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 59%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 42%; left: 49%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 87%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 92%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 46%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 69%; left: 14%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 14%; left: 6%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 21%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>27</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 14%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 13%; left: 39%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 56%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 94%; left: 55%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 80%; left: 34%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 84%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 50%; left: 20%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 15%; left: 20%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 29%; left: 13%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 86%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 72%; left: 12%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 41%; left: 35%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 85%; left: 65%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 51%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 54%; left: 38%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>22</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 48%; left: 14%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 40%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>27</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 61%; left: 63%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div></div>',"Pepperdine":'<div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 43%; left: 19%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 14%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 53%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 45%; left: 26%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 45%; left: 78%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 24%; left: 77%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 5%; left: 57%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 54%; left: 49%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 22%; left: 6%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 64%; left: 45%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 53%; left: 27%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 50%; left: 91%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 40%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 45%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 42%; left: 14%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 52%; left: 53%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 6%; left: 46%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 15%; left: 5%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 65%; left: 20%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 74%; left: 27%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 41%; left: 69%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 47%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 98%; left: 79%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 69%; left: 64%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 50%; left: 64%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 90%; left: 60%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 20%; left: 29%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 25%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 20%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 95%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 79%; left: 51%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>27</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 52%; left: 29%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 33%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 18%; left: 43%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 44%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 85%; left: 7%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 3%; left: 58%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>18</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 60%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>19</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 9%; left: 44%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>18</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 3%; left: 32%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 78%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>27</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 43%; left: 44%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 78%; left: 65%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 9%; left: 72%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 98%; left: 74%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 61%; left: 55%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 64%; left: 63%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 54%; left: 78%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 63%; left: 76%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 35%; left: 58%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 14%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 97%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 82%; left: 20%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 89%; left: 33%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 15%; left: 13%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 35%; left: 4%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 91%; left: 81%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 50%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 63%; left: 14%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 78%; left: 22%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 40%; left: 15%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 68%; left: 31%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 78%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 67%; left: 5%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 19%; left: 67%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 18%; left: 19%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 48%; left: 50%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 78%; left: 41%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 58%; left: 28%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 80%; left: 66%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 88%; left: 67%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 56%; left: 63%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>8</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 65%; left: 36%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 63%; left: 42%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>27</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 36%; left: 8%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 40%; left: 18%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 64%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 95%; left: 6%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>26</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 98%; left: 3%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 8%; background-color: rgb(255, 255, 255); border-color: rgb(0, 0, 0); color: rgb(0, 0, 0);"><span>26</span></div></div>',"SF":'<div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 90%; left: 60%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 85%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 47%; left: 7%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 72%; left: 51%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 66%; left: 20%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 40%; left: 47%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 87%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 38%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 67%; left: 66%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 59%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 6%; left: 8%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 8%; left: 15%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 27%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 27%; left: 21%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 89%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 88%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 76%; left: 91%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 69%; left: 73%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 43%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 19%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 28%; left: 54%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 10%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 62%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 79%; left: 56%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 82%; left: 43%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 44%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 18%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 69%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 61%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 20%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 89%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 67%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 80%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>27</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 77%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 70%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 69%; left: 14%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>27</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 45%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 44%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 43%; left: 47%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 34%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 89%; left: 44%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 72%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 81%; left: 24%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 90%; left: 8%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 12%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 74%; left: 16%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 14%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 97%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 24%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 61%; left: 14%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 80%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 71%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 24%; left: 63%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 91%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 26%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 26%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 77%; left: 44%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 61%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 72%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 61%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 76%; left: 69%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>11</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 58%; left: 50%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 51%; left: 63%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 71%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 82%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 98%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 63%; left: 24%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 89%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 46%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 36%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 91%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>16</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 97%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 87%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 72%; left: 10%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 2%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 95%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 74%; left: 5%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 77%; left: 25%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 90%; left: 12%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 55%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 97%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 13%; left: 24%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 74%; left: 29%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 13%; left: 35%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 11%; left: 24%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 26%; left: 31%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 13%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 14%; left: 6%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 41%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>9</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 40%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>18</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 93%; left: 43%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div></div>',"Cal":'<div class="teamstats__Dots-module__dots___3yZWS"><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 68%; left: 38%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 25%; left: 12%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 14%; left: 9%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>3</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 29%; left: 12%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 32%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 4%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 88%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 12%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 15%; left: 11%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 94%; left: 85%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 86%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>13</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 78%; left: 37%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 45%; left: 46%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 11%; left: 64%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 96%; left: 58%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 13%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 24%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 14%; left: 97%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 47%; left: 48%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 52%; left: 28%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 34%; left: 54%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 37%; left: 43%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 81%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 31%; left: 51%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 14%; left: 47%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 16%; left: 47%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 24%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 12%; left: 82%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 11%; left: 85%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 98%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>23</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 27%; left: 23%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 97%; left: 22%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 6%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 83%; left: 67%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 84%; left: 70%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>21</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 9%; left: 71%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 55%; left: 6%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>1</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 75%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 61%; left: 42%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 24%; left: 10%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 37%; left: 65%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 71%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 15%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 17%; left: 13%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 26%; left: 12%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 70%; left: 57%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 32%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 73%; left: 34%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 35%; left: 39%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 26%; left: 36%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 24%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 10%; left: 86%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 59%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 19%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 27%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 5%; left: 30%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 4%; left: 33%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 79%; left: 58%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 47%; left: 18%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 6%; left: 15%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>15</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 7%; left: 24%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 55%; left: 20%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 30%; left: 32%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>6</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 77%; left: 26%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>7</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 7%; left: 16%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>27</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 33%; left: 53%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 75%; left: 61%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__unsuccessful___1ch2n" style="top: 32%; left: 17%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>14</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 67%; left: 65%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 77%; left: 55%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>4</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 21%; left: 56%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>5</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 58%; left: 58%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>10</span></div><div class="teamstats__Dots-module__dot___147xT teamstats__Dots-module__successful___1vAJ-" style="top: 8%; left: 19%; background-color: rgb(0, 0, 0); border-color: rgb(255, 255, 255); color: rgb(255, 255, 255);"><span>17</span></div></div>'}

# %%
positions = []
for game in games:
    fullHtml = games[game]
    dots =fullHtml.find("teamstats__Dots-module__dots")
    dotsData = fullHtml[dots:]

    labels = dotsData.split('<div class="teamstats__Dots-module__dot')
    
    for label in labels[1:]:
        left = label.find("left:")
        left = int(label[left+6:left+8].replace("%",""))/100*120
        top = label.find("top:")
        top = int(label[top+5:top+7].replace("%",""))/100*80
        player = int(label.split("span")[-2].replace(">","").replace("<","").replace("/",""))
        positions.append([game, left,top,"module__successful" in label, player])
positions = pd.DataFrame(positions,columns=["game","x1","y1","won","player"])
duelsOwnHalf = positions[positions.get("x1")<60]
def assignSide(y1):
    if y1<40:
        return "Left"
    else:
        return "Right"
duelsOwnHalf = duelsOwnHalf.assign(Side = duelsOwnHalf.get("y1").apply(assignSide))
left = duelsOwnHalf[duelsOwnHalf.get("Side")=="Left"]
right = duelsOwnHalf[duelsOwnHalf.get("Side")=="Right"]

# %%
positions.to_csv("DefensiveDuels.csv",index=False)

# %%
print(duelsOwnHalf.get("won").mean(),left.get("won").mean(),right.get("won").mean())
# Out:
# 0.7224137931034482 0.7380952380952381 0.7062937062937062

# %%
positions.head(60)
positions.get("won").mean()
# Out:
# 0.7158712541620422

# %%
won = positions[positions.get("won")]
lost = positions[~positions.get("won")]
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=lost.get("x1"),y=lost.get("y1"),fill = True,shade_lowest = False,alpha = .5,n_levels = 15,cmap = "magma")
for i in range(lost.shape[0]):
    row = lost.iloc[i]
    if row.get("won"):
        color = "og"
    else:
        color = "ro"
    plt.plot(row.get("x1"),row.get("y1"),color)
plt.title("UCSD Defensive Duels lost")
plt.show()
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
kde = sns.kdeplot(x=won.get("x1"),y=won.get("y1"),fill = True,shade_lowest = False,alpha = .5,n_levels = 15,cmap = "magma")
for i in range(won.shape[0]):
    row = won.iloc[i]
    if row.get("won"):
        color = "og"
    else:
        color = "ro"
    plt.plot(row.get("x1"),row.get("y1"),color)
plt.title("UCSD Defensive Duels Won")
plt.show()

# %%
bins = (6,5)
pitch = Pitch(positional=True)
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')
# plot the heatmap - darker colors = more passes originating from that square
bs_heatmap = pitch.bin_statistic(positions.x1, positions.y1, statistic='count', bins=bins)
successful_bins = pitch.bin_statistic(won.x1, won.y1, statistic='count', bins=bins)
unsuccessful_bins = pitch.bin_statistic(lost.x1, lost.y1, statistic='count', bins=bins)
accuracies = successful_bins["statistic"]/(successful_bins["statistic"]+unsuccessful_bins["statistic"])
bs_heatmap["statistic"]=accuracies
hm = pitch.heatmap(bs_heatmap, ax=ax, cmap='Greens',alpha = .6)

labels2 = pitch.label_heatmap(bs_heatmap, color='black', fontsize=18,
                              ax=ax, ha='center', va='center',
                              str_format='{:.0%}',)
plt.title("Defensive Duels Accuracy on Pitch",color = "white",fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Defensive Duels Accuracy on Pitch')

# %%
num = 15
player = positions[positions.get("player")==num]
won = player[player.get("won")]
lost = player[~player.get("won")]
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
#kde = sns.kdeplot(x=lost.get("x1"),y=lost.get("y1"),fill = True,shade_lowest = False,alpha = .5,n_levels = 15,cmap = "magma")
for i in range(lost.shape[0]):
    row = lost.iloc[i]
    if row.get("won"):
        color = "og"
    else:
        color = "ro"
    plt.plot(row.get("x1"),row.get("y1"),color)
plt.title(str(num)+" Defensive Duels lost")
plt.show()
pitch = Pitch(positional=True, axis=True,label=True)
fig, ax = plt.subplots(figsize = (10,6))
pitch.draw(ax=ax)
#kde = sns.kdeplot(x=won.get("x1"),y=won.get("y1"),fill = True,shade_lowest = False,alpha = .5,n_levels = 15,cmap = "magma")
for i in range(won.shape[0]):
    row = won.iloc[i]
    if row.get("won"):
        color = "og"
    else:
        color = "ro"
    plt.plot(row.get("x1"),row.get("y1"),color)
plt.title(str(num)+" Defensive Duels Won")
plt.show()
